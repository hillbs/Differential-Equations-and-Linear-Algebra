# %%
import pandas as pd
import matplotlib.pyplot as plt 
import pprint as pp
import glob
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 20)
Files = glob.glob("/Users/LlewelynRW/Dropbox/Leigh/*.xlsx")
figsize(10,8)
Files[0]
# Out:
# '/Users/LlewelynRW/Dropbox/Leigh/Eastside youth survey Results.xlsx'

# %%
for name, hex in matplotlib.colors.cnames.iteritems():
    print(name, hex)
# Out:
# (u'indigo', u'#4B0082')
# (u'gold', u'#FFD700')
# (u'hotpink', u'#FF69B4')
# (u'firebrick', u'#B22222')
# (u'indianred', u'#CD5C5C')
# (u'sage', u'#87AE73')
# (u'yellow', u'#FFFF00')
# (u'mistyrose', u'#FFE4E1')
# (u'darkolivegreen', u'#556B2F')
# (u'olive', u'#808000')
# (u'darkseagreen', u'#8FBC8F')
# (u'pink', u'#FFC0CB')
# (u'tomato', u'#FF6347')
# (u'lightcoral', u'#F08080')
# (u'orangered', u'#FF4500')
# (u'navajowhite', u'#FFDEAD')
# (u'lime', u'#00FF00')
# (u'palegreen', u'#98FB98')
# (u'darkslategrey', u'#2F4F4F')
# (u'greenyellow', u'#ADFF2F')
# (u'burlywood', u'#DEB887')
# (u'seashell', u'#FFF5EE')
# (u'mediumspringgreen', u'#00FA9A')
# (u'fuchsia', u'#FF00FF')
# (u'papayawhip', u'#FFEFD5')
# (u'blanchedalmond', u'#FFEBCD')
# (u'chartreuse', u'#7FFF00')
# (u'dimgray', u'#696969')
# (u'black', u'#000000')
# (u'peachpuff', u'#FFDAB9')
# (u'springgreen', u'#00FF7F')
# (u'aquamarine', u'#7FFFD4')
# (u'white', u'#FFFFFF')
# (u'orange', u'#FFA500')
# (u'lightsalmon', u'#FFA07A')
# (u'darkslategray', u'#2F4F4F')
# (u'brown', u'#A52A2A')
# (u'ivory', u'#FFFFF0')
# (u'dodgerblue', u'#1E90FF')
# (u'peru', u'#CD853F')
# (u'darkgrey', u'#A9A9A9')
# (u'lawngreen', u'#7CFC00')
# (u'chocolate', u'#D2691E')
# (u'crimson', u'#DC143C')
# (u'forestgreen', u'#228B22')
# (u'slateblue', u'#6A5ACD')
# (u'lightseagreen', u'#20B2AA')
# (u'cyan', u'#00FFFF')
# (u'mintcream', u'#F5FFFA')
# (u'silver', u'#C0C0C0')
# (u'antiquewhite', u'#FAEBD7')
# (u'mediumorchid', u'#BA55D3')
# (u'skyblue', u'#87CEEB')
# (u'gray', u'#808080')
# (u'darkturquoise', u'#00CED1')
# (u'goldenrod', u'#DAA520')
# (u'darkgreen', u'#006400')
# (u'floralwhite', u'#FFFAF0')
# (u'darkviolet', u'#9400D3')
# (u'darkgray', u'#A9A9A9')
# (u'moccasin', u'#FFE4B5')
# (u'saddlebrown', u'#8B4513')
# (u'grey', u'#808080')
# (u'darkslateblue', u'#483D8B')
# (u'lightskyblue', u'#87CEFA')
# (u'lightpink', u'#FFB6C1')
# (u'mediumvioletred', u'#C71585')
# (u'slategrey', u'#708090')
# (u'red', u'#FF0000')
# (u'deeppink', u'#FF1493')
# (u'limegreen', u'#32CD32')
# (u'darkmagenta', u'#8B008B')
# (u'palegoldenrod', u'#EEE8AA')
# (u'plum', u'#DDA0DD')
# (u'turquoise', u'#40E0D0')
# (u'lightgrey', u'#D3D3D3')
# (u'lightgoldenrodyellow', u'#FAFAD2')
# (u'darkgoldenrod', u'#B8860B')
# (u'lavender', u'#E6E6FA')
# (u'maroon', u'#800000')
# (u'yellowgreen', u'#9ACD32')
# (u'sandybrown', u'#FAA460')
# (u'thistle', u'#D8BFD8')
# (u'violet', u'#EE82EE')
# (u'navy', u'#000080')
# (u'magenta', u'#FF00FF')
# (u'dimgrey', u'#696969')
# (u'tan', u'#D2B48C')
# (u'rosybrown', u'#BC8F8F')
# (u'olivedrab', u'#6B8E23')
# (u'blue', u'#0000FF')
# (u'lightblue', u'#ADD8E6')
# (u'ghostwhite', u'#F8F8FF')
# (u'honeydew', u'#F0FFF0')
# (u'cornflowerblue', u'#6495ED')
# (u'linen', u'#FAF0E6')
# (u'darkblue', u'#00008B')
# (u'powderblue', u'#B0E0E6')
# (u'seagreen', u'#2E8B57')
# (u'darkkhaki', u'#BDB76B')
# (u'snow', u'#FFFAFA')
# (u'sienna', u'#A0522D')
# (u'mediumblue', u'#0000CD')
# (u'royalblue', u'#4169E1')
# (u'lightcyan', u'#E0FFFF')
# (u'green', u'#008000')
# (u'mediumpurple', u'#9370DB')
# (u'midnightblue', u'#191970')
# (u'cornsilk', u'#FFF8DC')
# (u'paleturquoise', u'#AFEEEE')
# (u'bisque', u'#FFE4C4')
# (u'slategray', u'#708090')
# (u'darkcyan', u'#008B8B')
# (u'khaki', u'#F0E68C')
# (u'wheat', u'#F5DEB3')
# (u'teal', u'#008080')
# (u'darkorchid', u'#9932CC')
# (u'deepskyblue', u'#00BFFF')
# (u'salmon', u'#FA8072')
# (u'darkred', u'#8B0000')
# (u'steelblue', u'#4682B4')
# (u'palevioletred', u'#DB7093')
# (u'lightslategray', u'#778899')
# (u'aliceblue', u'#F0F8FF')
# (u'lightslategrey', u'#778899')
# (u'lightgreen', u'#90EE90')
# (u'orchid', u'#DA70D6')
# (u'gainsboro', u'#DCDCDC')
# (u'mediumseagreen', u'#3CB371')
# (u'lightgray', u'#D3D3D3')
# (u'mediumturquoise', u'#48D1CC')
# (u'darksage', u'#598556')
# (u'lemonchiffon', u'#FFFACD')
# (u'cadetblue', u'#5F9EA0')
# (u'lightyellow', u'#FFFFE0')
# (u'lavenderblush', u'#FFF0F5')
# (u'coral', u'#FF7F50')
# (u'purple', u'#800080')
# (u'aqua', u'#00FFFF')
# (u'lightsage', u'#BCECAC')
# (u'whitesmoke', u'#F5F5F5')
# (u'mediumslateblue', u'#7B68EE')
# (u'darkorange', u'#FF8C00')
# (u'mediumaquamarine', u'#66CDAA')
# (u'darksalmon', u'#E9967A')
# (u'beige', u'#F5F5DC')
# (u'blueviolet', u'#8A2BE2')
# (u'azure', u'#F0FFFF')
# (u'lightsteelblue', u'#B0C4DE')
# (u'oldlace', u'#FDF5E6')

# %%
#Create function to plot bar chart
def Make_bar(A,B,C,Header, Y_label,color='purple',alpha=.7):
    '''A is <object>.count()
       B is <object.values[0:A]
       c is <object>.keys()
       Header is plot title
       Y_Label is y-axis title'''
    N = A#10#schools.count()
    ind = np.arange(N)  # the x locations for the groups
    width = .8       # the width of the bars
    f = plt.figure()#facecolor=".9")
    ax = f.add_subplot(111)#, axisbg="#F4EAEA")
    rects1 = ax.bar(ind, B, width, color=color,alpha=alpha)

    # add some text for labels, title and axes ticks
    ax.set_ylabel(Y_label,fontsize=16)
    #ax.set_xlabel(ind,fontsize=16)
    ax.set_title(Header,fontsize=20)
    ax.set_xticks(ind+width/3)
    ax.set_fontsize=16
    xtickNames = ax.set_xticklabels(C)
    plt.setp(xtickNames, rotation=45, fontsize=14)
    ymax = np.max(B)*1.1
    plt.ylim(ymax=ymax) 
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                    ha='center', va='bottom',fontsize=16)

    autolabel(rects1)
    plt.grid(True)
    plt.show()
    return

# %%
#plt.figure()
def Standard_background():
    f = plt.figure()#facecolor=".9")
    ax = f.add_subplot(111)#, axisbg="#F4EAEA")
    return

# %% [markdown]
# ## Import Data

# %%
df = pd.read_excel(Files[0],sheetname='Raw data to be entered', na_values=0,index_row=0)
#This is a wee snippet to insert _ where there are column spaces
cols = df.columns
cols = cols.map(lambda x: x.replace(' ', '_') if isinstance(x, (str, unicode)) else x)
df.columns = cols
df.head(4)
# Out:
#    ID  Age  NZEuro Maori                 IWI Samoan  Cook_Is  Tongan  Niuean  \
# 0  o1    9     NaN     1              Mataua    NaN      NaN     NaN     NaN
# 1  o2   10     NaN     1  Te whanau-a-apanui    NaN      NaN     NaN     NaN
# 2  o3    9     NaN     1                 NaN    NaN      NaN     NaN     NaN
# 3  o4    9     NaN     1                 NaN    NaN      NaN     NaN     NaN
#
#    Chinese  Indian Other Gender_(M/F) Local_Area  Whangamarino  Rotokawa  \
# 0      NaN     NaN   NaN            F     Owhata           NaN       NaN
# 1      NaN     NaN   NaN            F     Owhata           NaN       NaN
# 2      NaN     NaN   NaN            F     Owhata           NaN       NaN
# 3      NaN     NaN   NaN            F     Owhata           NaN       NaN
#
#    RLHS  Owhata  Rotoma  Lynmore  Ruamata  Mokoia  Bus  Rollerblade  \
# 0   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 1   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 2   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 3   NaN       1     NaN      NaN      NaN     NaN    1          NaN
#
#    Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  Scooter Other.1  Family  \
# 0         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 1         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 2         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
# 3         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
#
#    Education  Friends  My_job/work  Finding_a_job  Social_life_-_fun  \
# 0        NaN      NaN          NaN            NaN                NaN
# 1        NaN      NaN          NaN            NaN                NaN
# 2        NaN      NaN          NaN            NaN                NaN
# 3        NaN      NaN          NaN            NaN                NaN
#
#    Money_making  Interests/hobbies  Sport Other.2  Lonely  Relationships  \
# 0           NaN                NaN    NaN     NaN     NaN            NaN
# 1           NaN                NaN    NaN     NaN     NaN            NaN
# 2           NaN                NaN    NaN     NaN     NaN            NaN
# 3           NaN                NaN    NaN     NaN     NaN            NaN
#
#    Grades  D&A  Bullying  Lack_of_money  Violence  Finding_job  \
# 0     NaN  NaN       NaN            NaN       NaN            1
# 1       1  NaN       NaN            NaN       NaN          NaN
# 2     NaN  NaN       NaN            NaN       NaN          NaN
# 3       1  NaN       NaN            NaN         1          NaN
#
#             ...            Culture.2  School  Shopping  With_friends_  \
# 0           ...                  NaN     NaN         1              1
# 1           ...                  NaN     NaN         1            NaN
# 2           ...                  NaN     NaN         1              1
# 3           ...                  NaN       1         1              1
#
#   With_family  Nothing  Other.6  Physical.1  Sport.2  Music.1  Creative.1  \
# 0           1      NaN      NaN           1      NaN      NaN           1
# 1           1      NaN      NaN           1        1      NaN         NaN
# 2           1      NaN      NaN         NaN      NaN        1           1
# 3         NaN      NaN      NaN         NaN      NaN        1         NaN
#
#    Comm_fiar.1  Youth_group.1  Faith_group.1  Student_council.1  \
# 0          NaN              1            NaN                  1
# 1            1            NaN            NaN                NaN
# 2          NaN            NaN            NaN                  1
# 3          NaN            NaN            NaN                NaN
#
#    Community_interest.1  Environmental_Volunter.1 Volunteering.1 Art.1  \
# 0                   NaN                         1              1     1
# 1                     1                       NaN            NaN   NaN
# 2                   NaN                       NaN              1     1
# 3                   NaN                       NaN            NaN   NaN
#
#   Culture.3 School.1 Shopping.1  With_friends_.1  With_family.1  Nothing.1  \
# 0         1        1        NaN              NaN            NaN        NaN
# 1         1        1        NaN              NaN            NaN        NaN
# 2       NaN      NaN        NaN              NaN            NaN        NaN
# 3       NaN      NaN        NaN              NaN              1        NaN
#
#    Other.7  Not_interested  Time  Costs_too_much  Can't_afford  No_friends  \
# 0      NaN             NaN   NaN               1             1           1
# 1      NaN             NaN   NaN               1           NaN           1
# 2      NaN             NaN   NaN               1           NaN         NaN
# 3      NaN             NaN   NaN             NaN           NaN         NaN
#
#   not_available  Cant_get_there  Shy  Other_responsibility  Parents_say_no  \
# 0           NaN               1    1                   NaN               1
# 1           NaN             NaN  NaN                   NaN             NaN
# 2             1             NaN    1                   NaN               1
# 3             1             NaN  NaN                   NaN             NaN
#
#    Don't_know_how  Other.8  Internet  Church.1  School.2  Newspaper  WINZ  \
# 0               1      NaN       NaN       NaN         1          1   NaN
# 1             NaN      NaN       NaN       NaN         1          1   NaN
# 2             NaN      NaN       NaN       NaN         1        NaN   NaN
# 3             NaN  no time       NaN       NaN         1        NaN   NaN
#
#    Library.1  Youth_group.2  Mail  Txt  800  Other.9  Eastside_youth_council
# 0        NaN            NaN   NaN  NaN  NaN      NaN                       Y
# 1          1            NaN     1  NaN  NaN   whanau                       Y
# 2        NaN            NaN     1  NaN  NaN      NaN                       N
# 3        NaN            NaN   NaN  NaN    1      NaN                       Y
#
# [4 rows x 176 columns]

# %% [markdown]
# ## Clean Data|

# %%
#Create School column
df.ix[df.Lynmore >= 1,'School'] = 'Lynmore'
df.ix[df.Whangamarino >= 1,'School'] = 'Whangamarino'
df.ix[df.Rotokawa >= 1,'School'] = 'Rotokawa'
df.ix[df.RLHS >= 1,'School'] = 'RLHS'
df.ix[df.Owhata  >= 1,'School'] = 'Owhata'
df.ix[df.Rotoma  >= 1,'School'] = 'Rotoma'
df.ix[df.Ruamata  >= 1,'School'] = 'Ruamata'
df.ix[df.Mokoia  >= 1,'School'] = 'Mokoia'
df.head
# Out:
# <bound method DataFrame.head of       ID  Age  NZEuro Maori                 IWI Samoan  Cook_Is  Tongan  \
# 0     o1    9     NaN     1              Mataua    NaN      NaN     NaN
# 1     o2   10     NaN     1  Te whanau-a-apanui    NaN      NaN     NaN
# 2     o3    9     NaN     1                 NaN    NaN      NaN     NaN
# 3     o4    9     NaN     1                 NaN    NaN      NaN     NaN
# 4     o5   10     NaN   NaN                 NaN    NaN        1     NaN
# 5     o6   10     NaN     1               Tuhoe    NaN      NaN     NaN
# 6     o7    9       1   NaN                 NaN    NaN      NaN     NaN
# 7     o8   10       1     1                 NaN    NaN      NaN     NaN
# 8     o9    9     NaN     1                 NaN    NaN      NaN     NaN
# 9    o10    9       1     1                 NaN    NaN      NaN     NaN
# ..   ...  ...     ...   ...                 ...    ...      ...     ...
# 856  R27   10       1   NaN                 NaN    NaN      NaN     NaN
# 857  R28    9       1   NaN                 NaN    NaN      NaN     NaN
# 858  R29    9       1   NaN                 NaN    NaN      NaN     NaN
# 859  R30    9     NaN     1                 NaN    NaN      NaN     NaN
# 860  R31    9     NaN     1                 NaN    NaN      NaN     NaN
# 861  R32   10       1     1                 NaN    NaN      NaN     NaN
# 862  R33    9       1     1                 NaN    NaN      NaN     NaN
# 863  R34    9       1   NaN                 NaN    NaN        1     NaN
# 864  R35   10       1     1                 NaN    NaN      NaN     NaN
# 865  R36   10       1     1                 NaN    NaN      NaN     NaN
#
#      Niuean  Chinese  Indian Other Gender_(M/F)   Local_Area  Whangamarino  \
# 0       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 1       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 2       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 3       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 4       NaN      NaN     NaN   NaN            M      Ngapuna           NaN
# 5       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 6       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 7       NaN      NaN     NaN   NaN            M      Ngapuna           NaN
# 8       NaN      NaN     NaN   NaN            M       Owhata           NaN
# 9       NaN      NaN     NaN   NaN            F       Owhata           NaN
# ..      ...      ...     ...   ...          ...          ...           ...
# 856     NaN      NaN     NaN   NaN            M  Okere Falls           NaN
# 857     NaN      NaN     NaN   NaN            F       Owhata           NaN
# 858     NaN      NaN     NaN   NaN            F      Rotoiti           NaN
# 859     NaN      NaN     NaN   NaN            M          NaN           NaN
# 860     NaN      NaN     NaN   NaN            M          NaN           NaN
# 861     NaN      NaN     NaN   NaN            M      Lynmore           NaN
# 862     NaN      NaN     NaN   NaN            F       Owhata           NaN
# 863     NaN      NaN     NaN   NaN            M          NaN           NaN
# 864     NaN      NaN     NaN   NaN            M          NaN           NaN
# 865     NaN      NaN     NaN   NaN            F     Tikitere           NaN
#
#      Rotokawa  RLHS  Owhata  Rotoma  Lynmore  Ruamata  Mokoia  Bus  \
# 0         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 1         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 2         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 3         NaN   NaN       1     NaN      NaN      NaN     NaN    1
# 4         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 5         NaN   NaN       1     NaN      NaN      NaN     NaN    1
# 6         NaN   NaN       1     NaN      NaN      NaN     NaN    1
# 7         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 8         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 9         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# ..        ...   ...     ...     ...      ...      ...     ...  ...
# 856         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 857         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 858         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 859         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 860         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 861         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 862         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 863         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 864         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 865         1   NaN     NaN     NaN      NaN      NaN     NaN    1
#
#      Rollerblade  Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  Scooter  \
# 0            NaN         NaN  NaN         1   NaN        NaN   NaN      NaN
# 1            NaN         NaN  NaN         1   NaN        NaN   NaN      NaN
# 2            NaN         NaN    1         1   NaN        NaN   NaN      NaN
# 3            NaN         NaN    1         1   NaN        NaN   NaN      NaN
# 4            NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 5            NaN         NaN  NaN       NaN   NaN        NaN   NaN      NaN
# 6            NaN         NaN    1         1   NaN          1   NaN      NaN
# 7            NaN         NaN  NaN         1   NaN        NaN   NaN      NaN
# 8            NaN         NaN    1         1   NaN        NaN   NaN      NaN
# 9            NaN         NaN    1         1   NaN        NaN   NaN        1
# ..           ...         ...  ...       ...   ...        ...   ...      ...
# 856          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 857          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 858          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 859          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 860          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 861          NaN         NaN    1         1     1          1   NaN        1
# 862          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 863          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 864          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 865          NaN         NaN  NaN       NaN   NaN        NaN   NaN      NaN
#
#     Other.1  Family  Education  Friends  My_job/work  Finding_a_job  \
# 0       NaN       1        NaN      NaN          NaN            NaN
# 1       NaN       1        NaN      NaN          NaN            NaN
# 2       NaN       1        NaN      NaN          NaN            NaN
# 3       NaN       1        NaN      NaN          NaN            NaN
# 4       NaN       1        NaN      NaN          NaN            NaN
# 5       NaN     NaN          1      NaN          NaN            NaN
# 6       NaN       1        NaN        1            1            NaN
# 7       NaN       1          1        1          NaN            NaN
# 8       NaN       1        NaN      NaN          NaN            NaN
# 9       NaN       1        NaN      NaN          NaN            NaN
# ..      ...     ...        ...      ...          ...            ...
# 856     NaN       1        NaN      NaN          NaN            NaN
# 857     NaN       1        NaN      NaN          NaN            NaN
# 858     NaN       1          1      NaN          NaN            NaN
# 859     NaN       1        NaN      NaN          NaN            NaN
# 860     NaN       1        NaN      NaN          NaN            NaN
# 861     NaN       1        NaN      NaN          NaN            NaN
# 862     NaN       1        NaN      NaN          NaN            NaN
# 863     NaN       1        NaN        1          NaN            NaN
# 864     NaN       1        NaN      NaN          NaN            NaN
# 865     NaN       1          1      NaN          NaN            NaN
#
#      Social_life_-_fun  Money_making  Interests/hobbies  Sport Other.2  \
# 0                  NaN           NaN                NaN    NaN     NaN
# 1                  NaN           NaN                NaN    NaN     NaN
# 2                  NaN           NaN                NaN    NaN     NaN
# 3                  NaN           NaN                NaN    NaN     NaN
# 4                  NaN           NaN                NaN    NaN     NaN
# 5                  NaN           NaN                NaN    NaN     NaN
# 6                  NaN             1                NaN    NaN     NaN
# 7                    1           NaN                NaN    NaN     NaN
# 8                  NaN           NaN                NaN    NaN     NaN
# 9                  NaN           NaN                NaN    NaN     NaN
# ..                 ...           ...                ...    ...     ...
# 856                NaN           NaN                NaN    NaN     NaN
# 857                NaN           NaN                NaN    NaN     NaN
# 858                NaN           NaN                NaN    NaN     NaN
# 859                NaN           NaN                NaN    NaN     NaN
# 860                NaN           NaN                NaN    NaN     NaN
# 861                NaN           NaN                NaN    NaN     NaN
# 862                NaN           NaN                NaN      1     NaN
# 863                NaN           NaN                NaN    NaN     NaN
# 864                NaN           NaN                  1      1     NaN
# 865                NaN           NaN                NaN    NaN     NaN
#
#      Lonely  Relationships  Grades  D&A  Bullying  Lack_of_money  Violence  \
# 0       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 1       NaN            NaN       1  NaN       NaN            NaN       NaN
# 2       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 3       NaN            NaN       1  NaN       NaN            NaN         1
# 4       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 5       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 6       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 7       NaN            NaN       1  NaN       NaN            NaN       NaN
# 8         1            NaN     NaN  NaN       NaN            NaN       NaN
# 9         1              1       1    1       NaN            NaN         1
# ..      ...            ...     ...  ...       ...            ...       ...
# 856       1            NaN     NaN  NaN       NaN            NaN       NaN
# 857       1            NaN     NaN  NaN       NaN            NaN       NaN
# 858     NaN            NaN       1  NaN       NaN            NaN       NaN
# 859     NaN            NaN     NaN  NaN         1            NaN         1
# 860       1            NaN     NaN  NaN         1            NaN       NaN
# 861     NaN            NaN       1    1       NaN            NaN       NaN
# 862       1            NaN     NaN  NaN       NaN            NaN       NaN
# 863       1            NaN     NaN  NaN         1            NaN       NaN
# 864     NaN            NaN       1    1       NaN            NaN       NaN
# 865       1            NaN     NaN  NaN       NaN            NaN       NaN
#
#      Finding_job           ...            Culture.2    School  Shopping  \
# 0              1           ...                  NaN    Owhata         1
# 1            NaN           ...                  NaN    Owhata         1
# 2            NaN           ...                  NaN    Owhata         1
# 3            NaN           ...                  NaN    Owhata         1
# 4            NaN           ...                    1    Owhata         1
# 5            NaN           ...                  NaN    Owhata         1
# 6            NaN           ...                  NaN    Owhata       NaN
# 7            NaN           ...                  NaN    Owhata         1
# 8            NaN           ...                  NaN    Owhata       NaN
# 9            NaN           ...                    1    Owhata         1
# ..           ...           ...                  ...       ...       ...
# 856          NaN           ...                  NaN  Rotokawa       NaN
# 857          NaN           ...                  NaN  Rotokawa         1
# 858          NaN           ...                  NaN  Rotokawa         1
# 859          NaN           ...                    1  Rotokawa         1
# 860          NaN           ...                  NaN  Rotokawa       NaN
# 861          NaN           ...                  NaN  Rotokawa         1
# 862          NaN           ...                  NaN  Rotokawa         1
# 863          NaN           ...                  NaN  Rotokawa       NaN
# 864          NaN           ...                  NaN  Rotokawa       NaN
# 865          NaN           ...                  NaN  Rotokawa       NaN
#
#      With_friends_ With_family  Nothing       Other.6  Physical.1  Sport.2  \
# 0                1           1      NaN           NaN           1      NaN
# 1              NaN           1      NaN           NaN           1        1
# 2                1           1      NaN           NaN         NaN      NaN
# 3                1         NaN      NaN           NaN         NaN      NaN
# 4                1           1      NaN           NaN         NaN      NaN
# 5                1           1      NaN           NaN         NaN      NaN
# 6                1           1      NaN           NaN           1        1
# 7                1           1      NaN           NaN         NaN      NaN
# 8                1           1      NaN           NaN         NaN      NaN
# 9                1           1      NaN           NaN         NaN      NaN
# ..             ...         ...      ...           ...         ...      ...
# 856            NaN         NaN      NaN           NaN         NaN      NaN
# 857            NaN         NaN        1           NaN         NaN      NaN
# 858              1         NaN      NaN           NaN         NaN      NaN
# 859              1           1      NaN           NaN         NaN      NaN
# 860            NaN         NaN      NaN           NaN         NaN        1
# 861              1           1      NaN           NaN         NaN      NaN
# 862            NaN         NaN        1           NaN         NaN      NaN
# 863            NaN         NaN      NaN           NaN         NaN      NaN
# 864            NaN         NaN      NaN           NaN         NaN      NaN
# 865            NaN         NaN      NaN  horse riding         NaN        1
#
#      Music.1  Creative.1  Comm_fiar.1  Youth_group.1  Faith_group.1  \
# 0        NaN           1          NaN              1            NaN
# 1        NaN         NaN            1            NaN            NaN
# 2          1           1          NaN            NaN            NaN
# 3          1         NaN          NaN            NaN            NaN
# 4        NaN         NaN          NaN            NaN            NaN
# 5        NaN         NaN          NaN            NaN              1
# 6        NaN         NaN          NaN              1            NaN
# 7          1         NaN          NaN            NaN            NaN
# 8        NaN         NaN          NaN            NaN            NaN
# 9        NaN         NaN          NaN              1              1
# ..       ...         ...          ...            ...            ...
# 856        1           1          NaN            NaN            NaN
# 857        1         NaN            1            NaN            NaN
# 858      NaN         NaN          NaN            NaN            NaN
# 859        1         NaN          NaN            NaN            NaN
# 860      NaN         NaN          NaN            NaN            NaN
# 861      NaN         NaN          NaN            NaN            NaN
# 862        1         NaN          NaN            NaN            NaN
# 863      NaN         NaN          NaN            NaN            NaN
# 864      NaN         NaN          NaN            NaN            NaN
# 865      NaN         NaN          NaN            NaN            NaN
#
#      Student_council.1  Community_interest.1  Environmental_Volunter.1  \
# 0                    1                   NaN                         1
# 1                  NaN                     1                       NaN
# 2                    1                   NaN                       NaN
# 3                  NaN                   NaN                       NaN
# 4                  NaN                   NaN                       NaN
# 5                  NaN                   NaN                       NaN
# 6                  NaN                   NaN                       NaN
# 7                    1                   NaN                       NaN
# 8                  NaN                   NaN                       NaN
# 9                    1                     1                       NaN
# ..                 ...                   ...                       ...
# 856                NaN                   NaN                       NaN
# 857                NaN                   NaN                       NaN
# 858                NaN                   NaN                       NaN
# 859                NaN                   NaN                       NaN
# 860                NaN                   NaN                       NaN
# 861                NaN                   NaN                       NaN
# 862                NaN                   NaN                       NaN
# 863                NaN                   NaN                       NaN
# 864                NaN                   NaN                       NaN
# 865                NaN                   NaN                       NaN
#
#     Volunteering.1 Art.1 Culture.3 School.1 Shopping.1  With_friends_.1  \
# 0                1     1         1        1        NaN              NaN
# 1              NaN   NaN         1        1        NaN              NaN
# 2                1     1       NaN      NaN        NaN              NaN
# 3              NaN   NaN       NaN      NaN        NaN              NaN
# 4              NaN   NaN       NaN      NaN        NaN              NaN
# 5              NaN     1       NaN      NaN        NaN              NaN
# 6              NaN     1       NaN      NaN        NaN              NaN
# 7              NaN   NaN         1        1        NaN              NaN
# 8              NaN   NaN       NaN      NaN        NaN              NaN
# 9              NaN   NaN       NaN      NaN        NaN              NaN
# ..             ...   ...       ...      ...        ...              ...
# 856            NaN     1       NaN      NaN        NaN                1
# 857            NaN   NaN       NaN      NaN        NaN              NaN
# 858            NaN     1       NaN      NaN        NaN              NaN
# 859              1     1       NaN      NaN        NaN              NaN
# 860            NaN   NaN       NaN      NaN        NaN              NaN
# 861            NaN   NaN       NaN      NaN        NaN              NaN
# 862            NaN     1       NaN      NaN          1              NaN
# 863            NaN     1       NaN      NaN        NaN              NaN
# 864            NaN   NaN       NaN      NaN        NaN              NaN
# 865              1   NaN       NaN      NaN        NaN                1
#
#      With_family.1  Nothing.1       Other.7  Not_interested  Time  \
# 0              NaN        NaN           NaN             NaN   NaN
# 1              NaN        NaN           NaN             NaN   NaN
# 2              NaN        NaN           NaN             NaN   NaN
# 3                1        NaN           NaN             NaN   NaN
# 4              NaN        NaN           NaN               1     1
# 5              NaN        NaN           NaN             NaN   NaN
# 6              NaN        NaN           NaN             NaN     1
# 7              NaN        NaN           NaN             NaN   NaN
# 8              NaN          1           NaN             NaN   NaN
# 9              NaN          1  be a teacher             NaN   NaN
# ..             ...        ...           ...             ...   ...
# 856            NaN        NaN           NaN               1   NaN
# 857            NaN          1           NaN             NaN     1
# 858            NaN        NaN           NaN             NaN   NaN
# 859            NaN        NaN           NaN               1     1
# 860            NaN        NaN           NaN             NaN   NaN
# 861            NaN          1           NaN               1   NaN
# 862            NaN          1           NaN             NaN   NaN
# 863            NaN        NaN           NaN             NaN   NaN
# 864            NaN          1           NaN             NaN   NaN
# 865            NaN        NaN           NaN             NaN   NaN
#
#      Costs_too_much  Can't_afford  No_friends not_available  Cant_get_there  \
# 0                 1             1           1           NaN               1
# 1                 1           NaN           1           NaN             NaN
# 2                 1           NaN         NaN             1             NaN
# 3               NaN           NaN         NaN             1             NaN
# 4               NaN           NaN         NaN           NaN             NaN
# 5               NaN           NaN         NaN           NaN               1
# 6                 1           NaN         NaN           NaN             NaN
# 7               NaN           NaN           1             1               1
# 8               NaN           NaN         NaN           NaN             NaN
# 9                 1             1           1             1             NaN
# ..              ...           ...         ...           ...             ...
# 856             NaN           NaN         NaN           NaN             NaN
# 857             NaN           NaN         NaN           NaN             NaN
# 858             NaN             1         NaN             1               1
# 859               1             1           1           NaN             NaN
# 860             NaN           NaN         NaN           NaN             NaN
# 861             NaN           NaN         NaN             1             NaN
# 862             NaN           NaN         NaN           NaN             NaN
# 863             NaN           NaN         NaN           NaN             NaN
# 864             NaN           NaN           1           NaN               1
# 865             NaN           NaN         NaN           NaN               1
#
#      Shy  Other_responsibility  Parents_say_no  Don't_know_how  Other.8  \
# 0      1                   NaN               1               1      NaN
# 1    NaN                   NaN             NaN             NaN      NaN
# 2      1                   NaN               1             NaN      NaN
# 3    NaN                   NaN             NaN             NaN  no time
# 4    NaN                   NaN             NaN             NaN      NaN
# 5    NaN                   NaN               1             NaN      NaN
# 6    NaN                     1               1             NaN      NaN
# 7    NaN                   NaN               1               1      NaN
# 8    NaN                   NaN             NaN               1      NaN
# 9      1                     1               1               1      NaN
# ..   ...                   ...             ...             ...      ...
# 856  NaN                   NaN             NaN             NaN      NaN
# 857  NaN                   NaN             NaN             NaN      NaN
# 858  NaN                     1               1               1      NaN
# 859  NaN                   NaN             NaN             NaN      NaN
# 860  NaN                   NaN             NaN             NaN      NaN
# 861  NaN                   NaN             NaN             NaN      NaN
# 862  NaN                   NaN             NaN             NaN      NaN
# 863  NaN                   NaN               1             NaN      NaN
# 864  NaN                   NaN             NaN             NaN      NaN
# 865  NaN                   NaN               1             NaN      NaN
#
#      Internet  Church.1  School.2  Newspaper  WINZ  Library.1  Youth_group.2  \
# 0         NaN       NaN         1          1   NaN        NaN            NaN
# 1         NaN       NaN         1          1   NaN          1            NaN
# 2         NaN       NaN         1        NaN   NaN        NaN            NaN
# 3         NaN       NaN         1        NaN   NaN        NaN            NaN
# 4         NaN       NaN       NaN        NaN   NaN        NaN              1
# 5         NaN       NaN         1        NaN   NaN        NaN            NaN
# 6           1         1         1          1   NaN          1            NaN
# 7           1       NaN       NaN        NaN   NaN        NaN            NaN
# 8         NaN       NaN         1        NaN   NaN        NaN            NaN
# 9         NaN       NaN         1        NaN   NaN        NaN            NaN
# ..        ...       ...       ...        ...   ...        ...            ...
# 856         1       NaN       NaN        NaN   NaN        NaN            NaN
# 857       NaN       NaN       NaN          1   NaN        NaN            NaN
# 858       NaN       NaN       NaN          1   NaN        NaN            NaN
# 859         1       NaN         1        NaN   NaN          1            NaN
# 860         1       NaN       NaN        NaN   NaN        NaN            NaN
# 861         1       NaN         1          1   NaN        NaN            NaN
# 862       NaN       NaN       NaN        NaN   NaN        NaN            NaN
# 863       NaN       NaN         1        NaN   NaN        NaN            NaN
# 864       NaN       NaN         1          1   NaN        NaN            NaN
# 865         1       NaN       NaN          1   NaN        NaN            NaN
#
#      Mail  Txt  800  Other.9  Eastside_youth_council
# 0     NaN  NaN  NaN      NaN                       Y
# 1       1  NaN  NaN   whanau                       Y
# 2       1  NaN  NaN      NaN                       N
# 3     NaN  NaN    1      NaN                       Y
# 4     NaN  NaN    1      NaN                       Y
# 5     NaN  NaN  NaN      NaN                       Y
# 6       1    1  NaN      NaN                       N
# 7       1  NaN    1      NaN                       Y
# 8       1    1  NaN      NaN                       Y
# 9       1    1  NaN      NaN                       Y
# ..    ...  ...  ...      ...                     ...
# 856   NaN  NaN  NaN      NaN                       N
# 857   NaN  NaN  NaN      NaN                       N
# 858     1  NaN  NaN      NaN                     NaN
# 859     1  NaN    1      NaN                       N
# 860   NaN  NaN  NaN      NaN                     NaN
# 861     1    1  NaN      NaN                       N
# 862   NaN  NaN  NaN      NaN                     NaN
# 863     1  NaN  NaN      NaN                       Y
# 864     1  NaN  NaN      NaN                       N
# 865   NaN  NaN  NaN      NaN                       N
#
# [866 rows x 176 columns]>

# %% [markdown]
# ### Local Area

# %%
#Standard_background()
xlabel('Area',fontsize=18)
ylabel('Count',fontsize=18)
title('Number of respondents from each area',fontsize=20)
df.Local_Area.value_counts()[df.Local_Area.value_counts() >10].plot(kind='bar',color='white',alpha=.7,
                                                                    width=.8,hatch='//',fontsize=18,
                                                                    rot=45)

# %% [markdown]
# ### Age data

# %%
#Exclude anyone less than 10
df['Age'] = df.Age.replace([8], np.NaN)
df.Age.value_counts(),df.Age.describe()
# Out:
# (11    130
#  13    111
#  10    109
#  15    106
#  14    103
#  12     92
#  16     70
#  9      54
#  17     41
#  18      4
#  dtype: int64, count    820.000000
#  mean      12.773171
#  std        2.298752
#  min        9.000000
#  25%       11.000000
#  50%       13.000000
#  75%       15.000000
#  max       18.000000
#  Name: Age, dtype: float64)

# %% [markdown]
# ### Gender

# %%
df['Gender_(M/F)'].value_counts()
# Out:
# F    428
# M    420
# dtype: int64

# %%
# %matplotlib inline
figsize(12,10)
f = plt.figure()#facecolor=".9")
ax = f.add_subplot(111)#, axisbg="#F4EAEA")
title('Distribution of  Age',fontsize=20)
ax.set_xlabel('Age',fontsize=16)
ax.set_ylabel('Count',fontsize=16)
n = 19
bins=np.arange(9,n+1,1)
df.Age.hist(bins=bins,rwidth=.9,color='green',align='left',alpha=.4,
            hatch='/',label='label')
ax.set_xticks(bins[:-1])
# Out:
# [<matplotlib.axis.XTick at 0x1526b5f90>,
#  <matplotlib.axis.XTick at 0x1526b5850>,
#  <matplotlib.axis.XTick at 0x151e5ebd0>,
#  <matplotlib.axis.XTick at 0x151e73610>,
#  <matplotlib.axis.XTick at 0x151e73d90>,
#  <matplotlib.axis.XTick at 0x151e67550>,
#  <matplotlib.axis.XTick at 0x151e67cd0>,
#  <matplotlib.axis.XTick at 0x151e4c490>,
#  <matplotlib.axis.XTick at 0x151e4cc10>,
#  <matplotlib.axis.XTick at 0x151e7c3d0>]

# %%
df.Age.mean(),df.Age.median(), df.Age.std()
# Out:
# (12.773170731707317, 13.0, 2.2987520519743132)

# %% [markdown]
# ### Ethnicity

# %%
df.ix[df.NZEuro >= 1,'NZEuro'] = 'NZEuro'
df.ix[df.Maori >= 1,'Maori'] = 'Maori'
df.ix[df.Samoan >= 1,'Samoan'] = 'Samoan'
df.ix[df.Cook_Is >= 1,'Cook_Is'] = 'Cook_Is'
df.ix[df.Tongan  >= 1,'Tongan'] = 'Tongan'
df.ix[df.Niuean  >= 1,'Niuean'] = 'Niuean'
df.ix[df.Chinese  >= 1,'Chinese'] = 'Chinese'
df.ix[df.Indian  >= 1,'Indian'] = 'Indian'

df['Ethnicity'] = df['NZEuro']\
.add(df.Maori, fill_value=' ')\
.add(df.Samoan,fill_value=' ')\
.add(df.Cook_Is,fill_value=' ')\
.add(df.Tongan,fill_value=' ')\
.add(df.Chinese,fill_value=' ')\
.add(df.Indian,fill_value=' ')\

df = df.drop(['NZEuro','Maori','Samoan','Cook_Is','Tongan','Niuean','Chinese','Indian'],axis=1)

df.replace(['NZEuroMaoriSamoan    ','NZEuro  Cook_Is   ','NZEuroMaori     ','NZEuro Samoan    ', ' MaoriSamoan    ',
       ' Maori Cook_Is   ', 'NZEuroMaori Cook_Is   ','NZEuro     Indian',  ' SamoanCook_Is   ','NZEuroMaoriSamoanCook_Is   '],\
           ['Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple'],inplace=True)
df.head()
# Out:
#    ID  Age                 IWI Other Gender_(M/F) Local_Area  Whangamarino  \
# 0  o1    9              Mataua   NaN            F     Owhata           NaN
# 1  o2   10  Te whanau-a-apanui   NaN            F     Owhata           NaN
# 2  o3    9                 NaN   NaN            F     Owhata           NaN
# 3  o4    9                 NaN   NaN            F     Owhata           NaN
# 4  o5   10                 NaN   NaN            M    Ngapuna           NaN
#
#    Rotokawa  RLHS  Owhata  Rotoma  Lynmore  Ruamata  Mokoia  Bus  Rollerblade  \
# 0       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 1       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 2       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 3       NaN   NaN       1     NaN      NaN      NaN     NaN    1          NaN
# 4       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
#
#    Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  Scooter Other.1  Family  \
# 0         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 1         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 2         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
# 3         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
# 4         NaN    1       NaN   NaN        NaN   NaN      NaN     NaN       1
#
#    Education  Friends  My_job/work  Finding_a_job  Social_life_-_fun  \
# 0        NaN      NaN          NaN            NaN                NaN
# 1        NaN      NaN          NaN            NaN                NaN
# 2        NaN      NaN          NaN            NaN                NaN
# 3        NaN      NaN          NaN            NaN                NaN
# 4        NaN      NaN          NaN            NaN                NaN
#
#    Money_making  Interests/hobbies  Sport Other.2  Lonely  Relationships  \
# 0           NaN                NaN    NaN     NaN     NaN            NaN
# 1           NaN                NaN    NaN     NaN     NaN            NaN
# 2           NaN                NaN    NaN     NaN     NaN            NaN
# 3           NaN                NaN    NaN     NaN     NaN            NaN
# 4           NaN                NaN    NaN     NaN     NaN            NaN
#
#    Grades  D&A  Bullying  Lack_of_money  Violence  Finding_job  Identity  \
# 0     NaN  NaN       NaN            NaN       NaN            1       NaN
# 1       1  NaN       NaN            NaN       NaN          NaN       NaN
# 2     NaN  NaN       NaN            NaN       NaN          NaN       NaN
# 3       1  NaN       NaN            NaN         1          NaN       NaN
# 4     NaN  NaN       NaN            NaN       NaN          NaN       NaN
#
#    Culture  Friends.1  Family.1 Other.3  Lonely.1  Relationships.1  Grades.1  \
# 0      NaN        NaN       NaN     NaN       NaN              NaN       NaN
# 1      NaN          1       NaN     NaN       NaN              NaN       NaN
# 2      NaN        NaN       NaN     pet       NaN              NaN       NaN
# 3      NaN        NaN       NaN     NaN       NaN                1       NaN
# 4      NaN        NaN         1     NaN       NaN              NaN       NaN
#
#       ...       School  Shopping  With_friends_  With_family  Nothing  \
# 0     ...       Owhata         1              1            1      NaN
# 1     ...       Owhata         1            NaN            1      NaN
# 2     ...       Owhata         1              1            1      NaN
# 3     ...       Owhata         1              1          NaN      NaN
# 4     ...       Owhata         1              1            1      NaN
#
#    Other.6  Physical.1  Sport.2  Music.1 Creative.1 Comm_fiar.1 Youth_group.1  \
# 0      NaN           1      NaN      NaN          1         NaN             1
# 1      NaN           1        1      NaN        NaN           1           NaN
# 2      NaN         NaN      NaN        1          1         NaN           NaN
# 3      NaN         NaN      NaN        1        NaN         NaN           NaN
# 4      NaN         NaN      NaN      NaN        NaN         NaN           NaN
#
#   Faith_group.1 Student_council.1  Community_interest.1  \
# 0           NaN                 1                   NaN
# 1           NaN               NaN                     1
# 2           NaN                 1                   NaN
# 3           NaN               NaN                   NaN
# 4           NaN               NaN                   NaN
#
#    Environmental_Volunter.1  Volunteering.1  Art.1  Culture.3  School.1  \
# 0                         1               1      1          1         1
# 1                       NaN             NaN    NaN          1         1
# 2                       NaN               1      1        NaN       NaN
# 3                       NaN             NaN    NaN        NaN       NaN
# 4                       NaN             NaN    NaN        NaN       NaN
#
#    Shopping.1  With_friends_.1  With_family.1 Nothing.1  Other.7  \
# 0         NaN              NaN            NaN       NaN      NaN
# 1         NaN              NaN            NaN       NaN      NaN
# 2         NaN              NaN            NaN       NaN      NaN
# 3         NaN              NaN              1       NaN      NaN
# 4         NaN              NaN            NaN       NaN      NaN
#
#    Not_interested  Time  Costs_too_much  Can't_afford  No_friends  \
# 0             NaN   NaN               1             1           1
# 1             NaN   NaN               1           NaN           1
# 2             NaN   NaN               1           NaN         NaN
# 3             NaN   NaN             NaN           NaN         NaN
# 4               1     1             NaN           NaN         NaN
#
#    not_available  Cant_get_there  Shy  Other_responsibility  Parents_say_no  \
# 0            NaN               1    1                   NaN               1
# 1            NaN             NaN  NaN                   NaN             NaN
# 2              1             NaN    1                   NaN               1
# 3              1             NaN  NaN                   NaN             NaN
# 4            NaN             NaN  NaN                   NaN             NaN
#
#    Don't_know_how  Other.8  Internet  Church.1  School.2  Newspaper  WINZ  \
# 0               1      NaN       NaN       NaN         1          1   NaN
# 1             NaN      NaN       NaN       NaN         1          1   NaN
# 2             NaN      NaN       NaN       NaN         1        NaN   NaN
# 3             NaN  no time       NaN       NaN         1        NaN   NaN
# 4             NaN      NaN       NaN       NaN       NaN        NaN   NaN
#
#    Library.1  Youth_group.2  Mail  Txt  800  Other.9 Eastside_youth_council  \
# 0        NaN            NaN   NaN  NaN  NaN      NaN                      Y
# 1          1            NaN     1  NaN  NaN   whanau                      Y
# 2        NaN            NaN     1  NaN  NaN      NaN                      N
# 3        NaN            NaN   NaN  NaN    1      NaN                      Y
# 4        NaN              1   NaN  NaN    1      NaN                      Y
#
#      Ethnicity
# 0   Maori
# 1   Maori
# 2   Maori
# 3   Maori
# 4   Cook_Is
#
# [5 rows x 169 columns]

# %%
Ethnic_dist = df.Ethnicity.value_counts()/df.Ethnicity.count()*100
pd.Series(df.Ethnicity.ravel()).unique()
# Out:
# array([' Maori     ', ' Cook_Is   ', 'NZEuro      ', 'Multiple',
#        ' Samoan    ', nan, ' Chinese ', ' Indian', ' Tongan  '], dtype=object)

# %%
df.Ethnicity.count()
#Ethnic_dist
# Out:
# 803

# %%
def labels(heading='title',x_='xlabel',y_='ylabel',fontsizeaxes=18,fontsizetitle=20):
    xlabel(x_,fontsize=fontsizeaxes)
    ylabel(y_,fontsize=fontsizeaxes)
    title(heading,fontsize=fontsizetitle)
    
    
xlabel('Ethnicity',fontsize=18)
ylabel('Percentage',fontsize=18)
title('Ethnic Distributions',fontsize=20)
Ethnic_dist.plot(kind='bar',table=False,width=0.8, color='blue',alpha=.4,hatch='/',fontsize=18,rot=45)

# %%
labels('Iwi distribution','Iwi','Count')
df.IWI.value_counts()[df.IWI.value_counts() >3].plot(kind='bar',color='blue',alpha=.4,
                                                     width=.8,hatch='..',fontsize=18,rot=45)

# %%
#List of who was left out -- 85 in total
df.IWI.value_counts()[df.IWI.value_counts() <4]
# Out:
# Ngai Tahu                                              2
# Te Whanau a Apanui                                     2
# Ngati Whakuae                                          2
# Ngati Raukawa                                          2
# Ngai Tuhoe                                             2
# Ngati kahunungu                                        1
# Ngapuhi/ Tuhourangi                                    1
# Te Whakatohea                                          1
# Ruatahuna                                              1
# Ngati Kahugunu/ Ngati Porou                            1
#                                                       ..
# Ngati kahungunu                                        1
# Ngati Pikiao/ Ngai Tahu, Ngati Awa, Whanau a Apanui    1
# Ngati Pikiao/Ngati Whakaue Te Arawa                    1
# Te Arawa/ touwharetoa                                  1
# Ngati porou, ngapuhi, tainui                           1
# Te Arawa/ Tuhourangi/ Nga Puhi                         1
# Te whanau-a-apanui                                     1
# Te Arawa, Rongowhakata                                 1
# Nga Te Rangi                                           1
# Ngai Tuhoe, Ngati Pikiao                               1
# dtype: int64

# %% [markdown]
# ### Schools

# %%
schools =df.ix[:,'Whangamarino':'Mokoia'].count()#*866
schools.values
# Out:
# array([ 43,  36, 460,  43,   0,  60,   0, 212])

# %%
N = schools.count()
ind = np.arange(N)  # the x locations for the groups
width = .8       # the width of the bars
f = plt.figure()#facecolor=".9")
ax = f.add_subplot(111)#, axisbg="#F4EAEA")
rects1 = ax.bar(ind, schools.values[0:N], width, color='purple',alpha=.4,hatch='/')

# add some text for labels, title and axes ticks
ax.set_ylabel('Count',fontsize=18)
ax.set_title('School Distribution',fontsize=20)
ax.set_xticks(ind+width/3)
xtickNames = ax.set_xticklabels( schools.keys() )
plt.setp(xtickNames, rotation=45, fontsize=18)
def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom',fontsize=16)

autolabel(rects1)
plt.grid(True)
plt.show()

# %%
table = pd.pivot_table(df, values=['Whangamarino','Rotokawa','RLHS','Ohwata','Rotoma','Lynmore','Ruamata','Mokoia'],
                       index=['Gender_(M/F)','Ethnicity'], aggfunc=np.sum)
table = table.fillna(0).copy()
table
# Out:
#                            Lynmore  Mokoia  RLHS  Rotokawa  Rotoma  Ruamata  \
# Gender_(M/F) Ethnicity
# F             Chinese            0       0     2         0       0        0
#               Cook_Is            0       2     1         0       0        0
#               Indian             2       1     1         0       0        0
#               Maori              4      13    60         4       0        0
#               Samoan             0       0     1         0       0        0
#              Multiple            5      11    39         5       0        0
#              NZEuro             20      60   124         4       0        0
# M             Chinese            0       1     3         0       0        0
#               Cook_Is            0       1     2         0       0        0
#               Indian             2       0     4         0       0        0
#               Maori              1      19    41         5       0        0
#               Samoan             0       0     0         0       0        0
#               Tongan             0       1     1         0       0        0
#              Multiple            3      17    26        11       0        0
#              NZEuro             11      73   126         6       0        0
#
#                            Whangamarino
# Gender_(M/F) Ethnicity
# F             Chinese                 0
#               Cook_Is                 0
#               Indian                  0
#               Maori                  19
#               Samoan                  0
#              Multiple                 2
#              NZEuro                   1
# M             Chinese                 0
#               Cook_Is                 0
#               Indian                  0
#               Maori                  15
#               Samoan                  0
#               Tongan                  0
#              Multiple                 1
#              NZEuro                   4

# %%
table.sum(axis=1)
# Out:
# Gender_(M/F)  Ethnicity
# F              Chinese          2
#                Cook_Is          3
#                Indian           4
#                Maori          100
#                Samoan           1
#               Multiple         62
#               NZEuro          209
# M              Chinese          4
#                Cook_Is          3
#                Indian           6
#                Maori           81
#                Samoan           0
#                Tongan           2
#               Multiple         58
#               NZEuro          220
# dtype: float64

# %% [markdown]
# ### Transport

# %%
#Percentage use of transport
Trans = df.loc[:,'Bus':'Scooter'].count()/len(df.index)*100
Trans.count(), Trans.values[0:10], Trans.keys()
# Out:
# (9, array([ 22.97921478,   0.46189376,   1.9630485 ,  68.2448037 ,
#          41.91685912,  19.28406467,   1.61662818,   0.11547344,   3.926097  ]), Index([        u'Bus', u'Rollerblade',  u'Skateboard',         u'Car',
#            u'Walk/run',        u'Bike',   u'Motorbike',        u'Taxi',
#             u'Scooter'],
#        dtype='object'))

# %%
#This shows the percentage of tranport options used. I've checked that they add the values accurately.
Make_bar(Trans.count(),Trans.values[0:Trans.count()],Trans.keys(),
         'Transport','Percentage (%)',alpha=.4)

# %% [markdown]
# ### Family

# %%
#split this by schools, ONE PER SCHOOL
def Percentage(x):
    percent = np.sum(x)/np.count_nonzero(x)*100
    return np.round(percent,2)

table2 = pd.pivot_table(df, values=['Family','Education','Friends', 'My_job/work','Finding_a_job','Social_life_-_fun',
                                    'Money_making','Interests/hobbies','Sport','Other.2'],
                       index=['School'], aggfunc=Percentage)
table2 = table2.fillna(0).copy()
table2ticks = ['Family','Education','Friends', 'My job/work','Finding a job','Social life-fun',
                                    'Money making','Interests/hobbies','Sport','Other']
table2.plot(kind='bar',fontsize=18,alpha=.5,width=.7,color=['b','g','r','c','m','y','k','w','brown'],
            hatch='..',rot=45)
plt.title('Most important thing to me, by School',fontsize=20)
plt.xlabel('School',fontsize=16)
plt.ylabel('Percentage',fontsize=16)
plt.legend(table2ticks,loc='upper left')
plt.show()

# %%
table2
# Out:
#               Education  Family  Finding_a_job  Friends  Interests/hobbies  \
# School
# Lynmore           20.00   53.33           0.00    16.67               3.33
# Mokoia            14.15   52.36           2.36     6.60               8.96
# Owhata            18.60   69.77           0.00    18.60               6.98
# RLHS              39.13   36.09           6.09    12.17              11.52
# Rotokawa          25.00   77.78           0.00    27.78               5.56
# Whangamarino       6.98   86.05           0.00    13.95               4.65
#
#               Money_making  My_job/work  Social_life_-_fun  Sport
# School
# Lynmore               0.00         1.67              16.67  20.00
# Mokoia                5.66         1.89              13.68  11.79
# Owhata               16.28         2.33               9.30  16.28
# RLHS                  7.17         3.48               9.78  15.87
# Rotokawa             16.67         2.78               2.78  16.67
# Whangamarino          6.98         2.33               4.65  16.28

# %%
#Percentage 
Fam_Total = df.loc[:,'Family':'Other.2'].count()/len(df.index)*100
Fam_Total
F = Make_bar(Fam_Total.count(),Fam_Total.values[0:Fam_Total.count()],table2ticks,
         'Most important thing to me: All Schools', 'Percentage',color='b',
         alpha=.4)

# %%
#Create df for each school
df_Lyn = df[df.Lynmore == 1]
df_Whang = df[df.Whangamarino == 1]
df_Rotokawa = df[df.Rotokawa == 1]
df_lhs = df[df.RLHS == 1]
df_Owha = df[df.Owhata == 1]
df_Rotoma = df[df.Rotoma == 1]
df_Ruamata = df[df.Ruamata == 1]
df_Mokoia = df[df.Mokoia == 1]
df_Mokoia.describe()
# Out:
#               Age  Whangamarino  Rotokawa  RLHS  Owhata  Rotoma  Lynmore  \
# count  206.000000             0         0     0       0       0        0
# mean    11.330097           NaN       NaN   NaN     NaN     NaN      NaN
# std      0.630731           NaN       NaN   NaN     NaN     NaN      NaN
# min     10.000000           NaN       NaN   NaN     NaN     NaN      NaN
# 25%     11.000000           NaN       NaN   NaN     NaN     NaN      NaN
# 50%     11.000000           NaN       NaN   NaN     NaN     NaN      NaN
# 75%     12.000000           NaN       NaN   NaN     NaN     NaN      NaN
# max     14.000000           NaN       NaN   NaN     NaN     NaN      NaN
#
#        Ruamata  Mokoia  Bus  Rollerblade  Skateboard  Car  Walk/run  Bike  \
# count        0     212   19            4           5  160        87    70
# mean       NaN       1    1            1           1    1         1     1
# std        NaN       0    0            0           0    0         0     0
# min        NaN       1    1            1           1    1         1     1
# 25%        NaN       1    1            1           1    1         1     1
# 50%        NaN       1    1            1           1    1         1     1
# 75%        NaN       1    1            1           1    1         1     1
# max        NaN       1    1            1           1    1         1     1
#
#        Motorbike  Taxi  Scooter  Family  Education  Friends  My_job/work  \
# count          4     0       18     111         30       14            4
# mean           1   NaN        1       1          1        1            1
# std            0   NaN        0       0          0        0            0
# min            1   NaN        1       1          1        1            1
# 25%            1   NaN        1       1          1        1            1
# 50%            1   NaN        1       1          1        1            1
# 75%            1   NaN        1       1          1        1            1
# max            1   NaN        1       1          1        1            1
#
#        Finding_a_job  Social_life_-_fun  Money_making  Interests/hobbies  \
# count              5                 29            12                 19
# mean               1                  1             1                  1
# std                0                  0             0                  0
# min                1                  1             1                  1
# 25%                1                  1             1                  1
# 50%                1                  1             1                  1
# 75%                1                  1             1                  1
# max                1                  1             1                  1
#
#        Sport  Lonely  Relationships  Grades  D&A  Bullying  Lack_of_money  \
# count     25      43             25      66   22        64             28
# mean       1       1              1       1    1         1              1
# std        0       0              0       0    0         0              0
# min        1       1              1       1    1         1              1
# 25%        1       1              1       1    1         1              1
# 50%        1       1              1       1    1         1              1
# 75%        1       1              1       1    1         1              1
# max        1       1              1       1    1         1              1
#
#        Violence  Finding_job  Identity  Culture  Friends.1  Family.1  \
# count        41           11        12        7         35        68
# mean          1            1         1        1          1         1
# std           0            0         0        0          0         0
# min           1            1         1        1          1         1
# 25%           1            1         1        1          1         1
# 50%           1            1         1        1          1         1
# 75%           1            1         1        1          1         1
# max           1            1         1        1          1         1
#
#        Lonely.1  Relationships.1  Grades.1  D&A.1  Bullying.1  \
# count        49               27        35     91         112
# mean          1                1         1      1           1
# std           0                0         0      0           0
# min           1                1         1      1           1
# 25%           1                1         1      1           1
# 50%           1                1         1      1           1
# 75%           1                1         1      1           1
# max           1                1         1      1           1
#
#        Lack_of_money.1  Violence.1  Finding_job.1  Identity.1  Culture.1  \
# count               52         110             26          15         13
# mean                 1           1              1           1          1
# std                  0           0              0           0          0
# min                  1           1              1           1          1
# 25%                  1           1              1           1          1
# 50%                  1           1              1           1          1
# 75%                  1           1              1           1          1
# max                  1           1              1           1          1
#
#        Friends.2 ...   Comm_fiar  Youth_group  Faith_group  Student_council  \
# count         31 ...          26            9           16               25
# mean           1 ...           1            1            1                1
# std            0 ...           0            0            0                0
# min            1 ...           1            1            1                1
# 25%            1 ...           1            1            1                1
# 50%            1 ...           1            1            1                1
# 75%            1 ...           1            1            1                1
# max            1 ...           1            1            1                1
#
#        Community_interest  Environmental_Volunter  Volunteering  Art  \
# count                   9                      26            22   53
# mean                    1                       1             1    1
# std                     0                       0             0    0
# min                     1                       1             1    1
# 25%                     1                       1             1    1
# 50%                     1                       1             1    1
# 75%                     1                       1             1    1
# max                     1                       1             1    1
#
#        Culture.2    Shopping  With_friends_  With_family  Physical.1  Sport.2  \
# count         18  117.000000     164.000000          160          14       39
# mean           1    1.017094       1.012195            1           1        1
# std            0    0.184900       0.156174            0           0        0
# min            1    1.000000       1.000000            1           1        1
# 25%            1    1.000000       1.000000            1           1        1
# 50%            1    1.000000       1.000000            1           1        1
# 75%            1    1.000000       1.000000            1           1        1
# max            1    3.000000       3.000000            1           1        1
#
#        Music.1  Creative.1  Comm_fiar.1  Youth_group.1  Faith_group.1  \
# count       49          44           25             22              9
# mean         1           1            1              1              1
# std          0           0            0              0              0
# min          1           1            1              1              1
# 25%          1           1            1              1              1
# 50%          1           1            1              1              1
# 75%          1           1            1              1              1
# max          1           1            1              1              1
#
#        Student_council.1  Community_interest.1  Environmental_Volunter.1  \
# count                 45                    10                        29
# mean                   1                     1                         1
# std                    0                     0                         0
# min                    1                     1                         1
# 25%                    1                     1                         1
# 50%                    1                     1                         1
# 75%                    1                     1                         1
# max                    1                     1                         1
#
#        Volunteering.1  Art.1  Culture.3  School.1  Shopping.1  \
# count              35     66         27        20          20
# mean                1      1          1         1           1
# std                 0      0          0         0           0
# min                 1      1          1         1           1
# 25%                 1      1          1         1           1
# 50%                 1      1          1         1           1
# 75%                 1      1          1         1           1
# max                 1      1          1         1           1
#
#        With_friends_.1  With_family.1  Not_interested  Time  Costs_too_much  \
# count               17             12              63    51              53
# mean                 1              1               1     1               1
# std                  0              0               0     0               0
# min                  1              1               1     1               1
# 25%                  1              1               1     1               1
# 50%                  1              1               1     1               1
# 75%                  1              1               1     1               1
# max                  1              1               1     1               1
#
#        Can't_afford  No_friends  not_available  Cant_get_there  Shy  \
# count     35.000000          46             33              30   48
# mean       1.057143           1              1               1    1
# std        0.338062           0              0               0    0
# min        1.000000           1              1               1    1
# 25%        1.000000           1              1               1    1
# 50%        1.000000           1              1               1    1
# 75%        1.000000           1              1               1    1
# max        3.000000           1              1               1    1
#
#        Other_responsibility  Parents_say_no  Don't_know_how  Internet  \
# count                    66              29              48       135
# mean                      1               1               1         1
# std                       0               0               0         0
# min                       1               1               1         1
# 25%                       1               1               1         1
# 50%                       1               1               1         1
# 75%                       1               1               1         1
# max                       1               1               1         1
#
#        Church.1  School.2  Newspaper  WINZ  Library.1  Youth_group.2  Mail  \
# count        10       148  70.000000     5         25              6   102
# mean          1         1   1.142857     1          1              1     1
# std           0         0   1.195229     0          0              0     0
# min           1         1   1.000000     1          1              1     1
# 25%           1         1   1.000000     1          1              1     1
# 50%           1         1   1.000000     1          1              1     1
# 75%           1         1   1.000000     1          1              1     1
# max           1         1  11.000000     1          1              1     1
#
#        Txt  800
# count   61   13
# mean     1    1
# std      0    0
# min      1    1
# 25%      1    1
# 50%      1    1
# 75%      1    1
# max      1    1
#
# [8 rows x 143 columns]

# %%
#Percentage 
Fam = df_lhs.loc[:,'Family':'Other.2'].count()/len(df_lhs.index)*100
Fam
# Out:
# Family               36.086957
# Education            39.130435
# Friends              12.173913
# My_job/work           3.478261
# Finding_a_job         6.086957
# Social_life_-_fun     9.782609
# Money_making          7.173913
# Interests/hobbies    11.521739
# Sport                15.869565
# Other.2               4.565217
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],table2ticks,
         'Most important thing to me: RLHS', 'Percentage',color='b',
         alpha=.4)

# %%
Fam = df_Lyn.loc[:,'Family':'Other.2'].count()/len(df_Lyn.index)*100
Fam
# Out:
# Family               53.333333
# Education            20.000000
# Friends              16.666667
# My_job/work           1.666667
# Finding_a_job         0.000000
# Social_life_-_fun    16.666667
# Money_making          0.000000
# Interests/hobbies     3.333333
# Sport                20.000000
# Other.2               3.333333
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],table2ticks,
         'Most important thing to me: Lynmore Primary', 'Percentage',color='g',alpha=.4)

# %%
Fam = df_Mokoia.loc[:,'Family':'Other.2'].count()/len(df_Mokoia.index)*100
Fam
# Out:
# Family               52.358491
# Education            14.150943
# Friends               6.603774
# My_job/work           1.886792
# Finding_a_job         2.358491
# Social_life_-_fun    13.679245
# Money_making          5.660377
# Interests/hobbies     8.962264
# Sport                11.792453
# Other.2               3.773585
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],table2ticks,
         'Most important thing to me: Mokoia Intermediate', 'Percentage',color='r',alpha=.8)

# %%
Fam = df_Owha.loc[:,'Family':'Other.2'].count()/len(df_Owha.index)*100
Fam
# Out:
# Family               69.767442
# Education            18.604651
# Friends              18.604651
# My_job/work           2.325581
# Finding_a_job         0.000000
# Social_life_-_fun     9.302326
# Money_making         16.279070
# Interests/hobbies     6.976744
# Sport                16.279070
# Other.2               0.000000
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],table2ticks,
         'Most important thing to me: Owhata Primary', 'Percentage',color='y',alpha=.8)

# %%
Fam = df_Rotokawa.loc[:,'Family':'Other.2'].count()/len(df_Rotokawa.index)*100
Fam
# Out:
# Family               77.777778
# Education            25.000000
# Friends              27.777778
# My_job/work           2.777778
# Finding_a_job         0.000000
# Social_life_-_fun     2.777778
# Money_making         16.666667
# Interests/hobbies     5.555556
# Sport                16.666667
# Other.2               0.000000
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],table2ticks,
         'Most important thing to me: Rotokawa Primary', 'Percentage',color='cyan',alpha=.8)

# %%
Fam = df_Whang.loc[:,'Family':'Other.2'].count()/len(df_Whang.index)*100
Fam
# Out:
# Family               86.046512
# Education             6.976744
# Friends              13.953488
# My_job/work           2.325581
# Finding_a_job         0.000000
# Social_life_-_fun     4.651163
# Money_making          6.976744
# Interests/hobbies     4.651163
# Sport                16.279070
# Other.2               4.651163
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],table2ticks,
         'Most important thing to me: Lynmore Primary', 'Percentage',color='magenta',alpha=.8)

# %% [markdown]
# ### Concerns

# %% [markdown]
# ##### Overall concerns

# %%
print 'The personal concerns raised were as a percentage of all participants:'
Concerns8 = df.loc[:,'Lonely':'Other.3'].count()/len(df.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df.loc[:,'Lonely.1':'Other.4'].count()/len(df.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of all participants:
# Lonely           16.628176
# Relationships    10.046189
# Grades           41.108545
# D&A               8.083141
# Bullying         20.785219
# Lack_of_money    11.662818
# Violence         13.856813
# Finding_job       7.852194
# Identity          3.464203
# Culture           2.655889
# Friends.1        14.203233
# Family.1         21.709007
# Other.3           5.542725
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1           12.355658
# Relationships.1    10.046189
# Grades.1           15.127021
# D&A.1              43.418014
# Bullying.1         39.260970
# Lack_of_money.1    17.782910
# Violence.1         38.337182
# Finding_job.1      10.392610
# Identity.1          5.196305
# Culture.1           5.196305
# Friends.2          11.316397
# Family.2           15.935335
# Other.4             3.926097
# dtype: float64

# %%
Concerns_list = ['Lonely','Relationships','Grades','D & A','Bullying','Lack of $',
                 'Violence','Finding a job','Identity','Culture','Friends','Family','Other']
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: Overall','Percentage',color='magenta')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: Overall','Percentage',color='cyan')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_list,
         'Difference between what matters to me versus others','Percentage change',color='lime')

# %% [markdown]
# The above plot shows the differential between concerns that are personal to the youth (what matters to them) compared to how that person rated what issues youth in Eastside face generally. So, for example, $5$% rated drugs and alcohol as a personal issue. However, this was rated as a general issue by $54$%. This $-48$% difference indicates that more than half of youth perceive drugs and alcohol as a major issue for Eastside Youth, even though only $5$% rated it as personally impacting on them. Similarly, bullying and violence were also rated as more relevant than personally experienced. This probably indicates general concerns, perhaps some expectation and stereotyping.
#
# Conversely, school grades were rated as much more personally than generally concerning. So one might expect that this indicates an issue with personal self efficacy wherein youth feel grades, or the lack thereof, to be more applicable to themselves than to their peers. In any event, grades present a general concern for youth. The last differential of note was the issue of loneliness, with $14$% of youth rating themselves as feeling lonely, but with a perception that this was a slightly lesser issue for others. What is interesting is that the differential wasn't larger, suggesting that youth are aware of others being lonely. So the question arising is that where this impression is relatively accurate, that still the issue of loneliness persists. Being lonely and being aware of other lonely people doesn't appear to assist in changing anything.

# %%
#Whangamarino
print 'The personal concerns raised were as a percentage of Whangamarino participants:'
Concerns8 = df_Whang.loc[:,'Lonely':'Other.3'].count()/len(df_Whang.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_Whang.loc[:,'Lonely.1':'Other.4'].count()/len(df_Whang.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of Whangamarino participants:
# Lonely            9.302326
# Relationships     6.976744
# Grades            9.302326
# D&A              11.627907
# Bullying         37.209302
# Lack_of_money     2.325581
# Violence         23.255814
# Finding_job       2.325581
# Identity          0.000000
# Culture           2.325581
# Friends.1         9.302326
# Family.1         39.534884
# Other.3           0.000000
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1            9.302326
# Relationships.1     9.302326
# Grades.1            2.325581
# D&A.1              20.930233
# Bullying.1         41.860465
# Lack_of_money.1     4.651163
# Violence.1         30.232558
# Finding_job.1       0.000000
# Identity.1          4.651163
# Culture.1           4.651163
# Friends.2          16.279070
# Family.2           32.558140
# Other.4             9.302326
# dtype: float64

# %%
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: Whangamarino','Percentage',color='sage')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: Whangamarino','Percentage',color='olive')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_list,
         'Difference between what matters to me versus others','Percentage change',color='darkolivegreen')

# %%
#Lynmore
print 'The personal concerns raised were as a percentage of Lynmore participants:'
Concerns8 = df_Lyn.loc[:,'Lonely':'Other.3'].count()/len(df_Lyn.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_Lyn.loc[:,'Lonely.1':'Other.4'].count()/len(df_Lyn.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of Lynmore participants:
# Lonely           16.666667
# Relationships     5.000000
# Grades           30.000000
# D&A              13.333333
# Bullying         26.666667
# Lack_of_money     8.333333
# Violence         23.333333
# Finding_job       3.333333
# Identity          1.666667
# Culture           5.000000
# Friends.1        13.333333
# Family.1         26.666667
# Other.3           5.000000
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1           21.666667
# Relationships.1    10.000000
# Grades.1           25.000000
# D&A.1              18.333333
# Bullying.1         38.333333
# Lack_of_money.1    13.333333
# Violence.1         28.333333
# Finding_job.1      15.000000
# Identity.1          1.666667
# Culture.1           5.000000
# Friends.2          23.333333
# Family.2           18.333333
# Other.4             3.333333
# dtype: float64

# %%
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: Lynmore','Percentage',color='forestgreen')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: Lynmore','Percentage',color='green')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_diff.keys(),
         '$Lynmore: \ Personal - General \ Concerns$','Percentage change')

# %%
#Mokoia
print 'The personal concerns raised were as a percentage of Mokoia participants:'
Concerns8 = df_Mokoia.loc[:,'Lonely':'Other.3'].count()/len(df_Mokoia.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_Mokoia.loc[:,'Lonely.1':'Other.4'].count()/len(df_Mokoia.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of Mokoia participants:
# Lonely           20.283019
# Relationships    11.792453
# Grades           31.132075
# D&A              10.377358
# Bullying         30.188679
# Lack_of_money    13.207547
# Violence         19.339623
# Finding_job       5.188679
# Identity          5.660377
# Culture           3.301887
# Friends.1        16.509434
# Family.1         32.075472
# Other.3           8.018868
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1           23.113208
# Relationships.1    12.735849
# Grades.1           16.509434
# D&A.1              42.924528
# Bullying.1         52.830189
# Lack_of_money.1    24.528302
# Violence.1         51.886792
# Finding_job.1      12.264151
# Identity.1          7.075472
# Culture.1           6.132075
# Friends.2          14.622642
# Family.2           17.924528
# Other.4             3.773585
# dtype: float64

# %%
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: Mokoia','Percentage',color='red')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: Mokoia','Percentage',color='darkred')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_diff.keys(),
         '$Mokoia: \ Personal - General \ Concerns$','Percentage change')

# %%
print 'The personal concerns raised were as a percentage of Owhata participants:'
Concerns8 = df_Owha.loc[:,'Lonely':'Other.3'].count()/len(df_Owha.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_Owha.loc[:,'Lonely.1':'Other.4'].count()/len(df_Owha.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of Owhata participants:
# Lonely           20.930233
# Relationships     9.302326
# Grades           16.279070
# D&A               6.976744
# Bullying         18.604651
# Lack_of_money     4.651163
# Violence         18.604651
# Finding_job      11.627907
# Identity          2.325581
# Culture           2.325581
# Friends.1        13.953488
# Family.1         25.581395
# Other.3          11.627907
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1           11.627907
# Relationships.1    16.279070
# Grades.1            6.976744
# D&A.1              25.581395
# Bullying.1         27.906977
# Lack_of_money.1    23.255814
# Violence.1         37.209302
# Finding_job.1      13.953488
# Identity.1          2.325581
# Culture.1           6.976744
# Friends.2           4.651163
# Family.2           18.604651
# Other.4             0.000000
# dtype: float64

# %%
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: Owhata','Percentage',color='yellow')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: Owhata','Percentage',color='yellowgreen')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_diff.keys(),
         '$Owhata: \ Personal - General \ Concerns$','Percentage change')

# %%
print 'The personal concerns raised were as a percentage of Rotokawa participants:'
Concerns8 = df_Rotokawa.loc[:,'Lonely':'Other.3'].count()/len(df_Rotokawa.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_Rotokawa.loc[:,'Lonely.1':'Other.4'].count()/len(df_Rotokawa.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of Rotokawa participants:
# Lonely           44.444444
# Relationships     2.777778
# Grades           25.000000
# D&A              22.222222
# Bullying         25.000000
# Lack_of_money    16.666667
# Violence         19.444444
# Finding_job       8.333333
# Identity          8.333333
# Culture           8.333333
# Friends.1        27.777778
# Family.1         27.777778
# Other.3           5.555556
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1           11.111111
# Relationships.1     5.555556
# Grades.1           16.666667
# D&A.1              50.000000
# Bullying.1         36.111111
# Lack_of_money.1    13.888889
# Violence.1         36.111111
# Finding_job.1       5.555556
# Identity.1          8.333333
# Culture.1           8.333333
# Friends.2          25.000000
# Family.2           33.333333
# Other.4             0.000000
# dtype: float64

# %%
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: Rotokawa','Percentage',color='brown')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: Rotokawa','Percentage',color='sandybrown')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_diff.keys(),
         '$Rotokawa: \ Personal - General \ Concerns$','Percentage change')

# %%
print 'The personal concerns raised were as a percentage of RLHS participants:'
Concerns8 = df_lhs.loc[:,'Lonely':'Other.3'].count()/len(df_lhs.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_lhs.loc[:,'Lonely.1':'Other.4'].count()/len(df_lhs.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of RLHS participants:
# Lonely           13.478261
# Relationships    11.086957
# Grades           54.782609
# D&A               5.217391
# Bullying         14.565217
# Lack_of_money    12.826087
# Violence          8.695652
# Finding_job      10.000000
# Identity          2.826087
# Culture           1.739130
# Friends.1        13.043478
# Family.1         14.347826
# Other.3           4.565217
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1            6.956522
# Relationships.1     8.913043
# Grades.1           15.434783
# D&A.1              51.304348
# Bullying.1         35.217391
# Lack_of_money.1    16.739130
# Violence.1         35.434783
# Finding_job.1      10.217391
# Identity.1          5.000000
# Culture.1           4.565217
# Friends.2           7.608696
# Family.2           11.956522
# Other.4             4.347826
# dtype: float64

# %%
Make_bar(Concerns8.count(),Concerns8.values[0:Concerns8.count()],Concerns_list,
         'The main thing that causes me to worry: RLHS','Percentage',color='darkblue')

# %%
Make_bar(Concerns9.count(),Concerns9.values[0:Concerns9.count()],Concerns_list,
         'Biggest issues facing Eastside Youth?: RLHS','Percentage',color='blue')

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_diff.keys(),
         '$RLHS: \ Personal - General \ Concerns$','Percentage change')

# %% [markdown]
# ### Activities

# %%
print 'The activities undertaken as a percentage of 866 participants:'
activities =  df.loc[:,'Volleyball':'Other.5'].count()/len(df.index)*100
print activities
# Out:
# The activities undertaken as a percentage of 866 participants:
# Volleyball    25.057737
# Ki_orahi      11.200924
# T_Ball        21.478060
# Ripper        23.210162
# B_Ball        25.173210
# Zumba         18.591224
# Netball       18.475751
# Dance_off     15.819861
# Bootcamp      20.669746
# Other.5       17.321016
# dtype: float64

# %%
Standard_background()
act_ticks=['Volleyball','Ki Orahi','T-Ball','Ripper','Basketball','Zumba','Netball',
           'Dance-off','Bootcamp','Other']
ax =activities.plot(kind='bar',color='gray',alpha=.4,hatch='//')
ax.set_xticklabels(('Volleyball','Ki Orahi','T-Ball','Ripper','Basketball','Zumba',
           'Netball','Dance-off','Bootcamp','Other'),rotation=45,fontsize=14)
ax.set_xlabel('Activity',fontsize=16)
ax.set_ylabel('Percentage',fontsize=16)
ax.set_title('Activities I would like to be run by Freeparking Programme',fontsize=18)

# %% [markdown]
# ### Days of the week

# %%
print 'The after school care as a percentage of 866 participants:'
print df.loc[:,'Monday':'Sunday'].count()/len(df.index)*100
# Out:
# The after school care as a percentage of 866 participants:
# Monday       27.829099
# Tuesday      23.787529
# Wednesday    24.826790
# Thursday     25.404157
# Friday       24.249423
# Saturday     24.711316
# Sunday       23.903002
# dtype: float64

# %% [markdown]
# ### Places visited

# %%
print 'The places visited as a  frequency rating (0-6) of 866 participants:'
places =  df.loc[:,'Library':'Stadium'].mean().round(2)
places
# Out:
# The places visited as a  frequency rating (0-6) of 866 participants:
# Library              3.80
# Aquatic              3.54
# City_Focus           3.59
# Redwoods             2.94
# Parks                2.99
# Lakes                2.57
# Night_market         3.95
# Museuem              4.10
# Youth_centre         4.86
# Youth_health         5.00
# Gym                  4.24
# Church               4.72
# Marae                4.47
# Events_centre        4.24
# Sports_drom          4.52
# Convention_centre    4.28
# Stadium              4.52
# dtype: float64

# %% [markdown]
# ### Parks?

# %%
print 'The parks visited as a mean frequency rating of 866 participants:'
print df.loc[:,'W_Heights':'Puketawhero'].mean().round(0)
YS_Y = (df.loc[:,'Youth_space?'] == 'Y').sum()
YS_N = (df.loc[:,'Youth_space?'] == 'N').sum()
print 'The number who wanted to have a youth space was',YS_Y,'where', YS_N,'said "No"'
print 'So {:.2f}% for "Y" and {:.2f}% said "N".'.format(YS_Y.sum()/760.*100,YS_N.sum()/760.*100)
# Out:
# The parks visited as a mean frequency rating of 866 participants:
# W_Heights       5
# Fordlands       5
# Central_City    5
# Ngong           5
# Puketawhero     5
# dtype: float64
# The number who wanted to have a youth space was 539 where 220 said "No"
# So 70.92% for "Y" and 28.95% said "N".

# %%
#How does this vary over school?
table_youth_space = pd.pivot_table(df, values=['Whangamarino','Rotokawa','RLHS','Ohwata','Lynmore','Mokoia'],
                       columns=['Youth_space?'], aggfunc=np.sum)
table_youth_space = table_youth_space.fillna(0).copy()
#table_youth_space['Ratio']=table_youth_space['Y']/table_youth_space['N']
table_youth_space
# Out:
# Youth_space?    N    Y
# Lynmore        16   42
# Mokoia         49  161
# RLHS          141  258
# Rotokawa        9   22
# Whangamarino    4   15

# %%
table_youth_space.plot(kind='bar',width=.9,color=['g','y'],alpha=.4,rot=45,fontsize=14)
plt.title('$Youth \ Space$',fontsize=20)
plt.legend(['Yes','No'])
plt.xlabel('School',fontsize=16)
plt.ylabel('Count of responses',fontsize=16)

# %%
df.loc[:,'Youth_space?':'Rotaz?'].count()
# Out:
# Youth_space?    759
# Rotaz?          738
# dtype: int64

# %% [markdown]
# Youth space desire was generally viewed as a need by around $71$% but not as need by $29$% of youth. The ratio of those saying "Yes" to "No" to the questions was around $3:1$. However, for the $41$ youth in Owhata School responses, all bar one person indicated a need for a youth space.

# %% [markdown]
# ### Rotaz Card

# %%
Rotaz_Y = (df.loc[:,'Rotaz?'] == 'Y').sum()
Rotaz_N = (df.loc[:,'Rotaz?'] == 'N').sum()
print 'The number who knew about the Rotaz care was',Rotaz_Y,'where', Rotaz_N,'said "No"'
print 'So {:.2f}% for "Y" and {:.2f}% said "N".'.format(Rotaz_Y.sum()/738.*100,Rotaz_N.sum()/738.*100)
# Out:
# The number who knew about the Rotaz care was 293 where 444 said "No"
# So 39.70% for "Y" and 60.16% said "N".

# %% [markdown]
# ### Interests

# %%
print 'Current interests as a percentage of 866 participants:'
interests_A = df.loc[:,'Physical':'Other.6'].count()/len(df.index)*100
interests_A.name = ('Current Interests')
print interests_A
# Out:
# Current interests as a percentage of 866 participants:
# Physical                  45.150115
# Sport.1                   52.078522
# Music                     23.325635
# Creative                  14.318707
# Comm_fiar                 10.854503
# Youth_group                8.545035
# Faith_group                9.006928
# Student_council            6.351039
# Community_interest         2.540416
# Environmental_Volunter     6.812933
# Volunteering              11.085450
# Art                       22.748268
# Culture.2                  7.736721
# School                    98.614319
# Shopping                  42.263279
# With_friends_             68.475751
# With_family               59.930716
# Nothing                    8.429561
# Other.6                   10.508083
# Name: Current Interests, dtype: float64

# %%
print 'Interests they would like more of, as a percentage of 866 participants:'
interests_B = df.loc[:,'Physical.1':'Other.7'].count()/len(df.index)*100
interests_B.name =('Desired interests')
print interests_B
# Out:
# Interests they would like more of, as a percentage of 866 participants:
# Physical.1                  10.508083
# Sport.2                     16.743649
# Music.1                     17.321016
# Creative.1                  14.780600
# Comm_fiar.1                 10.508083
# Youth_group.1               11.547344
# Faith_group.1                4.157044
# Student_council.1           13.625866
# Community_interest.1         5.427252
# Environmental_Volunter.1    10.739030
# Volunteering.1              14.549654
# Art.1                       19.053118
# Culture.3                    8.314088
# School.1                     8.314088
# Shopping.1                   8.775982
# With_friends_.1              9.237875
# With_family.1                6.235566
# Nothing.1                   17.898383
# Other.7                      4.849885
# Name: Desired interests, dtype: float64

# %%
fig, axs = plt.subplots(1,2)
plt.suptitle('Youth interests',fontsize=20)
int_labels = ['Physical','Sport','Music','Creative','Community Fair','Youth Group',
                    'Faith Group','Student Council','Community Interest',
                    'Environmental Volunteer','Volunteering','Art','Culture','School',
                    'Shopping','Be with friends','Be with family','Nothing','Other']
interests_A.plot(kind='barh',legend=True, alpha=.4,ax=axs[0],width=.8)
interests_B.plot(kind='barh',color='g',legend=True, alpha=.4,ax=axs[1],sharey=True,sharex=True,width=.8)
# Set the tick labels for each axes instance.
axs[0].set_yticklabels(int_labels,fontsize=14)
axs[1].set_yticklabels(int_labels)
axs[0].set_xlim(0,100)
axs[1].set_xlim(0,100)
axs[0].set_xlabel('Percentage',fontsize=14)
axs[1].set_xlabel('Percentage',fontsize=14)

# %%
interests_diff = interests_A.sub(interests_B.values)
Standard_background()
#interests_diff['positive']=interests_diff.values>0
co =['g' if x>0 else 'y' for x in interests_diff.values]
intere = interests_diff.plot(kind='barh',alpha=.4,fontsize=14,width=.8,hatch='..',color=co)
intere.set_title('Change in interests from current to desired',fontsize=20)
intere.set_yticklabels(int_labels)
intere.set_xlabel('Percentage change',fontsize=16)
#intere.annotate('Note',(.2,.5),(.5,.2),xycoords="axes fraction" ,textcoords="axes fraction",
#                 arrowprops=dict(arrowstyle="fancy",
#                                 fc="0.6", ec="none",
#                                 connectionstyle="arc3,rad=0.3"))

# %% [markdown]
# The above ratings indicate that in some areas (Volunteering to Student Council), a higher percentage of youth want more of these things than the percentage currently stating that they engage in these activities. Interpreting these data is, however, problematic in terms of meaning. A followup might be a focus group with high school youth to ask them what they think is going on with this result.
#
# Also, from the quick examination below,  proportion of respondents did not follow the question links. So the question asked to indicate what you would like to be involved in that you **are not presently**. In the samples below, $10-15$% were already involved and indicated that they would like to be involved at the same time.

# %%
df.Comm_interest_change = df.Community_interest.fillna(0) - df['Community_interest.1'].fillna(0)
df.Comm_interest_change.value_counts()
# Out:
#  0    801
# -1     45
#  1     20
# dtype: int64

# %%
df['Sport.1']=df['Sport.1'].fillna(0).copy()
df['Sport.2']=df['Sport.2'].fillna(0).copy()
sport_pivot = pd.pivot_table(df, values='ID',columns='Sport.1',index='Sport.2',aggfunc=count_nonzero)
sport_pivot
# Out:
# Sport.1    0    1
# Sport.2
# 0        305  416
# 1        110   35

# %%
df['School.1']=df['School.1'].fillna(0).copy()
df['School.2']=df['School.2'].fillna(0).copy()
school_pivot = pd.pivot_table(df, values='ID',columns='School.1',index='School.2',
                             aggfunc=count_nonzero)
school_pivot
# Out:
# School.1    0   1
# School.2
# 0         303   9
# 1         491  63

# %%
df['Volunteering']=df['Volunteering'].fillna(0).copy()
df['Volunteering.1']=df['Volunteering.1'].fillna(0).copy()
vol_pivot = pd.pivot_table(df, values='ID',columns='Volunteering',index='Volunteering.1',
                             aggfunc=count_nonzero)
vol_pivot
# Out:
# Volunteering      0   1
# Volunteering.1
# 0               654  86
# 1               116  10

# %%
print 'Reasons as a percentage of 866 participants:'
print df.loc[:,'Not_interested':'Other.8'].count()/len(df.index)*100
print 'Reasons as a percentage of RLHS participants:'
print df_lhs.loc[:,'Not_interested':'Other.8'].count()/len(df_lhs.index)*100
# Out:
# Reasons as a percentage of 866 participants:
# Not_interested          27.598152
# Time                    22.863741
# Costs_too_much          16.859122
# Can't_afford            12.817552
# No_friends              21.247113
# not_available           13.856813
# Cant_get_there          14.780600
# Shy                     18.244804
# Other_responsibility    29.099307
# Parents_say_no          10.277136
# Don't_know_how          15.242494
# Other.8                  9.237875
# dtype: float64
# Reasons as a percentage of RLHS participants:
# Not_interested          32.173913
# Time                    24.565217
# Costs_too_much          12.391304
# Can't_afford            10.217391
# No_friends              21.304348
# not_available           12.391304
# Cant_get_there          15.869565
# Shy                     16.739130
# Other_responsibility    30.652174
# Parents_say_no           5.000000
# Don't_know_how          10.217391
# Other.8                 10.000000
# dtype: float64

# %% [markdown]
# Disinterest and time account for nearly half of the reason youth don't participate in activites. This matches the above impression of mismatching interest to activity. Cost is relevant for $29$% overall and for $22$% of high school youth. What changes for that $7$%? Are they youth with paid work?
#
# Lack of friends accounts for a $\frac{1}{5}$ of reasons youth cannot participate in desired activites.
#
# Shyness also accounts for just under $\frac{1}{5}$ of reasons youth cannot participate in activities they desire. It would be interesting to examine the extent to which this shyness really prevents participation, given a much lower epidemiology of clincial social phobia. Strategies to counteract shyness, a Positive Psychology approach, would probably also be worth considering, and of course would relate directly to making friends and reducing loneliness. It might also be a project linked to increasing self-efficacy given the $10-15$% of youth indicating that they don't know how to engage with desired activities.
#
# Is it worth examining for a difference between Owhata and the rest?

# %%
reasons =list(df.loc[:,'Not_interested':'Other.8'].keys())
reasons
# Out:
# [u'Not_interested',
#  u'Time',
#  u'Costs_too_much',
#  u"Can't_afford",
#  u'No_friends',
#  u'not_available',
#  u'Cant_get_there',
#  u'Shy',
#  u'Other_responsibility',
#  u'Parents_say_no',
#  u"Don't_know_how",
#  u'Other.8']

# %%
table3 = pd.pivot_table(df,values=reasons,index=['School'],aggfunc=Percentage)
                        
table3 = table3.fillna(0).copy()
table3
# Out:
#               Can't_afford  Cant_get_there  Costs_too_much  Don't_know_how  \
# School
# Lynmore              16.67           13.33           26.67           30.00
# Mokoia               17.45           14.15           25.00           22.64
# Owhata               20.93           20.93           30.23           30.23
# RLHS                 10.22           15.87           12.39           10.22
# Rotokawa             22.22           13.89           19.44            8.33
# Whangamarino          4.65            6.98            0.00            6.98
#
#               No_friends  Not_interested  Other_responsibility  \
# School
# Lynmore            21.67           23.33                 36.67
# Mokoia             21.70           29.72                 31.13
# Owhata             37.21           11.63                 30.23
# RLHS               21.30           32.17                 30.65
# Rotokawa           22.22           16.67                 19.44
# Whangamarino        6.98            6.98                  6.98
#
#               Parents_say_no    Shy   Time  not_available
# School
# Lynmore                20.00  20.00  28.33          13.33
# Mokoia                 13.68  22.64  24.06          15.57
# Owhata                 39.53  30.23  16.28          27.91
# RLHS                    5.00  16.74  24.57          12.39
# Rotokawa               22.22  16.67  22.22          19.44
# Whangamarino            0.00   4.65   4.65           6.98

# %%
table3ticks = ["Can't afford","Can't get there","Costs too much",
               "Don't know how","No friends","Not interested",
               "Other responsibility","Parents say 'No'",
               "Shy","No time","Not available"]

table3.plot(kind='bar',fontsize=18,alpha=.5,width=.7,
            color=['b','g','r','c','m','y','k','w','brown','olive','yellowgreen'],
            hatch='..',rot=45)
plt.title('Barriers to interests, by School',fontsize=20)
plt.xlabel('School',fontsize=16)
plt.ylabel('Percentage',fontsize=16)
plt.legend(table3ticks,loc='upper right')
plt.show()

# %% [markdown]
# ### Information Sources

# %%
print 'Found out about it from... as a percentage of 866 participants:'
info_source = df.loc[:,'Internet':'Other.9'].count()/len(df.index)*100
Standard_background()
info= info_source.plot(kind='bar',alpha=.4,width=.8,color='gray',hatch='/')
info.set_title('Best information sources',fontsize=20)
info.set_xlabel('Information source',fontsize=14)
info.set_ylabel('Percentage',fontsize=14)
info.set_xticklabels(['Internet','Church','School','Newspaper','WINZ','Library','Youth Group',
            'Mail','Text message','0800 number','Other'],fontsize=14,rotation=60)
# Out:
# Found out about it from... as a percentage of 866 participants:
# [<matplotlib.text.Text at 0x14a474e10>,
#  <matplotlib.text.Text at 0x14a477e10>,
#  <matplotlib.text.Text at 0x14a427990>,
#  <matplotlib.text.Text at 0x14a43f0d0>,
#  <matplotlib.text.Text at 0x14a43f810>,
#  <matplotlib.text.Text at 0x14a43ff50>,
#  <matplotlib.text.Text at 0x14a45d6d0>,
#  <matplotlib.text.Text at 0x14a45de10>,
#  <matplotlib.text.Text at 0x14a422590>,
#  <matplotlib.text.Text at 0x14a422cd0>,
#  <matplotlib.text.Text at 0x14a42a450>]

# %% [markdown]
# ### Interest in Eastside Community Council

# %%
EYC_Y = (df.loc[:,'Eastside_youth_council'] == 'Y').sum()
EYC_N = (df.loc[:,'Eastside_youth_council'] == 'N').sum()
EYC_tot = float(EYC_Y + EYC_N)
print 'Interest in being on the EYC as a percentage of {:.0f} participants:'.format(EYC_tot)
print 'The number who wanted to have a youth space was',EYC_Y,'where', EYC_N,'said "No"'
print 'So {:.2f}% for "Y" and {:.2f}% said "N".'.format(EYC_Y/EYC_tot*100.,EYC_N/EYC_tot*100.)
# Out:
# Interest in being on the EYC as a percentage of 716 participants:
# The number who wanted to have a youth space was 201 where 515 said "No"
# So 28.07% for "Y" and 71.93% said "N".

# %%
def func_2(a, total=EYC_tot):
    return np.count_nonzero(a)/total*100
table4 = pd.pivot_table(df, values=['Eastside_youth_council'],#values=['Eastside_youth_council'],
                       columns=['Gender_(M/F)','Ethnicity'], aggfunc=count_nonzero)
table4 = table4.fillna(0).copy()
table4
# Out:
#                         Gender_(M/F)  Ethnicity
# Eastside_youth_council  F              Chinese          2
#                                        Cook_Is          5
#                                        Indian           4
#                                        Maori          111
#                                        Samoan           1
#                                       Multiple         64
#                                       NZEuro          216
#                         M              Chinese          4
#                                        Cook_Is          6
#                                        Indian           6
#                                        Maori           89
#                                        Samoan           1
#                                        Tongan           2
#                                       Multiple         65
#                                       NZEuro          222
# dtype: int64

# %%
df.columns.values.tolist()
# Out:
# [u'ID',
#  u'Age',
#  u'IWI',
#  u'Other',
#  u'Gender_(M/F)',
#  u'Local_Area',
#  u'Whangamarino',
#  u'Rotokawa',
#  u'RLHS',
#  u'Owhata',
#  u'Rotoma',
#  u'Lynmore',
#  u'Ruamata',
#  u'Mokoia',
#  u'Bus',
#  u'Rollerblade',
#  u'Skateboard',
#  u'Car',
#  u'Walk/run',
#  u'Bike',
#  u'Motorbike',
#  u'Taxi',
#  u'Scooter',
#  u'Other.1',
#  u'Family',
#  u'Education',
#  u'Friends',
#  u'My_job/work',
#  u'Finding_a_job',
#  u'Social_life_-_fun',
#  u'Money_making',
#  u'Interests/hobbies',
#  u'Sport',
#  u'Other.2',
#  u'Lonely',
#  u'Relationships',
#  u'Grades',
#  u'D&A',
#  u'Bullying',
#  u'Lack_of_money',
#  u'Violence',
#  u'Finding_job',
#  u'Identity',
#  u'Culture',
#  u'Friends.1',
#  u'Family.1',
#  u'Other.3',
#  u'Lonely.1',
#  u'Relationships.1',
#  u'Grades.1',
#  u'D&A.1',
#  u'Bullying.1',
#  u'Lack_of_money.1',
#  u'Violence.1',
#  u'Finding_job.1',
#  u'Identity.1',
#  u'Culture.1',
#  u'Friends.2',
#  u'Family.2',
#  u'Other.4',
#  u'10._One_change',
#  u'3_best_things',
#  u'#2',
#  u'#3',
#  u'Volleyball',
#  u'Ki_orahi',
#  u'T_Ball',
#  u'Ripper',
#  u'B_Ball',
#  u'Zumba',
#  u'Netball',
#  u'Dance_off',
#  u'Bootcamp',
#  u'Other.5',
#  u'Monday',
#  u'Tuesday',
#  u'Wednesday',
#  u'Thursday',
#  u'Friday',
#  u'Saturday',
#  u'Sunday',
#  u'Library',
#  u'Aquatic',
#  u'City_Focus',
#  u'Redwoods',
#  u'Parks',
#  u'Lakes',
#  u'Night_market',
#  u'Museuem',
#  u'Youth_centre',
#  u'Youth_health',
#  u'Gym',
#  u'Church',
#  u'Marae',
#  u'Events_centre',
#  u'Sports_drom',
#  u'Convention_centre',
#  u'Stadium',
#  u'Where_else_do_you_go?',
#  u'W_Heights',
#  u'Fordlands',
#  u'Central_City',
#  u'Ngong',
#  u'Puketawhero',
#  u'Youth_space?',
#  u'Rotaz?',
#  u'Physical',
#  u'Sport.1',
#  u'Music',
#  u'Creative',
#  u'Comm_fiar',
#  u'Youth_group',
#  u'Faith_group',
#  u'Student_council',
#  u'Community_interest',
#  u'Environmental_Volunter',
#  u'Volunteering',
#  u'Art',
#  u'Culture.2',
#  u'School',
#  u'Shopping',
#  u'With_friends_',
#  u'With_family',
#  u'Nothing',
#  u'Other.6',
#  u'Physical.1',
#  u'Sport.2',
#  u'Music.1',
#  u'Creative.1',
#  u'Comm_fiar.1',
#  u'Youth_group.1',
#  u'Faith_group.1',
#  u'Student_council.1',
#  u'Community_interest.1',
#  u'Environmental_Volunter.1',
#  u'Volunteering.1',
#  u'Art.1',
#  u'Culture.3',
#  u'School.1',
#  u'Shopping.1',
#  u'With_friends_.1',
#  u'With_family.1',
#  u'Nothing.1',
#  u'Other.7',
#  u'Not_interested',
#  u'Time',
#  u'Costs_too_much',
#  u"Can't_afford",
#  u'No_friends',
#  u'not_available',
#  u'Cant_get_there',
#  u'Shy',
#  u'Other_responsibility',
#  u'Parents_say_no',
#  u"Don't_know_how",
#  u'Other.8',
#  u'Internet',
#  u'Church.1',
#  u'School.2',
#  u'Newspaper',
#  u'WINZ',
#  u'Library.1',
#  u'Youth_group.2',
#  u'Mail',
#  u'Txt',
#  800,
#  u'Other.9',
#  u'Eastside_youth_council',
#  'Ethnicity']

# %%
temp =df.ix[:,'Physical':'Other.6'].count()
act_list = list(temp.keys()[0:18])
act_list
# Out:
# [u'Physical',
#  u'Sport.1',
#  u'Music',
#  u'Creative',
#  u'Comm_fiar',
#  u'Youth_group',
#  u'Faith_group',
#  u'Student_council',
#  u'Community_interest',
#  u'Environmental_Volunter',
#  u'Volunteering',
#  u'Art',
#  u'Culture.2',
#  u'School',
#  u'Shopping',
#  u'With_friends_',
#  u'With_family',
#  u'Nothing']

# %%
table5 = pd.pivot_table(df, values=act_list, index=['Age'], aggfunc=Percentage)
table5
# Out:
#        Art  Comm_fiar  Community_interest  Creative  Culture.2  \
# Age
# 9    42.59      24.07                1.85     22.22      14.81
# 10   31.19      16.51                5.50     14.68      14.68
# 11   32.31      14.62                7.69     23.08      10.00
# 12   19.57       8.70                 NaN     10.87       5.43
# 13   24.32      13.51                1.80     14.41       5.41
# 14   16.50       5.83                0.97     12.62       7.77
# 15   16.04       2.83                 NaN     11.32       3.77
# 16   15.71       8.57                 NaN     12.86       4.29
# 17    4.88       7.32                2.44      7.32       4.88
# 18   25.00        NaN                 NaN     25.00        NaN
#
#      Environmental_Volunter  Faith_group  Music  Physical  Shopping  Sport.1  \
# Age
# 9                      5.56        18.52  29.63     20.37     55.56    42.59
# 10                    12.84        14.68  31.19     40.37     52.29    63.30
# 11                    16.15         7.69  33.85     46.92     56.92    61.54
# 12                     8.70         5.43  27.17     35.87     46.74    51.09
# 13                     1.80         4.50  23.42     45.95     40.54    45.05
# 14                     1.94         8.74  16.50     61.17     38.83    64.08
# 15                     1.89        14.15  16.04     50.94     33.02    43.40
# 16                     2.86         8.57  21.43     68.57     34.29    57.14
# 17                     7.32         2.44   9.76     31.71     31.71    46.34
# 18                      NaN          NaN    NaN     50.00     25.00    25.00
#
#      Student_council  Volunteering  With_family  With_friends_  Youth_group
# Age
# 9               5.56         16.67        59.26          46.30        11.11
# 10              9.17         17.43        66.06          67.89        11.01
# 11             10.77         15.38        76.15          76.15         3.85
# 12             13.04          5.43        65.22          71.74         4.35
# 13               NaN          3.60        56.76          72.07        11.71
# 14              4.85          4.85        63.11          80.58         7.77
# 15              3.77         16.04        53.77          73.58         8.49
# 16              5.71         10.00        52.86          75.71        15.71
# 17              7.32         14.63        53.66          53.66         7.32
# 18               NaN         25.00        25.00          25.00          NaN

# %%
place_list = list(df_lhs.ix[:,'Library':'Stadium'].keys())
place_corr = np.corrcoef([df_lhs.Library.fillna(0),df_lhs.Aquatic.fillna(0),df_lhs.City_Focus.fillna(0),df_lhs.Redwoods.fillna(0),
             df_lhs.Parks.fillna(0),df_lhs.Lakes.fillna(0),df_lhs.Night_market.fillna(0),df_lhs.Museuem.fillna(0),
             df_lhs.Youth_centre.fillna(0),df_lhs.Youth_health.fillna(0),df_lhs.Gym.fillna(0),df_lhs.Church.fillna(0),
             df_lhs.Marae.fillna(0),df_lhs.Events_centre.fillna(0),df_lhs.Sports_drom.fillna(0),
             df_lhs.Convention_centre.fillna(0),df_lhs.Stadium.fillna(0)])
place_list
# Out:
# [u'Library',
#  u'Aquatic',
#  u'City_Focus',
#  u'Redwoods',
#  u'Parks',
#  u'Lakes',
#  u'Night_market',
#  u'Museuem',
#  u'Youth_centre',
#  u'Youth_health',
#  u'Gym',
#  u'Church',
#  u'Marae',
#  u'Events_centre',
#  u'Sports_drom',
#  u'Convention_centre',
#  u'Stadium']

# %%
sm.graphics.plot_corr(place_corr,xnames=place_list,title='Correlation of places to each other')

# %%
#Ignore these analyses Leigh
import statsmodels.api as sm
from patsy import dmatrices
vars = place_list #['Lakes','Age','Parks','Redwoods','Aquatic','Library','Events_centre','Church']
df3= df_lhs[vars].fillna(0)
df3=df3
x,Y = dmatrices('Church ~ Aquatic+ City_Focus+Redwoods+Parks+Lakes+Night_market+Museuem +Youth_centre+Youth_health',
                data=df3, return_type='dataframe')
mod = sm.OLS(x,Y)    # Describe model
res = mod.fit()       # Fit model
print res.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Church   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     9.090
# Date:                Thu, 25 Jun 2015   Prob (F-statistic):           1.13e-12
# Time:                        19:40:39   Log-Likelihood:                -1169.7
# No. Observations:                 460   AIC:                             2359.
# Df Residuals:                     450   BIC:                             2401.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.6746      0.471      1.432      0.153        -0.251     1.600
# Aquatic          0.0175      0.127      0.138      0.890        -0.232     0.267
# City_Focus      -0.0501      0.106     -0.471      0.638        -0.259     0.159
# Redwoods        -0.0797      0.118     -0.678      0.498        -0.311     0.151
# Parks            0.0776      0.123      0.632      0.528        -0.164     0.319
# Lakes            0.1960      0.127      1.548      0.122        -0.053     0.445
# Night_market    -0.0443      0.137     -0.323      0.747        -0.314     0.226
# Museuem          0.0842      0.167      0.504      0.615        -0.244     0.413
# Youth_centre     0.0668      0.164      0.407      0.684        -0.256     0.390
# Youth_health     0.6330      0.168      3.766      0.000         0.303     0.963
# ==============================================================================
# Omnibus:                      996.096   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1965677.031
# Skew:                          16.327   Prob(JB):                         0.00
# Kurtosis:                     321.576   Cond. No.                         36.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
table5ticks = ["Art","Community fair","Community interest","Creative","Culture",
               "Environmental volunteer","Faith Group","Music","Physical","Shopping",
               "Sport","Student Council","Volunteering","With Family","With Friends",
               "Youth Group"]

table5.plot(kind='bar',fontsize=18,alpha=.5,width=.7,
            color=['b','g','r','c','m','y','k','w','brown','olive','yellowgreen'],
            hatch='..',rot=45)
plt.title('Interests by age',fontsize=20)
plt.xlabel('Age',fontsize=16)
plt.ylabel('Percentage',fontsize=16)
plt.legend(table5ticks,loc='upper right',fancybox=True, framealpha=0.5)
plt.show()

# %% [markdown]
# ### Bullying and who it impacts upon

# %%
df.Bullying.fillna(0,inplace=True)
table6 = pd.pivot_table(df, index=['School'], columns=['Bullying'], values=['ID'],
                        aggfunc=count_nonzero,margins=False)
#Calculate percentages
table6 = np.round(table6.apply(lambda x : x / x.sum()*100., axis=1),2)
table6
# Out:
#                  ID
# Bullying          0      1
# School
# Lynmore       73.33  26.67
# Mokoia        69.81  30.19
# Owhata        81.40  18.60
# RLHS          85.43  14.57
# Rotokawa      75.00  25.00
# Whangamarino  62.79  37.21

# %%
# as a reference http://pbpython.com/pandas-pivot-table-explained.html
table6.plot(kind='barh',width=.7,alpha=.4,color=['w','r'],hatch='//',fontsize=14)
plt.legend(labels=['No report of bullying', 'Reports being bullied'])
plt.title('Bullying reporting by School',fontsize=20)
plt.xlabel('Percentage',fontsize=16)
plt.ylabel('School',fontsize=16)

# %%
#Bullying by Gender
df.Bullying.fillna(0,inplace=True)
table7 = pd.pivot_table(df, index=df['Gender_(M/F)'], columns=['Bullying','School'], values=['ID'],
                        aggfunc=count_nonzero,margins=False)
#Calculate percentages
table7 = np.round(table7.apply(lambda x : x / x.sum()*100., axis=1),2)
table7
# Out:
#                   ID                                                     \
# Bullying           0                                                  1
# School       Lynmore Mokoia Owhata   RLHS Rotokawa Whangamarino Lynmore
# Gender_(M/F)
# F               6.54  12.62   4.21  47.43     2.57         3.50    1.87
# M               3.57  22.14   4.05  45.00     3.81         2.62    1.90
#
#
# Bullying
# School       Mokoia Owhata  RLHS Rotokawa Whangamarino
# Gender_(M/F)
# F              9.11   0.93  9.11     0.47         1.64
# M              5.95   0.95  6.19     1.67         2.14

# %%
table7.plot(kind='barh',width=.7,alpha=.4,color=['w','r'],hatch='//',fontsize=14)
plt.legend(labels=['No report of bullying', 'Reports being bullied'])
plt.title('Bullying reporting by Gender',fontsize=20)
plt.xlabel('Percentage',fontsize=16)
plt.ylabel('Gender',fontsize=16)

# %% [markdown]
# Whilst bullying is often gauged by the impression of adults, a strength of these data is that youth were asked to rate whether it was an issue for them. They also were asked to indicate if they were concerned at it being an issue for Eastside youth in general.
#
# Taking the issue of personal experience, as reported by youth, it is interesting that the distribution of bullying across schools varies. Also, it seems that, as youth progress to Intermediate, the perception of bullying increases, but, by high school, has dropped to its lowest percentage. At Intermediate, this is the only place where girls feel more bullied than boys (7% more).
#
# It would be fascinating to ascertain what type of bullying and the perceived impact on youth as a follow up.
#
# There were no clear gender differences between boys or girls being bullied, although there was a tendency for girls to report this slightly more.
