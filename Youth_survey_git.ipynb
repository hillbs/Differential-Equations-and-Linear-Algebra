# %%
import pandas as pd
import matplotlib.pyplot as plt 
import pprint as pp
import glob
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 20)
Files = glob.glob("/Users/LlewelynRW/Dropbox/Leigh/*.xlsx")
figsize(10,8)
Files[0]
# Out:
# '/Users/LlewelynRW/Dropbox/Leigh/Eastside youth survey Results.xlsx'

# %%
#Create function to plot bar chart
def Make_bar(A,B,C,Header, Y_label):
    '''A is <object>.count()
       B is <object.values[0:A]
       c is <object>.keys()
       Header is plot title
       Y_Label is y-axis title'''
    N = A#10#schools.count()
    ind = np.arange(N)  # the x locations for the groups
    width = .8       # the width of the bars
    f = plt.figure()#facecolor=".9")
    ax = f.add_subplot(111)#, axisbg="#F4EAEA")
    rects1 = ax.bar(ind, B, width, color='purple',alpha=.4)

    # add some text for labels, title and axes ticks
    ax.set_ylabel(Y_label,fontsize=14)
    ax.set_title(Header,fontsize=20)
    ax.set_xticks(ind+width/3)
    xtickNames = ax.set_xticklabels(C)
    plt.setp(xtickNames, rotation=75, fontsize=14)
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                    ha='center', va='bottom')

    autolabel(rects1)
    plt.grid(True)
    plt.show()
    return

# %%
#plt.figure()
def Standard_background():
    f = plt.figure()#facecolor=".9")
    ax = f.add_subplot(111)#, axisbg="#F4EAEA")
    return

# %% [markdown]
# ## Import Data

# %%
df = pd.read_excel(Files[0],sheetname='Raw data to be entered', na_values=0,index_row=0)
#This is a wee snippet to insert _ where there are column spaces
cols = df.columns
cols = cols.map(lambda x: x.replace(' ', '_') if isinstance(x, (str, unicode)) else x)
df.columns = cols
df.head(4)
# Out:
#    ID  Age  NZEuro Maori                 IWI Samoan  Cook_Is  Tongan  Niuean  \
# 0  o1    9     NaN     1              Mataua    NaN      NaN     NaN     NaN
# 1  o2   10     NaN     1  Te whanau-a-apanui    NaN      NaN     NaN     NaN
# 2  o3    9     NaN     1                 NaN    NaN      NaN     NaN     NaN
# 3  o4    9     NaN     1                 NaN    NaN      NaN     NaN     NaN
#
#    Chinese  Indian Other Gender_(M/F) Local_Area  Whangamarino  Rotokawa  \
# 0      NaN     NaN   NaN            F     Owhata           NaN       NaN
# 1      NaN     NaN   NaN            F     Owhata           NaN       NaN
# 2      NaN     NaN   NaN            F     Owhata           NaN       NaN
# 3      NaN     NaN   NaN            F     Owhata           NaN       NaN
#
#    RLHS  Owhata  Rotoma  Lynmore  Ruamata  Mokoia  Bus  Rollerblade  \
# 0   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 1   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 2   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 3   NaN       1     NaN      NaN      NaN     NaN    1          NaN
#
#    Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  Scooter Other.1  Family  \
# 0         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 1         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 2         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
# 3         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
#
#    Education  Friends  My_job/work  Finding_a_job  Social_life_-_fun  \
# 0        NaN      NaN          NaN            NaN                NaN
# 1        NaN      NaN          NaN            NaN                NaN
# 2        NaN      NaN          NaN            NaN                NaN
# 3        NaN      NaN          NaN            NaN                NaN
#
#    Money_making  Interests/hobbies  Sport Other.2  Lonely  Relationships  \
# 0           NaN                NaN    NaN     NaN     NaN            NaN
# 1           NaN                NaN    NaN     NaN     NaN            NaN
# 2           NaN                NaN    NaN     NaN     NaN            NaN
# 3           NaN                NaN    NaN     NaN     NaN            NaN
#
#    Grades  D&A  Bullying  Lack_of_money  Violence  Finding_job  \
# 0     NaN  NaN       NaN            NaN       NaN            1
# 1       1  NaN       NaN            NaN       NaN          NaN
# 2     NaN  NaN       NaN            NaN       NaN          NaN
# 3       1  NaN       NaN            NaN         1          NaN
#
#             ...            Culture.2  School  Shopping  With_friends_  \
# 0           ...                  NaN     NaN         1              1
# 1           ...                  NaN     NaN         1            NaN
# 2           ...                  NaN     NaN         1              1
# 3           ...                  NaN       1         1              1
#
#   With_family  Nothing  Other.6  Physical.1  Sport.2  Music.1  Creative.1  \
# 0           1      NaN      NaN           1      NaN      NaN           1
# 1           1      NaN      NaN           1        1      NaN         NaN
# 2           1      NaN      NaN         NaN      NaN        1           1
# 3         NaN      NaN      NaN         NaN      NaN        1         NaN
#
#    Comm_fiar.1  Youth_group.1  Faith_group.1  Student_council.1  \
# 0          NaN              1            NaN                  1
# 1            1            NaN            NaN                NaN
# 2          NaN            NaN            NaN                  1
# 3          NaN            NaN            NaN                NaN
#
#    Community_interest.1  Environmental_Volunter.1 Volunteering.1 Art.1  \
# 0                   NaN                         1              1     1
# 1                     1                       NaN            NaN   NaN
# 2                   NaN                       NaN              1     1
# 3                   NaN                       NaN            NaN   NaN
#
#   Culture.3 School.1 Shopping.1  With_friends_.1  With_family.1  Nothing.1  \
# 0         1        1        NaN              NaN            NaN        NaN
# 1         1        1        NaN              NaN            NaN        NaN
# 2       NaN      NaN        NaN              NaN            NaN        NaN
# 3       NaN      NaN        NaN              NaN              1        NaN
#
#    Other.7  Not_interested  Time  Costs_too_much  Can't_afford  No_friends  \
# 0      NaN             NaN   NaN               1             1           1
# 1      NaN             NaN   NaN               1           NaN           1
# 2      NaN             NaN   NaN               1           NaN         NaN
# 3      NaN             NaN   NaN             NaN           NaN         NaN
#
#   not_available  Cant_get_there  Shy  Other_responsibility  Parents_say_no  \
# 0           NaN               1    1                   NaN               1
# 1           NaN             NaN  NaN                   NaN             NaN
# 2             1             NaN    1                   NaN               1
# 3             1             NaN  NaN                   NaN             NaN
#
#    Don't_know_how  Other.8  Internet  Church.1  School.2  Newspaper  WINZ  \
# 0               1      NaN       NaN       NaN         1          1   NaN
# 1             NaN      NaN       NaN       NaN         1          1   NaN
# 2             NaN      NaN       NaN       NaN         1        NaN   NaN
# 3             NaN  no time       NaN       NaN         1        NaN   NaN
#
#    Library.1  Youth_group.2  Mail  Txt  800  Other.9  Eastside_youth_council
# 0        NaN            NaN   NaN  NaN  NaN      NaN                       Y
# 1          1            NaN     1  NaN  NaN   whanau                       Y
# 2        NaN            NaN     1  NaN  NaN      NaN                       N
# 3        NaN            NaN   NaN  NaN    1      NaN                       Y
#
# [4 rows x 176 columns]

# %% [markdown]
# ## Clean Data|

# %%
#Create School column
df.ix[df.Lynmore >= 1,'School'] = 'Lynmore'
df.ix[df.Whangamarino >= 1,'School'] = 'Whangamarino'
df.ix[df.Rotokawa >= 1,'School'] = 'Rotokawa'
df.ix[df.RLHS >= 1,'School'] = 'RLHS'
df.ix[df.Owhata  >= 1,'School'] = 'Owhata'
df.ix[df.Rotoma  >= 1,'School'] = 'Rotoma'
df.ix[df.Ruamata  >= 1,'School'] = 'Ruamata'
df.ix[df.Mokoia  >= 1,'School'] = 'Mokoia'
df.head
# Out:
# <bound method DataFrame.head of       ID  Age  NZEuro Maori                 IWI Samoan  Cook_Is  Tongan  \
# 0     o1    9     NaN     1              Mataua    NaN      NaN     NaN
# 1     o2   10     NaN     1  Te whanau-a-apanui    NaN      NaN     NaN
# 2     o3    9     NaN     1                 NaN    NaN      NaN     NaN
# 3     o4    9     NaN     1                 NaN    NaN      NaN     NaN
# 4     o5   10     NaN   NaN                 NaN    NaN        1     NaN
# 5     o6   10     NaN     1               Tuhoe    NaN      NaN     NaN
# 6     o7    9       1   NaN                 NaN    NaN      NaN     NaN
# 7     o8   10       1     1                 NaN    NaN      NaN     NaN
# 8     o9    9     NaN     1                 NaN    NaN      NaN     NaN
# 9    o10    9       1     1                 NaN    NaN      NaN     NaN
# ..   ...  ...     ...   ...                 ...    ...      ...     ...
# 856  R27   10       1   NaN                 NaN    NaN      NaN     NaN
# 857  R28    9       1   NaN                 NaN    NaN      NaN     NaN
# 858  R29    9       1   NaN                 NaN    NaN      NaN     NaN
# 859  R30    9     NaN     1                 NaN    NaN      NaN     NaN
# 860  R31    9     NaN     1                 NaN    NaN      NaN     NaN
# 861  R32   10       1     1                 NaN    NaN      NaN     NaN
# 862  R33    9       1     1                 NaN    NaN      NaN     NaN
# 863  R34    9       1   NaN                 NaN    NaN        1     NaN
# 864  R35   10       1     1                 NaN    NaN      NaN     NaN
# 865  R36   10       1     1                 NaN    NaN      NaN     NaN
#
#      Niuean  Chinese  Indian Other Gender_(M/F)   Local_Area  Whangamarino  \
# 0       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 1       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 2       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 3       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 4       NaN      NaN     NaN   NaN            M      Ngapuna           NaN
# 5       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 6       NaN      NaN     NaN   NaN            F       Owhata           NaN
# 7       NaN      NaN     NaN   NaN            M      Ngapuna           NaN
# 8       NaN      NaN     NaN   NaN            M       Owhata           NaN
# 9       NaN      NaN     NaN   NaN            F       Owhata           NaN
# ..      ...      ...     ...   ...          ...          ...           ...
# 856     NaN      NaN     NaN   NaN            M  Okere Falls           NaN
# 857     NaN      NaN     NaN   NaN            F       Owhata           NaN
# 858     NaN      NaN     NaN   NaN            F      Rotoiti           NaN
# 859     NaN      NaN     NaN   NaN            M          NaN           NaN
# 860     NaN      NaN     NaN   NaN            M          NaN           NaN
# 861     NaN      NaN     NaN   NaN            M      Lynmore           NaN
# 862     NaN      NaN     NaN   NaN            F       Owhata           NaN
# 863     NaN      NaN     NaN   NaN            M          NaN           NaN
# 864     NaN      NaN     NaN   NaN            M          NaN           NaN
# 865     NaN      NaN     NaN   NaN            F     Tikitere           NaN
#
#      Rotokawa  RLHS  Owhata  Rotoma  Lynmore  Ruamata  Mokoia  Bus  \
# 0         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 1         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 2         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 3         NaN   NaN       1     NaN      NaN      NaN     NaN    1
# 4         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 5         NaN   NaN       1     NaN      NaN      NaN     NaN    1
# 6         NaN   NaN       1     NaN      NaN      NaN     NaN    1
# 7         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 8         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# 9         NaN   NaN       1     NaN      NaN      NaN     NaN  NaN
# ..        ...   ...     ...     ...      ...      ...     ...  ...
# 856         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 857         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 858         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 859         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 860         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 861         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 862         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 863         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 864         1   NaN     NaN     NaN      NaN      NaN     NaN  NaN
# 865         1   NaN     NaN     NaN      NaN      NaN     NaN    1
#
#      Rollerblade  Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  Scooter  \
# 0            NaN         NaN  NaN         1   NaN        NaN   NaN      NaN
# 1            NaN         NaN  NaN         1   NaN        NaN   NaN      NaN
# 2            NaN         NaN    1         1   NaN        NaN   NaN      NaN
# 3            NaN         NaN    1         1   NaN        NaN   NaN      NaN
# 4            NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 5            NaN         NaN  NaN       NaN   NaN        NaN   NaN      NaN
# 6            NaN         NaN    1         1   NaN          1   NaN      NaN
# 7            NaN         NaN  NaN         1   NaN        NaN   NaN      NaN
# 8            NaN         NaN    1         1   NaN        NaN   NaN      NaN
# 9            NaN         NaN    1         1   NaN        NaN   NaN        1
# ..           ...         ...  ...       ...   ...        ...   ...      ...
# 856          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 857          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 858          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 859          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 860          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 861          NaN         NaN    1         1     1          1   NaN        1
# 862          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 863          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 864          NaN         NaN    1       NaN   NaN        NaN   NaN      NaN
# 865          NaN         NaN  NaN       NaN   NaN        NaN   NaN      NaN
#
#     Other.1  Family  Education  Friends  My_job/work  Finding_a_job  \
# 0       NaN       1        NaN      NaN          NaN            NaN
# 1       NaN       1        NaN      NaN          NaN            NaN
# 2       NaN       1        NaN      NaN          NaN            NaN
# 3       NaN       1        NaN      NaN          NaN            NaN
# 4       NaN       1        NaN      NaN          NaN            NaN
# 5       NaN     NaN          1      NaN          NaN            NaN
# 6       NaN       1        NaN        1            1            NaN
# 7       NaN       1          1        1          NaN            NaN
# 8       NaN       1        NaN      NaN          NaN            NaN
# 9       NaN       1        NaN      NaN          NaN            NaN
# ..      ...     ...        ...      ...          ...            ...
# 856     NaN       1        NaN      NaN          NaN            NaN
# 857     NaN       1        NaN      NaN          NaN            NaN
# 858     NaN       1          1      NaN          NaN            NaN
# 859     NaN       1        NaN      NaN          NaN            NaN
# 860     NaN       1        NaN      NaN          NaN            NaN
# 861     NaN       1        NaN      NaN          NaN            NaN
# 862     NaN       1        NaN      NaN          NaN            NaN
# 863     NaN       1        NaN        1          NaN            NaN
# 864     NaN       1        NaN      NaN          NaN            NaN
# 865     NaN       1          1      NaN          NaN            NaN
#
#      Social_life_-_fun  Money_making  Interests/hobbies  Sport Other.2  \
# 0                  NaN           NaN                NaN    NaN     NaN
# 1                  NaN           NaN                NaN    NaN     NaN
# 2                  NaN           NaN                NaN    NaN     NaN
# 3                  NaN           NaN                NaN    NaN     NaN
# 4                  NaN           NaN                NaN    NaN     NaN
# 5                  NaN           NaN                NaN    NaN     NaN
# 6                  NaN             1                NaN    NaN     NaN
# 7                    1           NaN                NaN    NaN     NaN
# 8                  NaN           NaN                NaN    NaN     NaN
# 9                  NaN           NaN                NaN    NaN     NaN
# ..                 ...           ...                ...    ...     ...
# 856                NaN           NaN                NaN    NaN     NaN
# 857                NaN           NaN                NaN    NaN     NaN
# 858                NaN           NaN                NaN    NaN     NaN
# 859                NaN           NaN                NaN    NaN     NaN
# 860                NaN           NaN                NaN    NaN     NaN
# 861                NaN           NaN                NaN    NaN     NaN
# 862                NaN           NaN                NaN      1     NaN
# 863                NaN           NaN                NaN    NaN     NaN
# 864                NaN           NaN                  1      1     NaN
# 865                NaN           NaN                NaN    NaN     NaN
#
#      Lonely  Relationships  Grades  D&A  Bullying  Lack_of_money  Violence  \
# 0       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 1       NaN            NaN       1  NaN       NaN            NaN       NaN
# 2       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 3       NaN            NaN       1  NaN       NaN            NaN         1
# 4       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 5       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 6       NaN            NaN     NaN  NaN       NaN            NaN       NaN
# 7       NaN            NaN       1  NaN       NaN            NaN       NaN
# 8         1            NaN     NaN  NaN       NaN            NaN       NaN
# 9         1              1       1    1       NaN            NaN         1
# ..      ...            ...     ...  ...       ...            ...       ...
# 856       1            NaN     NaN  NaN       NaN            NaN       NaN
# 857       1            NaN     NaN  NaN       NaN            NaN       NaN
# 858     NaN            NaN       1  NaN       NaN            NaN       NaN
# 859     NaN            NaN     NaN  NaN         1            NaN         1
# 860       1            NaN     NaN  NaN         1            NaN       NaN
# 861     NaN            NaN       1    1       NaN            NaN       NaN
# 862       1            NaN     NaN  NaN       NaN            NaN       NaN
# 863       1            NaN     NaN  NaN         1            NaN       NaN
# 864     NaN            NaN       1    1       NaN            NaN       NaN
# 865       1            NaN     NaN  NaN       NaN            NaN       NaN
#
#      Finding_job           ...            Culture.2    School  Shopping  \
# 0              1           ...                  NaN    Owhata         1
# 1            NaN           ...                  NaN    Owhata         1
# 2            NaN           ...                  NaN    Owhata         1
# 3            NaN           ...                  NaN    Owhata         1
# 4            NaN           ...                    1    Owhata         1
# 5            NaN           ...                  NaN    Owhata         1
# 6            NaN           ...                  NaN    Owhata       NaN
# 7            NaN           ...                  NaN    Owhata         1
# 8            NaN           ...                  NaN    Owhata       NaN
# 9            NaN           ...                    1    Owhata         1
# ..           ...           ...                  ...       ...       ...
# 856          NaN           ...                  NaN  Rotokawa       NaN
# 857          NaN           ...                  NaN  Rotokawa         1
# 858          NaN           ...                  NaN  Rotokawa         1
# 859          NaN           ...                    1  Rotokawa         1
# 860          NaN           ...                  NaN  Rotokawa       NaN
# 861          NaN           ...                  NaN  Rotokawa         1
# 862          NaN           ...                  NaN  Rotokawa         1
# 863          NaN           ...                  NaN  Rotokawa       NaN
# 864          NaN           ...                  NaN  Rotokawa       NaN
# 865          NaN           ...                  NaN  Rotokawa       NaN
#
#      With_friends_ With_family  Nothing       Other.6  Physical.1  Sport.2  \
# 0                1           1      NaN           NaN           1      NaN
# 1              NaN           1      NaN           NaN           1        1
# 2                1           1      NaN           NaN         NaN      NaN
# 3                1         NaN      NaN           NaN         NaN      NaN
# 4                1           1      NaN           NaN         NaN      NaN
# 5                1           1      NaN           NaN         NaN      NaN
# 6                1           1      NaN           NaN           1        1
# 7                1           1      NaN           NaN         NaN      NaN
# 8                1           1      NaN           NaN         NaN      NaN
# 9                1           1      NaN           NaN         NaN      NaN
# ..             ...         ...      ...           ...         ...      ...
# 856            NaN         NaN      NaN           NaN         NaN      NaN
# 857            NaN         NaN        1           NaN         NaN      NaN
# 858              1         NaN      NaN           NaN         NaN      NaN
# 859              1           1      NaN           NaN         NaN      NaN
# 860            NaN         NaN      NaN           NaN         NaN        1
# 861              1           1      NaN           NaN         NaN      NaN
# 862            NaN         NaN        1           NaN         NaN      NaN
# 863            NaN         NaN      NaN           NaN         NaN      NaN
# 864            NaN         NaN      NaN           NaN         NaN      NaN
# 865            NaN         NaN      NaN  horse riding         NaN        1
#
#      Music.1  Creative.1  Comm_fiar.1  Youth_group.1  Faith_group.1  \
# 0        NaN           1          NaN              1            NaN
# 1        NaN         NaN            1            NaN            NaN
# 2          1           1          NaN            NaN            NaN
# 3          1         NaN          NaN            NaN            NaN
# 4        NaN         NaN          NaN            NaN            NaN
# 5        NaN         NaN          NaN            NaN              1
# 6        NaN         NaN          NaN              1            NaN
# 7          1         NaN          NaN            NaN            NaN
# 8        NaN         NaN          NaN            NaN            NaN
# 9        NaN         NaN          NaN              1              1
# ..       ...         ...          ...            ...            ...
# 856        1           1          NaN            NaN            NaN
# 857        1         NaN            1            NaN            NaN
# 858      NaN         NaN          NaN            NaN            NaN
# 859        1         NaN          NaN            NaN            NaN
# 860      NaN         NaN          NaN            NaN            NaN
# 861      NaN         NaN          NaN            NaN            NaN
# 862        1         NaN          NaN            NaN            NaN
# 863      NaN         NaN          NaN            NaN            NaN
# 864      NaN         NaN          NaN            NaN            NaN
# 865      NaN         NaN          NaN            NaN            NaN
#
#      Student_council.1  Community_interest.1  Environmental_Volunter.1  \
# 0                    1                   NaN                         1
# 1                  NaN                     1                       NaN
# 2                    1                   NaN                       NaN
# 3                  NaN                   NaN                       NaN
# 4                  NaN                   NaN                       NaN
# 5                  NaN                   NaN                       NaN
# 6                  NaN                   NaN                       NaN
# 7                    1                   NaN                       NaN
# 8                  NaN                   NaN                       NaN
# 9                    1                     1                       NaN
# ..                 ...                   ...                       ...
# 856                NaN                   NaN                       NaN
# 857                NaN                   NaN                       NaN
# 858                NaN                   NaN                       NaN
# 859                NaN                   NaN                       NaN
# 860                NaN                   NaN                       NaN
# 861                NaN                   NaN                       NaN
# 862                NaN                   NaN                       NaN
# 863                NaN                   NaN                       NaN
# 864                NaN                   NaN                       NaN
# 865                NaN                   NaN                       NaN
#
#     Volunteering.1 Art.1 Culture.3 School.1 Shopping.1  With_friends_.1  \
# 0                1     1         1        1        NaN              NaN
# 1              NaN   NaN         1        1        NaN              NaN
# 2                1     1       NaN      NaN        NaN              NaN
# 3              NaN   NaN       NaN      NaN        NaN              NaN
# 4              NaN   NaN       NaN      NaN        NaN              NaN
# 5              NaN     1       NaN      NaN        NaN              NaN
# 6              NaN     1       NaN      NaN        NaN              NaN
# 7              NaN   NaN         1        1        NaN              NaN
# 8              NaN   NaN       NaN      NaN        NaN              NaN
# 9              NaN   NaN       NaN      NaN        NaN              NaN
# ..             ...   ...       ...      ...        ...              ...
# 856            NaN     1       NaN      NaN        NaN                1
# 857            NaN   NaN       NaN      NaN        NaN              NaN
# 858            NaN     1       NaN      NaN        NaN              NaN
# 859              1     1       NaN      NaN        NaN              NaN
# 860            NaN   NaN       NaN      NaN        NaN              NaN
# 861            NaN   NaN       NaN      NaN        NaN              NaN
# 862            NaN     1       NaN      NaN          1              NaN
# 863            NaN     1       NaN      NaN        NaN              NaN
# 864            NaN   NaN       NaN      NaN        NaN              NaN
# 865              1   NaN       NaN      NaN        NaN                1
#
#      With_family.1  Nothing.1       Other.7  Not_interested  Time  \
# 0              NaN        NaN           NaN             NaN   NaN
# 1              NaN        NaN           NaN             NaN   NaN
# 2              NaN        NaN           NaN             NaN   NaN
# 3                1        NaN           NaN             NaN   NaN
# 4              NaN        NaN           NaN               1     1
# 5              NaN        NaN           NaN             NaN   NaN
# 6              NaN        NaN           NaN             NaN     1
# 7              NaN        NaN           NaN             NaN   NaN
# 8              NaN          1           NaN             NaN   NaN
# 9              NaN          1  be a teacher             NaN   NaN
# ..             ...        ...           ...             ...   ...
# 856            NaN        NaN           NaN               1   NaN
# 857            NaN          1           NaN             NaN     1
# 858            NaN        NaN           NaN             NaN   NaN
# 859            NaN        NaN           NaN               1     1
# 860            NaN        NaN           NaN             NaN   NaN
# 861            NaN          1           NaN               1   NaN
# 862            NaN          1           NaN             NaN   NaN
# 863            NaN        NaN           NaN             NaN   NaN
# 864            NaN          1           NaN             NaN   NaN
# 865            NaN        NaN           NaN             NaN   NaN
#
#      Costs_too_much  Can't_afford  No_friends not_available  Cant_get_there  \
# 0                 1             1           1           NaN               1
# 1                 1           NaN           1           NaN             NaN
# 2                 1           NaN         NaN             1             NaN
# 3               NaN           NaN         NaN             1             NaN
# 4               NaN           NaN         NaN           NaN             NaN
# 5               NaN           NaN         NaN           NaN               1
# 6                 1           NaN         NaN           NaN             NaN
# 7               NaN           NaN           1             1               1
# 8               NaN           NaN         NaN           NaN             NaN
# 9                 1             1           1             1             NaN
# ..              ...           ...         ...           ...             ...
# 856             NaN           NaN         NaN           NaN             NaN
# 857             NaN           NaN         NaN           NaN             NaN
# 858             NaN             1         NaN             1               1
# 859               1             1           1           NaN             NaN
# 860             NaN           NaN         NaN           NaN             NaN
# 861             NaN           NaN         NaN             1             NaN
# 862             NaN           NaN         NaN           NaN             NaN
# 863             NaN           NaN         NaN           NaN             NaN
# 864             NaN           NaN           1           NaN               1
# 865             NaN           NaN         NaN           NaN               1
#
#      Shy  Other_responsibility  Parents_say_no  Don't_know_how  Other.8  \
# 0      1                   NaN               1               1      NaN
# 1    NaN                   NaN             NaN             NaN      NaN
# 2      1                   NaN               1             NaN      NaN
# 3    NaN                   NaN             NaN             NaN  no time
# 4    NaN                   NaN             NaN             NaN      NaN
# 5    NaN                   NaN               1             NaN      NaN
# 6    NaN                     1               1             NaN      NaN
# 7    NaN                   NaN               1               1      NaN
# 8    NaN                   NaN             NaN               1      NaN
# 9      1                     1               1               1      NaN
# ..   ...                   ...             ...             ...      ...
# 856  NaN                   NaN             NaN             NaN      NaN
# 857  NaN                   NaN             NaN             NaN      NaN
# 858  NaN                     1               1               1      NaN
# 859  NaN                   NaN             NaN             NaN      NaN
# 860  NaN                   NaN             NaN             NaN      NaN
# 861  NaN                   NaN             NaN             NaN      NaN
# 862  NaN                   NaN             NaN             NaN      NaN
# 863  NaN                   NaN               1             NaN      NaN
# 864  NaN                   NaN             NaN             NaN      NaN
# 865  NaN                   NaN               1             NaN      NaN
#
#      Internet  Church.1  School.2  Newspaper  WINZ  Library.1  Youth_group.2  \
# 0         NaN       NaN         1          1   NaN        NaN            NaN
# 1         NaN       NaN         1          1   NaN          1            NaN
# 2         NaN       NaN         1        NaN   NaN        NaN            NaN
# 3         NaN       NaN         1        NaN   NaN        NaN            NaN
# 4         NaN       NaN       NaN        NaN   NaN        NaN              1
# 5         NaN       NaN         1        NaN   NaN        NaN            NaN
# 6           1         1         1          1   NaN          1            NaN
# 7           1       NaN       NaN        NaN   NaN        NaN            NaN
# 8         NaN       NaN         1        NaN   NaN        NaN            NaN
# 9         NaN       NaN         1        NaN   NaN        NaN            NaN
# ..        ...       ...       ...        ...   ...        ...            ...
# 856         1       NaN       NaN        NaN   NaN        NaN            NaN
# 857       NaN       NaN       NaN          1   NaN        NaN            NaN
# 858       NaN       NaN       NaN          1   NaN        NaN            NaN
# 859         1       NaN         1        NaN   NaN          1            NaN
# 860         1       NaN       NaN        NaN   NaN        NaN            NaN
# 861         1       NaN         1          1   NaN        NaN            NaN
# 862       NaN       NaN       NaN        NaN   NaN        NaN            NaN
# 863       NaN       NaN         1        NaN   NaN        NaN            NaN
# 864       NaN       NaN         1          1   NaN        NaN            NaN
# 865         1       NaN       NaN          1   NaN        NaN            NaN
#
#      Mail  Txt  800  Other.9  Eastside_youth_council
# 0     NaN  NaN  NaN      NaN                       Y
# 1       1  NaN  NaN   whanau                       Y
# 2       1  NaN  NaN      NaN                       N
# 3     NaN  NaN    1      NaN                       Y
# 4     NaN  NaN    1      NaN                       Y
# 5     NaN  NaN  NaN      NaN                       Y
# 6       1    1  NaN      NaN                       N
# 7       1  NaN    1      NaN                       Y
# 8       1    1  NaN      NaN                       Y
# 9       1    1  NaN      NaN                       Y
# ..    ...  ...  ...      ...                     ...
# 856   NaN  NaN  NaN      NaN                       N
# 857   NaN  NaN  NaN      NaN                       N
# 858     1  NaN  NaN      NaN                     NaN
# 859     1  NaN    1      NaN                       N
# 860   NaN  NaN  NaN      NaN                     NaN
# 861     1    1  NaN      NaN                       N
# 862   NaN  NaN  NaN      NaN                     NaN
# 863     1  NaN  NaN      NaN                       Y
# 864     1  NaN  NaN      NaN                       N
# 865   NaN  NaN  NaN      NaN                       N
#
# [866 rows x 176 columns]>

# %% [markdown]
# ### Local Area

# %%
Standard_background()
df.Local_Area.value_counts()[df.Local_Area.value_counts() >10].plot(kind='bar',color='green',alpha=.7)

# %% [markdown]
# ### Age data

# %%
#Exclude anyone less than 10
df['Age'] = df.Age.replace([8], np.NaN)
df.Age.value_counts(),df.Age.describe()
# Out:
# (11    130
#  13    111
#  10    109
#  15    106
#  14    103
#  12     92
#  16     70
#  9      54
#  17     41
#  18      4
#  dtype: int64, count    820.000000
#  mean      12.773171
#  std        2.298752
#  min        9.000000
#  25%       11.000000
#  50%       13.000000
#  75%       15.000000
#  max       18.000000
#  Name: Age, dtype: float64)

# %%
# %matplotlib inline
figsize(12,10)
f = plt.figure()#facecolor=".9")
ax = f.add_subplot(111)#, axisbg="#F4EAEA")
title('$Distribution \ of \ Age$',fontsize=20)
xlabel('$Age$',fontsize=16)
ylabel('$Number$',fontsize=16)
df.Age.hist(rwidth=0.9, color='g')

# %%
df.columns
# Out:
# Index([                    u'ID',                    u'Age',
#                        u'NZEuro',                  u'Maori',
#                           u'IWI',                 u'Samoan',
#                       u'Cook_Is',                 u'Tongan',
#                        u'Niuean',                u'Chinese',
#        ...
#                      u'School.2',              u'Newspaper',
#                          u'WINZ',              u'Library.1',
#                 u'Youth_group.2',                   u'Mail',
#                           u'Txt',                       800,
#                       u'Other.9', u'Eastside_youth_council'],
#       dtype='object', length=176)

# %%
df.Age.mean(),df.Age.median(), df.Age.std()
# Out:
# (12.773170731707317, 13.0, 2.2987520519743132)

# %% [markdown]
# ### Ethnicity

# %%
df.ix[df.NZEuro >= 1,'NZEuro'] = 'NZEuro'
df.ix[df.Maori >= 1,'Maori'] = 'Maori'
df.ix[df.Samoan >= 1,'Samoan'] = 'Samoan'
df.ix[df.Cook_Is >= 1,'Cook_Is'] = 'Cook_Is'
df.ix[df.Tongan  >= 1,'Tongan'] = 'Tongan'
df.ix[df.Niuean  >= 1,'Niuean'] = 'Niuean'
df.ix[df.Chinese  >= 1,'Chinese'] = 'Chinese'
df.ix[df.Indian  >= 1,'Indian'] = 'Indian'

df['Ethnicity'] = df['NZEuro']\
.add(df.Maori, fill_value=' ')\
.add(df.Samoan,fill_value=' ')\
.add(df.Cook_Is,fill_value=' ')\
.add(df.Tongan,fill_value=' ')\
.add(df.Chinese,fill_value=' ')\
.add(df.Indian,fill_value=' ')\

df = df.drop(['NZEuro','Maori','Samoan','Cook_Is','Tongan','Niuean','Chinese','Indian'],axis=1)

df.replace(['NZEuroMaoriSamoan    ','NZEuro  Cook_Is   ','NZEuroMaori     ','NZEuro Samoan    ', ' MaoriSamoan    ',
       ' Maori Cook_Is   ', 'NZEuroMaori Cook_Is   ','NZEuro     Indian',  ' SamoanCook_Is   ','NZEuroMaoriSamoanCook_Is   '],\
           ['Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple','Multiple'],inplace=True)
df.head()
# Out:
#    ID  Age                 IWI Other Gender_(M/F) Local_Area  Whangamarino  \
# 0  o1    9              Mataua   NaN            F     Owhata           NaN
# 1  o2   10  Te whanau-a-apanui   NaN            F     Owhata           NaN
# 2  o3    9                 NaN   NaN            F     Owhata           NaN
# 3  o4    9                 NaN   NaN            F     Owhata           NaN
# 4  o5   10                 NaN   NaN            M    Ngapuna           NaN
#
#    Rotokawa  RLHS  Ohwata  Rotoma  Lynmore  Ruamata  Mokoia  Bus  Rollerblade  \
# 0       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 1       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 2       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
# 3       NaN   NaN       1     NaN      NaN      NaN     NaN    1          NaN
# 4       NaN   NaN       1     NaN      NaN      NaN     NaN  NaN          NaN
#
#    Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  Scooter Other.1  Family  \
# 0         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 1         NaN  NaN         1   NaN        NaN   NaN      NaN     NaN       1
# 2         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
# 3         NaN    1         1   NaN        NaN   NaN      NaN     NaN       1
# 4         NaN    1       NaN   NaN        NaN   NaN      NaN     NaN       1
#
#    Education  Friends  My_job/work  Finding_a_job  Social_life_-_fun  \
# 0        NaN      NaN          NaN            NaN                NaN
# 1        NaN      NaN          NaN            NaN                NaN
# 2        NaN      NaN          NaN            NaN                NaN
# 3        NaN      NaN          NaN            NaN                NaN
# 4        NaN      NaN          NaN            NaN                NaN
#
#    Money_making  Interests/hobbies  Sport Other.2  Lonely  Relationships  \
# 0           NaN                NaN    NaN     NaN     NaN            NaN
# 1           NaN                NaN    NaN     NaN     NaN            NaN
# 2           NaN                NaN    NaN     NaN     NaN            NaN
# 3           NaN                NaN    NaN     NaN     NaN            NaN
# 4           NaN                NaN    NaN     NaN     NaN            NaN
#
#    Grades  D&A  Bullying  Lack_of_money  Violence  Finding_job  Identity  \
# 0     NaN  NaN       NaN            NaN       NaN            1       NaN
# 1       1  NaN       NaN            NaN       NaN          NaN       NaN
# 2     NaN  NaN       NaN            NaN       NaN          NaN       NaN
# 3       1  NaN       NaN            NaN         1          NaN       NaN
# 4     NaN  NaN       NaN            NaN       NaN          NaN       NaN
#
#    Culture  Friends.1  Family.1 Other.3  Lonely.1  Relationships.1  Grades.1  \
# 0      NaN        NaN       NaN     NaN       NaN              NaN       NaN
# 1      NaN          1       NaN     NaN       NaN              NaN       NaN
# 2      NaN        NaN       NaN     pet       NaN              NaN       NaN
# 3      NaN        NaN       NaN     NaN       NaN                1       NaN
# 4      NaN        NaN         1     NaN       NaN              NaN       NaN
#
#       ...       School  Shopping  With_friends_  With_family  Nothing  \
# 0     ...          NaN         1              1            1      NaN
# 1     ...          NaN         1            NaN            1      NaN
# 2     ...          NaN         1              1            1      NaN
# 3     ...            1         1              1          NaN      NaN
# 4     ...            1         1              1            1      NaN
#
#    Other.6  Physical.1  Sport.2  Music.1 Creative.1 Comm_fiar.1 Youth_group.1  \
# 0      NaN           1      NaN      NaN          1         NaN             1
# 1      NaN           1        1      NaN        NaN           1           NaN
# 2      NaN         NaN      NaN        1          1         NaN           NaN
# 3      NaN         NaN      NaN        1        NaN         NaN           NaN
# 4      NaN         NaN      NaN      NaN        NaN         NaN           NaN
#
#   Faith_group.1 Student_council.1  Community_interest.1  \
# 0           NaN                 1                   NaN
# 1           NaN               NaN                     1
# 2           NaN                 1                   NaN
# 3           NaN               NaN                   NaN
# 4           NaN               NaN                   NaN
#
#    Environmental_Volunter.1  Volunteering.1  Art.1  Culture.3  School.1  \
# 0                         1               1      1          1         1
# 1                       NaN             NaN    NaN          1         1
# 2                       NaN               1      1        NaN       NaN
# 3                       NaN             NaN    NaN        NaN       NaN
# 4                       NaN             NaN    NaN        NaN       NaN
#
#    Shopping.1  With_friends_.1  With_family.1 Nothing.1  Other.7  \
# 0         NaN              NaN            NaN       NaN      NaN
# 1         NaN              NaN            NaN       NaN      NaN
# 2         NaN              NaN            NaN       NaN      NaN
# 3         NaN              NaN              1       NaN      NaN
# 4         NaN              NaN            NaN       NaN      NaN
#
#    Not_interested  Time  Costs_too_much  Can't_afford  No_friends  \
# 0             NaN   NaN               1             1           1
# 1             NaN   NaN               1           NaN           1
# 2             NaN   NaN               1           NaN         NaN
# 3             NaN   NaN             NaN           NaN         NaN
# 4               1     1             NaN           NaN         NaN
#
#    not_available  Cant_get_there  Shy  Other_responsibility  Parents_say_no  \
# 0            NaN               1    1                   NaN               1
# 1            NaN             NaN  NaN                   NaN             NaN
# 2              1             NaN    1                   NaN               1
# 3              1             NaN  NaN                   NaN             NaN
# 4            NaN             NaN  NaN                   NaN             NaN
#
#    Don't_know_how  Other.8  Internet  Church.1  School.2  Newspaper  WINZ  \
# 0               1      NaN       NaN       NaN         1          1   NaN
# 1             NaN      NaN       NaN       NaN         1          1   NaN
# 2             NaN      NaN       NaN       NaN         1        NaN   NaN
# 3             NaN  no time       NaN       NaN         1        NaN   NaN
# 4             NaN      NaN       NaN       NaN       NaN        NaN   NaN
#
#    Library.1  Youth_group.2  Mail  Txt  800  Other.9 Eastside_youth_council  \
# 0        NaN            NaN   NaN  NaN  NaN      NaN                      Y
# 1          1            NaN     1  NaN  NaN   whanau                      Y
# 2        NaN            NaN     1  NaN  NaN      NaN                      N
# 3        NaN            NaN   NaN  NaN    1      NaN                      Y
# 4        NaN              1   NaN  NaN    1      NaN                      Y
#
#      Ethnicity
# 0   Maori
# 1   Maori
# 2   Maori
# 3   Maori
# 4   Cook_Is
#
# [5 rows x 169 columns]

# %%
Ethnic_dist = df.Ethnicity.value_counts()
pd.Series(df.Ethnicity.ravel()).unique()
# Out:
# array([' Maori     ', ' Cook_Is   ', 'NZEuro      ', 'Multiple',
#        ' Samoan    ', nan, ' Chinese ', ' Indian', ' Tongan  '], dtype=object)

# %%
Ethnic_dist
# Out:
# NZEuro          440
#  Maori          201
# Multiple        131
#  Cook_Is         11
#  Indian          10
#  Chinese          6
#  Samoan           2
#  Tongan           2
# dtype: int64

# %%
Standard_background()
Ethnic_dist.plot(kind='pie',table=True,label='$Ethnic \ Distribution$',fontsize=16)

# %%
N = Ethnic_dist.count()
ind = np.arange(N)  # the x locations for the groups
width = .8       # the width of the bars
f = plt.figure()#facecolor=".9")
ax = f.add_subplot(111)#, axisbg="#F4EAEA")
rects1 = ax.bar(ind, Ethnic_dist.values[0:N], width, color='purple')

# add some text for labels, title and axes ticks
ax.set_ylabel('$Frequency$',fontsize=14)
ax.set_title('$Ethnic \ Distribution$',fontsize=20)
ax.set_xticks(ind+width/3)
xtickNames = ax.set_xticklabels( pd.Series(df.Ethnicity.ravel()).unique() )
plt.setp(xtickNames, rotation=75, fontsize=14)
def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')

autolabel(rects1)
plt.grid(True)
plt.show()

# %%
Standard_background()
df.IWI.value_counts()[df.IWI.value_counts() >3].plot(kind='bar',color='purple')

# %%
#List of who was left out -- 85 in total
df.IWI.value_counts()[df.IWI.value_counts() <4]
# Out:
# Ngai Tahu                                              2
# Te Whanau a Apanui                                     2
# Ngati Whakuae                                          2
# Ngati Raukawa                                          2
# Ngai Tuhoe                                             2
# Ngati kahunungu                                        1
# Ngapuhi/ Tuhourangi                                    1
# Te Whakatohea                                          1
# Ruatahuna                                              1
# Ngati Kahugunu/ Ngati Porou                            1
#                                                       ..
# Ngati kahungunu                                        1
# Ngati Pikiao/ Ngai Tahu, Ngati Awa, Whanau a Apanui    1
# Ngati Pikiao/Ngati Whakaue Te Arawa                    1
# Te Arawa/ touwharetoa                                  1
# Ngati porou, ngapuhi, tainui                           1
# Te Arawa/ Tuhourangi/ Nga Puhi                         1
# Te whanau-a-apanui                                     1
# Te Arawa, Rongowhakata                                 1
# Nga Te Rangi                                           1
# Ngai Tuhoe, Ngati Pikiao                               1
# dtype: int64

# %% [markdown]
# ### Schools

# %%
schools =df.ix[:,'Whangamarino':'Mokoia'].count()#*866
schools.values
# Out:
# array([ 45,  37, 432,  43,   0,  60,   0, 212])

# %%
N = schools.count()
ind = np.arange(N)  # the x locations for the groups
width = .8       # the width of the bars
f = plt.figure()#facecolor=".9")
ax = f.add_subplot(111)#, axisbg="#F4EAEA")
rects1 = ax.bar(ind, schools.values[0:N], width, color='purple')

# add some text for labels, title and axes ticks
ax.set_ylabel('$Frequency$',fontsize=16)
ax.set_title('$School \ Distribution$',fontsize=20)
ax.set_xticks(ind+width/3)
xtickNames = ax.set_xticklabels( schools.keys() )
plt.setp(xtickNames, rotation=75, fontsize=16)
def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')

autolabel(rects1)
plt.grid(True)
plt.show()

# %%
table = pd.pivot_table(df, values=['Whangamarino','Rotokawa','RLHS','Ohwata','Rotoma','Lynmore','Ruamata','Mokoia'],
                       index=['Gender_(M/F)','Ethnicity'], aggfunc=np.sum)
table = table.fillna(0).copy()
table
# Out:
#                            Lynmore  Mokoia  Ohwata  RLHS  Rotokawa  Rotoma  \
# Gender_(M/F) Ethnicity
# F             Chinese            0       0       0     2         0       0
#               Cook_Is            0       2       2     1         0       0
#               Indian             2       1       0     1         0       0
#               Maori              4      13      11    46         4       0
#               Samoan             0       0       0     1         0       0
#              Multiple            5      11       2    36         5       0
#              NZEuro             20      60       7   123         5       0
# M             Chinese            0       1       0     3         0       0
#               Cook_Is            0       1       3     2         0       0
#               Indian             2       0       0     4         0       0
#               Maori              1      19       8    34         5       0
#               Samoan             0       0       1     0         0       0
#               Tongan             0       1       0     1         0       0
#              Multiple            3      17       7    23        11       0
#              NZEuro             11      73       2   126         6       0
#
#                            Ruamata  Whangamarino
# Gender_(M/F) Ethnicity
# F             Chinese            0             0
#               Cook_Is            0             0
#               Indian             0             0
#               Maori              0            19
#               Samoan             0             0
#              Multiple            0             2
#              NZEuro              0             2
# M             Chinese            0             0
#               Cook_Is            0             0
#               Indian             0             0
#               Maori              0            15
#               Samoan             0             0
#               Tongan             0             0
#              Multiple            0             1
#              NZEuro              0             4

# %%
table.sum(axis=1)
# Out:
# Gender_(M/F)  Ethnicity
# F              Chinese          2
#                Cook_Is          5
#                Indian           4
#                Maori           97
#                Samoan           1
#               Multiple         61
#               NZEuro          217
# M              Chinese          4
#                Cook_Is          6
#                Indian           6
#                Maori           82
#                Samoan           1
#                Tongan           2
#               Multiple         62
#               NZEuro          222
# dtype: float64

# %% [markdown]
# ### Transport

# %%
#Percentage use of transport
Trans = df.loc[:,'Bus':'Other.1'].count()/len(df.index)*100
Trans.count(), Trans.values[0:10], Trans.keys()
# Out:
# (10, array([ 22.97921478,   0.46189376,   1.9630485 ,  68.2448037 ,
#          41.91685912,  19.28406467,   1.61662818,   0.11547344,
#           3.926097  ,   1.15473441]), Index([        u'Bus', u'Rollerblade',  u'Skateboard',         u'Car',
#            u'Walk/run',        u'Bike',   u'Motorbike',        u'Taxi',
#             u'Scooter',     u'Other.1'],
#        dtype='object'))

# %%
Make_bar(Trans.count(),Trans.values[0:Trans.count()],Trans.keys(),'$Transport$','$Frequency$')

# %% [markdown]
# ### Family

# %%
#split this by schools, ONE PER SCHOOL
temp = df.groupby('School')
temp.describe()
# Out:
#                     800        Age    Aquatic  Art  Art.1  B_Ball  Bike  \
# School
# 1.0          count    0   1.000000   1.000000    1      0       0     0
#              mean   NaN  13.000000   2.000000    1    NaN     NaN   NaN
#              std    NaN        NaN        NaN  NaN    NaN     NaN   NaN
#              min    NaN  13.000000   2.000000    1    NaN     NaN   NaN
#              25%    NaN  13.000000   2.000000    1    NaN     NaN   NaN
#              50%    NaN  13.000000   2.000000    1    NaN     NaN   NaN
#              75%    NaN  13.000000   2.000000    1    NaN     NaN   NaN
#              max    NaN  13.000000   2.000000    1    NaN     NaN   NaN
# Lynmore      count    2  58.000000   0.000000   21     20       0    12
#              mean     1   9.965517        NaN    1      1     NaN     1
# ...                 ...        ...        ...  ...    ...     ...   ...
# Rotokawa     75%      1  10.000000        NaN    1      1       1     1
#              max      1  10.000000        NaN    1      1       1     1
# Whangamarino count    2  43.000000  11.000000    7      3      22     4
#              mean     1  10.255814   2.909091    1      1       1     1
#              std      0   1.255332   1.375103    0      0       0     0
#              min      1   8.000000   1.000000    1      1       1     1
#              25%      1   9.500000   2.000000    1      1       1     1
#              50%      1  10.000000   3.000000    1      1       1     1
#              75%      1  11.000000   3.500000    1      1       1     1
#              max      1  12.000000   6.000000    1      1       1     1
#
#                     Bootcamp  Bullying  Bullying.1  Bus  Can't_afford  \
# School
# 1.0          count         0         0           1    1             0
#              mean        NaN       NaN           1    1           NaN
#              std         NaN       NaN         NaN  NaN           NaN
#              min         NaN       NaN           1    1           NaN
#              25%         NaN       NaN           1    1           NaN
#              50%         NaN       NaN           1    1           NaN
#              75%         NaN       NaN           1    1           NaN
#              max         NaN       NaN           1    1           NaN
# Lynmore      count         0        16          23    1            10
#              mean        NaN         1           1    1             1
# ...                      ...       ...         ...  ...           ...
# Rotokawa     75%           1         1           1    1             1
#              max           1         1           1    1             1
# Whangamarino count         9        16          18   31             2
#              mean          1         1           1    1             1
#              std           0         0           0    0             0
#              min           1         1           1    1             1
#              25%           1         1           1    1             1
#              50%           1         1           1    1             1
#              75%           1         1           1    1             1
#              max           1         1           1    1             1
#
#                     Cant_get_there  Car  Central_City  Chinese     Church  \
# School
# 1.0          count               0    1      1.000000        0   1.000000
#              mean              NaN    1      5.000000      NaN   5.000000
#              std               NaN  NaN           NaN      NaN        NaN
#              min               NaN    1      5.000000      NaN   5.000000
#              25%               NaN    1      5.000000      NaN   5.000000
#              50%               NaN    1      5.000000      NaN   5.000000
#              75%               NaN    1      5.000000      NaN   5.000000
#              max               NaN    1      5.000000      NaN   5.000000
# Lynmore      count               8   48      0.000000        0   0.000000
#              mean                1    1           NaN      NaN        NaN
# ...                            ...  ...           ...      ...        ...
# Rotokawa     75%                 1    1           NaN      NaN        NaN
#              max                 1    1           NaN      NaN        NaN
# Whangamarino count               3   17      7.000000        0  11.000000
#              mean                1    1      3.714286      NaN   4.636364
#              std                 0    0      1.704336      NaN   1.120065
#              min                 1    1      1.000000      NaN   2.000000
#              25%                 1    1      2.500000      NaN   5.000000
#              50%                 1    1      5.000000      NaN   5.000000
#              75%                 1    1      5.000000      NaN   5.000000
#              max                 1    1      5.000000      NaN   6.000000
#
#                     Church.1  City_Focus  Comm_fiar  Comm_fiar.1  \
# School
# 1.0          count         0    1.000000          1            0
#              mean        NaN    3.000000          1          NaN
#              std         NaN         NaN        NaN          NaN
#              min         NaN    3.000000          1          NaN
#              25%         NaN    3.000000          1          NaN
#              50%         NaN    3.000000          1          NaN
#              75%         NaN    3.000000          1          NaN
#              max         NaN    3.000000          1          NaN
# Lynmore      count         3    0.000000         10           12
#              mean          1         NaN          1            1
# ...                      ...         ...        ...          ...
# Rotokawa     75%         NaN         NaN          1            1
#              max         NaN         NaN          1            1
# Whangamarino count         0    9.000000          3            3
#              mean        NaN    3.666667          1            1
#              std         NaN    1.414214          0            0
#              min         NaN    2.000000          1            1
#              25%         NaN    2.000000          1            1
#              50%         NaN    4.000000          1            1
#              75%         NaN    5.000000          1            1
#              max         NaN    5.000000          1            1
#
#                     Community_interest  Community_interest.1  \
# School
# 1.0          count                   0                     0
#              mean                  NaN                   NaN
#              std                   NaN                   NaN
#              min                   NaN                   NaN
#              25%                   NaN                   NaN
#              50%                   NaN                   NaN
#              75%                   NaN                   NaN
#              max                   NaN                   NaN
# Lynmore      count                   2                     7
#              mean                    1                     1
# ...                                ...                   ...
# Rotokawa     75%                   NaN                     1
#              max                   NaN                     1
# Whangamarino count                   2                     1
#              mean                    1                     1
#              std                     0                   NaN
#              min                     1                     1
#              25%                     1                     1
#              50%                     1                     1
#              75%                     1                     1
#              max                     1                     1
#
#                     Convention_centre  Cook_Is  Costs_too_much  Creative  \
# School
# 1.0          count           1.000000        0               0         1
#              mean            3.000000      NaN             NaN         1
#              std                  NaN      NaN             NaN       NaN
#              min             3.000000      NaN             NaN         1
#              25%             3.000000      NaN             NaN         1
#              50%             3.000000      NaN             NaN         1
#              75%             3.000000      NaN             NaN         1
#              max             3.000000      NaN             NaN         1
# Lynmore      count           0.000000        4              16         9
#              mean                 NaN        1               1         1
# ...                               ...      ...             ...       ...
# Rotokawa     75%                  NaN        1               1         1
#              max                  NaN        1               1         1
# Whangamarino count          11.000000        0               0         3
#              mean            3.727273      NaN             NaN         1
#              std             1.348400      NaN             NaN         0
#              min             1.000000      NaN             NaN         1
#              25%             3.000000      NaN             NaN         1
#              50%             4.000000      NaN             NaN         1
#              75%             4.500000      NaN             NaN         1
#              max             6.000000      NaN             NaN         1
#
#                     Creative.1  Culture  Culture.1  Culture.2  Culture.3  D&A  \
# School
# 1.0          count           0        0          0          0          0    0
#              mean          NaN      NaN        NaN        NaN        NaN  NaN
#              std           NaN      NaN        NaN        NaN        NaN  NaN
#              min           NaN      NaN        NaN        NaN        NaN  NaN
#              25%           NaN      NaN        NaN        NaN        NaN  NaN
#              50%           NaN      NaN        NaN        NaN        NaN  NaN
#              75%           NaN      NaN        NaN        NaN        NaN  NaN
#              max           NaN      NaN        NaN        NaN        NaN  NaN
# Lynmore      count          17        3          3          8         14    8
#              mean            1        1          1          1          1    1
# ...                        ...      ...        ...        ...        ...  ...
# Rotokawa     75%             1        1          1          1          1    1
#              max             1        1          1          1          1    1
# Whangamarino count           1        1          2          2          2    5
#              mean            1        1          1          1          1    1
#              std           NaN      NaN          0          0          0    0
#              min             1        1          1          1          1    1
#              25%             1        1          1          1          1    1
#              50%             1        1          1          1          1    1
#              75%             1        1          1          1          1    1
#              max             1        1          1          1          1    1
#
#                     D&A.1  Dance_off  Don't_know_how  Education  \
# School
# 1.0          count      0          0               0          1
#              mean     NaN        NaN             NaN          1
#              std      NaN        NaN             NaN        NaN
#              min      NaN        NaN             NaN          1
#              25%      NaN        NaN             NaN          1
#              50%      NaN        NaN             NaN          1
#              75%      NaN        NaN             NaN          1
#              max      NaN        NaN             NaN          1
# Lynmore      count     11          0              18         12
#              mean       1        NaN               1          1
# ...                   ...        ...             ...        ...
# Rotokawa     75%        1          1               1          1
#              max        1          1               1          1
# Whangamarino count      9          7               3          3
#              mean       1          1               1          1
#              std        0          0               0          0
#              min        1          1               1          1
#              25%        1          1               1          1
#              50%        1          1               1          1
#              75%        1          1               1          1
#              max        1          1               1          1
#
#                     Environmental_Volunter  Environmental_Volunter.1  \
# School
# 1.0          count                       1                         0
#              mean                        1                       NaN
#              std                       NaN                       NaN
#              min                         1                       NaN
#              25%                         1                       NaN
#              50%                         1                       NaN
#              75%                         1                       NaN
#              max                         1                       NaN
# Lynmore      count                       8                        15
#              mean                        1                         1
# ...                                    ...                       ...
# Rotokawa     75%                         1                         1
#              max                         1                         1
# Whangamarino count                       3                         1
#              mean                        1                         1
#              std                         0                       NaN
#              min                         1                         1
#              25%                         1                         1
#              50%                         1                         1
#              75%                         1                         1
#              max                         1                         1
#
#                     Events_centre  Faith_group  Faith_group.1  Family  \
# School
# 1.0          count       1.000000            0              0       0
#              mean        3.000000          NaN            NaN     NaN
#              std              NaN          NaN            NaN     NaN
#              min         3.000000          NaN            NaN     NaN
#              25%         3.000000          NaN            NaN     NaN
#              50%         3.000000          NaN            NaN     NaN
#              75%         3.000000          NaN            NaN     NaN
#              max         3.000000          NaN            NaN     NaN
# Lynmore      count       0.000000           10              3      32
#              mean             NaN            1              1       1
# ...                           ...          ...            ...     ...
# Rotokawa     75%              NaN            1              1       1
#              max              NaN            1              1       1
# Whangamarino count      11.000000            3              1      37
#              mean        3.727273            1              1       1
#              std         1.489356            0            NaN       0
#              min         1.000000            1              1       1
#              25%         3.000000            1              1       1
#              50%         4.000000            1              1       1
#              75%         5.000000            1              1       1
#              max         6.000000            1              1       1
#
#                     Family.1  Family.2  Finding_a_job  Finding_job  \
# School
# 1.0          count         0         0              0            0
#              mean        NaN       NaN            NaN          NaN
#              std         NaN       NaN            NaN          NaN
#              min         NaN       NaN            NaN          NaN
#              25%         NaN       NaN            NaN          NaN
#              50%         NaN       NaN            NaN          NaN
#              75%         NaN       NaN            NaN          NaN
#              max         NaN       NaN            NaN          NaN
# Lynmore      count        16        11              0            2
#              mean          1         1            NaN            1
# ...                      ...       ...            ...          ...
# Rotokawa     75%           1         1            NaN            1
#              max           1         1            NaN            1
# Whangamarino count        17        14              0            1
#              mean          1         1            NaN            1
#              std           0         0            NaN          NaN
#              min           1         1            NaN            1
#              25%           1         1            NaN            1
#              50%           1         1            NaN            1
#              75%           1         1            NaN            1
#              max           1         1            NaN            1
#
#                     Finding_job.1  Fordlands  Friday      ...        Ripper  \
# School                                                    ...
# 1.0          count              0   1.000000       0      ...             0
#              mean             NaN   5.000000     NaN      ...           NaN
#              std              NaN        NaN     NaN      ...           NaN
#              min              NaN   5.000000     NaN      ...           NaN
#              25%              NaN   5.000000     NaN      ...           NaN
#              50%              NaN   5.000000     NaN      ...           NaN
#              75%              NaN   5.000000     NaN      ...           NaN
#              max              NaN   5.000000     NaN      ...           NaN
# Lynmore      count              9   0.000000       0      ...             0
#              mean               1        NaN     NaN      ...           NaN
# ...                           ...        ...     ...      ...           ...
# Rotokawa     75%                1        NaN       1      ...             1
#              max                1        NaN       1      ...             1
# Whangamarino count              0   7.000000      14      ...            15
#              mean             NaN   4.000000       1      ...             1
#              std              NaN   1.527525       0      ...             0
#              min              NaN   1.000000       1      ...             1
#              25%              NaN   3.500000       1      ...             1
#              50%              NaN   5.000000       1      ...             1
#              75%              NaN   5.000000       1      ...             1
#              max              NaN   5.000000       1      ...             1
#
#                     Rollerblade  Rotokawa  Rotoma  Ruamata  Saturday  \
# School
# 1.0          count            0         0       0        0         0
#              mean           NaN       NaN     NaN      NaN       NaN
#              std            NaN       NaN     NaN      NaN       NaN
#              min            NaN       NaN     NaN      NaN       NaN
#              25%            NaN       NaN     NaN      NaN       NaN
#              50%            NaN       NaN     NaN      NaN       NaN
#              75%            NaN       NaN     NaN      NaN       NaN
#              max            NaN       NaN     NaN      NaN       NaN
# Lynmore      count            0         0       0        0         0
#              mean           NaN       NaN     NaN      NaN       NaN
# ...                         ...       ...     ...      ...       ...
# Rotokawa     75%            NaN         1     NaN      NaN         1
#              max            NaN         1     NaN      NaN         1
# Whangamarino count            0         0       0        0        23
#              mean           NaN       NaN     NaN      NaN         1
#              std            NaN       NaN     NaN      NaN         0
#              min            NaN       NaN     NaN      NaN         1
#              25%            NaN       NaN     NaN      NaN         1
#              50%            NaN       NaN     NaN      NaN         1
#              75%            NaN       NaN     NaN      NaN         1
#              max            NaN       NaN     NaN      NaN         1
#
#                     School.1  School.2  Scooter  Shopping  Shopping.1  Shy  \
# School
# 1.0          count         0         1        0         1           0    0
#              mean        NaN         1      NaN         1         NaN  NaN
#              std         NaN       NaN      NaN       NaN         NaN  NaN
#              min         NaN         1      NaN         1         NaN  NaN
#              25%         NaN         1      NaN         1         NaN  NaN
#              50%         NaN         1      NaN         1         NaN  NaN
#              75%         NaN         1      NaN         1         NaN  NaN
#              max         NaN         1      NaN         1         NaN  NaN
# Lynmore      count        10        48        5        33           6   12
#              mean          1         1        1         1           1    1
# ...                      ...       ...      ...       ...         ...  ...
# Rotokawa     75%           1         1        1         1           1    1
#              max           1         1        1         1           1    1
# Whangamarino count         2        12        2         8           1    2
#              mean          1         1        1         1           1    1
#              std           0         0        0         0         NaN    0
#              min           1         1        1         1           1    1
#              25%           1         1        1         1           1    1
#              50%           1         1        1         1           1    1
#              75%           1         1        1         1           1    1
#              max           1         1        1         1           1    1
#
#                     Skateboard  Social_life_-_fun  Sport  Sport.1  Sport.2  \
# School
# 1.0          count           0                  0      0        1        0
#              mean          NaN                NaN    NaN        1      NaN
#              std           NaN                NaN    NaN      NaN      NaN
#              min           NaN                NaN    NaN        1      NaN
#              25%           NaN                NaN    NaN        1      NaN
#              50%           NaN                NaN    NaN        1      NaN
#              75%           NaN                NaN    NaN        1      NaN
#              max           NaN                NaN    NaN        1      NaN
# Lynmore      count           0                 10     12       44        8
#              mean          NaN                  1      1        1        1
# ...                        ...                ...    ...      ...      ...
# Rotokawa     75%             1                  1      1        1        1
#              max             1                  1      1        1        1
# Whangamarino count           1                  2      7        9        5
#              mean            1                  1      1        1        1
#              std           NaN                  0      0        0        0
#              min             1                  1      1        1        1
#              25%             1                  1      1        1        1
#              50%             1                  1      1        1        1
#              75%             1                  1      1        1        1
#              max             1                  1      1        1        1
#
#                     Sports_drom    Stadium  Student_council  \
# School
# 1.0          count     1.000000   1.000000                0
#              mean      4.000000   4.000000              NaN
#              std            NaN        NaN              NaN
#              min       4.000000   4.000000              NaN
#              25%       4.000000   4.000000              NaN
#              50%       4.000000   4.000000              NaN
#              75%       4.000000   4.000000              NaN
#              max       4.000000   4.000000              NaN
# Lynmore      count     0.000000   0.000000                5
#              mean           NaN        NaN                1
# ...                         ...        ...              ...
# Rotokawa     75%            NaN        NaN              NaN
#              max            NaN        NaN              NaN
# Whangamarino count    11.000000  11.000000                5
#              mean      3.818182   4.000000                1
#              std       1.601136   1.414214                0
#              min       1.000000   1.000000                1
#              25%       2.500000   3.500000                1
#              50%       4.000000   5.000000                1
#              75%       5.000000   5.000000                1
#              max       6.000000   5.000000                1
#
#                     Student_council.1  Sunday  T_Ball  Taxi  Thursday  Time  \
# School
# 1.0          count                  1       0       0     0         0     0
#              mean                   1     NaN     NaN   NaN       NaN   NaN
#              std                  NaN     NaN     NaN   NaN       NaN   NaN
#              min                    1     NaN     NaN   NaN       NaN   NaN
#              25%                    1     NaN     NaN   NaN       NaN   NaN
#              50%                    1     NaN     NaN   NaN       NaN   NaN
#              75%                    1     NaN     NaN   NaN       NaN   NaN
#              max                    1     NaN     NaN   NaN       NaN   NaN
# Lynmore      count                 26       0       0     0         0    17
#              mean                   1     NaN     NaN   NaN       NaN     1
# ...                               ...     ...     ...   ...       ...   ...
# Rotokawa     75%                    1       1       1   NaN         1     1
#              max                    1       1       1   NaN         1     1
# Whangamarino count                  1      14       8     1        16     2
#              mean                   1       1       1     1         1     1
#              std                  NaN       0       0   NaN         0     0
#              min                    1       1       1     1         1     1
#              25%                    1       1       1     1         1     1
#              50%                    1       1       1     1         1     1
#              75%                    1       1       1     1         1     1
#              max                    1       1       1     1         1     1
#
#                     Tongan  Tuesday  Txt  Violence  Violence.1  Volleyball  \
# School
# 1.0          count       0        0    0         0           0           0
#              mean      NaN      NaN  NaN       NaN         NaN         NaN
#              std       NaN      NaN  NaN       NaN         NaN         NaN
#              min       NaN      NaN  NaN       NaN         NaN         NaN
#              25%       NaN      NaN  NaN       NaN         NaN         NaN
#              50%       NaN      NaN  NaN       NaN         NaN         NaN
#              75%       NaN      NaN  NaN       NaN         NaN         NaN
#              max       NaN      NaN  NaN       NaN         NaN         NaN
# Lynmore      count       0        0   16        14          17           0
#              mean      NaN      NaN    1         1           1         NaN
# ...                    ...      ...  ...       ...         ...         ...
# Rotokawa     75%       NaN        1    1         1           1           1
#              max       NaN        1    1         1           1           1
# Whangamarino count       0       14    5        10          13           6
#              mean      NaN        1    1         1           1           1
#              std       NaN        0    0         0           0           0
#              min       NaN        1    1         1           1           1
#              25%       NaN        1    1         1           1           1
#              50%       NaN        1    1         1           1           1
#              75%       NaN        1    1         1           1           1
#              max       NaN        1    1         1           1           1
#
#                     Volunteering  Volunteering.1  WINZ  W_Heights  Walk/run  \
# School
# 1.0          count             0               1     0    1.00000         0
#              mean            NaN               1   NaN    5.00000       NaN
#              std             NaN             NaN   NaN        NaN       NaN
#              min             NaN               1   NaN    5.00000       NaN
#              25%             NaN               1   NaN    5.00000       NaN
#              50%             NaN               1   NaN    5.00000       NaN
#              75%             NaN               1   NaN    5.00000       NaN
#              max             NaN               1   NaN    5.00000       NaN
# Lynmore      count            10              17     4    0.00000        22
#              mean              1               1     1        NaN         1
# ...                          ...             ...   ...        ...       ...
# Rotokawa     75%               1               1   NaN        NaN         1
#              max               1               1   NaN        NaN         1
# Whangamarino count             4               3     0    8.00000         6
#              mean              1               1   NaN    4.50000         1
#              std               0               0   NaN    0.92582         0
#              min               1               1   NaN    3.00000         1
#              25%               1               1   NaN    4.50000         1
#              50%               1               1   NaN    5.00000         1
#              75%               1               1   NaN    5.00000         1
#              max               1               1   NaN    5.00000         1
#
#                     Wednesday  Whangamarino  With_family  With_family.1  \
# School
# 1.0          count          0             0            1              0
#              mean         NaN           NaN            1            NaN
#              std          NaN           NaN          NaN            NaN
#              min          NaN           NaN            1            NaN
#              25%          NaN           NaN            1            NaN
#              50%          NaN           NaN            1            NaN
#              75%          NaN           NaN            1            NaN
#              max          NaN           NaN            1            NaN
# Lynmore      count          0             0           44              5
#              mean         NaN           NaN            1              1
# ...                       ...           ...          ...            ...
# Rotokawa     75%            1           NaN            1              1
#              max            1           NaN            1              1
# Whangamarino count         13            44            9              1
#              mean           1             1            1              1
#              std            0             0            0            NaN
#              min            1             1            1              1
#              25%            1             1            1              1
#              50%            1             1            1              1
#              75%            1             1            1              1
#              max            1             1            1              1
#
#                     With_friends_  With_friends_.1  Youth_centre  Youth_group  \
# School
# 1.0          count              1                0      1.000000            0
#              mean               1              NaN      4.000000          NaN
#              std              NaN              NaN           NaN          NaN
#              min                1              NaN      4.000000          NaN
#              25%                1              NaN      4.000000          NaN
#              50%                1              NaN      4.000000          NaN
#              75%                1              NaN      4.000000          NaN
#              max                1              NaN      4.000000          NaN
# Lynmore      count             45                7      0.000000            5
#              mean               1                1           NaN            1
# ...                           ...              ...           ...          ...
# Rotokawa     75%                1                1           NaN            1
#              max                1                1           NaN            1
# Whangamarino count              8                1     11.000000            3
#              mean               1                1      4.000000            1
#              std                0              NaN      1.549193            0
#              min                1                1      2.000000            1
#              25%                1                1      2.500000            1
#              50%                1                1      4.000000            1
#              75%                1                1      5.000000            1
#              max                1                1      6.000000            1
#
#                     Youth_group.1  Youth_group.2  Youth_health  Zumba  \
# School
# 1.0          count              0              0      1.000000      0
#              mean             NaN            NaN      4.000000    NaN
#              std              NaN            NaN           NaN    NaN
#              min              NaN            NaN      4.000000    NaN
#              25%              NaN            NaN      4.000000    NaN
#              50%              NaN            NaN      4.000000    NaN
#              75%              NaN            NaN      4.000000    NaN
#              max              NaN            NaN      4.000000    NaN
# Lynmore      count             12              1      0.000000      0
#              mean               1              1           NaN    NaN
# ...                           ...            ...           ...    ...
# Rotokawa     75%                1            NaN           NaN      1
#              max                1            NaN           NaN      1
# Whangamarino count              3              1     11.000000      4
#              mean               1              1      4.727273      1
#              std                0            NaN      0.786245      0
#              min                1              1      3.000000      1
#              25%                1              1      4.500000      1
#              50%                1              1      5.000000      1
#              75%                1              1      5.000000      1
#              max                1              1      6.000000      1
#
#                     not_available
# School
# 1.0          count              0
#              mean             NaN
#              std              NaN
#              min              NaN
#              25%              NaN
#              50%              NaN
#              75%              NaN
#              max              NaN
# Lynmore      count              8
#              mean               1
# ...                           ...
# Rotokawa     75%                1
#              max                1
# Whangamarino count              3
#              mean               1
#              std                0
#              min                1
#              25%                1
#              50%                1
#              75%                1
#              max                1
#
# [56 rows x 149 columns]

# %%
#Percentage 
Fam = df.loc[:,'Family':'Other.2'].count()/len(df.index)*100
Fam
# Out:
# Family               46.651270
# Education            27.944573
# Friends              12.009238
# My_job/work           2.771363
# Finding_a_job         3.810624
# Social_life_-_fun    10.508083
# Money_making          7.043880
# Interests/hobbies     9.353349
# Sport                15.011547
# Other.2               3.810624
# dtype: float64

# %%
Make_bar(Fam.count(),Fam.values[0:Fam.count()],Fam.keys(),'$Family\ and\ other\ issues$', '$Percentage$')

# %% [markdown]
# ### Concerns

# %%
#Create df for each school
df_Lyn = df[df.Lynmore == 1]
df_Whang = df[df.Whangamarino == 1]
df_Rotokawa = df[df.Rotokawa == 1]
df_lhs = df[df.RLHS == 1]
df_Owha = df[df.Owhata == 1]
df_Rotoma = df[df.Rotoma == 1]
df_Ruamata = df[df.Ruamata == 1]
df_Mokoia = df[df.Mokoia == 1]
df_Mokoia.describe()
# Out:
#               Age  NZEuro  Cook_Is  Tongan  Niuean  Chinese  Indian  \
# count  206.000000     160        6       1       0        1       1
# mean    11.330097       1        1       1     NaN        1       1
# std      0.630731       0        0     NaN     NaN      NaN     NaN
# min     10.000000       1        1       1     NaN        1       1
# 25%     11.000000       1        1       1     NaN        1       1
# 50%     11.000000       1        1       1     NaN        1       1
# 75%     12.000000       1        1       1     NaN        1       1
# max     14.000000       1        1       1     NaN        1       1
#
#        Whangamarino  Rotokawa  RLHS  Owhata  Rotoma  Lynmore  Ruamata  Mokoia  \
# count             0         0     0       0       0        0        0     212
# mean            NaN       NaN   NaN     NaN     NaN      NaN      NaN       1
# std             NaN       NaN   NaN     NaN     NaN      NaN      NaN       0
# min             NaN       NaN   NaN     NaN     NaN      NaN      NaN       1
# 25%             NaN       NaN   NaN     NaN     NaN      NaN      NaN       1
# 50%             NaN       NaN   NaN     NaN     NaN      NaN      NaN       1
# 75%             NaN       NaN   NaN     NaN     NaN      NaN      NaN       1
# max             NaN       NaN   NaN     NaN     NaN      NaN      NaN       1
#
#        Bus  Rollerblade  Skateboard  Car  Walk/run  Bike  Motorbike  Taxi  \
# count   19            4           5  160        87    70          4     0
# mean     1            1           1    1         1     1          1   NaN
# std      0            0           0    0         0     0          0   NaN
# min      1            1           1    1         1     1          1   NaN
# 25%      1            1           1    1         1     1          1   NaN
# 50%      1            1           1    1         1     1          1   NaN
# 75%      1            1           1    1         1     1          1   NaN
# max      1            1           1    1         1     1          1   NaN
#
#        Scooter  Family  Education  Friends  My_job/work  Finding_a_job  \
# count       18     111         30       14            4              5
# mean         1       1          1        1            1              1
# std          0       0          0        0            0              0
# min          1       1          1        1            1              1
# 25%          1       1          1        1            1              1
# 50%          1       1          1        1            1              1
# 75%          1       1          1        1            1              1
# max          1       1          1        1            1              1
#
#        Social_life_-_fun  Money_making  Interests/hobbies  Sport  Lonely  \
# count                 29            12                 19     25      43
# mean                   1             1                  1      1       1
# std                    0             0                  0      0       0
# min                    1             1                  1      1       1
# 25%                    1             1                  1      1       1
# 50%                    1             1                  1      1       1
# 75%                    1             1                  1      1       1
# max                    1             1                  1      1       1
#
#        Relationships  Grades  D&A  Bullying  Lack_of_money  Violence  \
# count             25      66   22        64             28        41
# mean               1       1    1         1              1         1
# std                0       0    0         0              0         0
# min                1       1    1         1              1         1
# 25%                1       1    1         1              1         1
# 50%                1       1    1         1              1         1
# 75%                1       1    1         1              1         1
# max                1       1    1         1              1         1
#
#        Finding_job  Identity  Culture  Friends.1  Family.1  Lonely.1  \
# count           11        12        7         35        68        49
# mean             1         1        1          1         1         1
# std              0         0        0          0         0         0
# min              1         1        1          1         1         1
# 25%              1         1        1          1         1         1
# 50%              1         1        1          1         1         1
# 75%              1         1        1          1         1         1
# max              1         1        1          1         1         1
#
#        Relationships.1  Grades.1  D&A.1  Bullying.1 ...   Comm_fiar  \
# count               27        35     91         112 ...          26
# mean                 1         1      1           1 ...           1
# std                  0         0      0           0 ...           0
# min                  1         1      1           1 ...           1
# 25%                  1         1      1           1 ...           1
# 50%                  1         1      1           1 ...           1
# 75%                  1         1      1           1 ...           1
# max                  1         1      1           1 ...           1
#
#        Youth_group  Faith_group  Student_council  Community_interest  \
# count            9           16               25                   9
# mean             1            1                1                   1
# std              0            0                0                   0
# min              1            1                1                   1
# 25%              1            1                1                   1
# 50%              1            1                1                   1
# 75%              1            1                1                   1
# max              1            1                1                   1
#
#        Environmental_Volunter  Volunteering  Art  Culture.2    Shopping  \
# count                      26            22   53         18  117.000000
# mean                        1             1    1          1    1.017094
# std                         0             0    0          0    0.184900
# min                         1             1    1          1    1.000000
# 25%                         1             1    1          1    1.000000
# 50%                         1             1    1          1    1.000000
# 75%                         1             1    1          1    1.000000
# max                         1             1    1          1    3.000000
#
#        With_friends_  With_family  Physical.1  Sport.2  Music.1  Creative.1  \
# count     164.000000          160          14       39       49          44
# mean        1.012195            1           1        1        1           1
# std         0.156174            0           0        0        0           0
# min         1.000000            1           1        1        1           1
# 25%         1.000000            1           1        1        1           1
# 50%         1.000000            1           1        1        1           1
# 75%         1.000000            1           1        1        1           1
# max         3.000000            1           1        1        1           1
#
#        Comm_fiar.1  Youth_group.1  Faith_group.1  Student_council.1  \
# count           25             22              9                 45
# mean             1              1              1                  1
# std              0              0              0                  0
# min              1              1              1                  1
# 25%              1              1              1                  1
# 50%              1              1              1                  1
# 75%              1              1              1                  1
# max              1              1              1                  1
#
#        Community_interest.1  Environmental_Volunter.1  Volunteering.1  Art.1  \
# count                    10                        29              35     66
# mean                      1                         1               1      1
# std                       0                         0               0      0
# min                       1                         1               1      1
# 25%                       1                         1               1      1
# 50%                       1                         1               1      1
# 75%                       1                         1               1      1
# max                       1                         1               1      1
#
#        Culture.3  School.1  Shopping.1  With_friends_.1  With_family.1  \
# count         27        20          20               17             12
# mean           1         1           1                1              1
# std            0         0           0                0              0
# min            1         1           1                1              1
# 25%            1         1           1                1              1
# 50%            1         1           1                1              1
# 75%            1         1           1                1              1
# max            1         1           1                1              1
#
#        Not_interested  Time  Costs_too_much  Can't_afford  No_friends  \
# count              63    51              53     35.000000          46
# mean                1     1               1      1.057143           1
# std                 0     0               0      0.338062           0
# min                 1     1               1      1.000000           1
# 25%                 1     1               1      1.000000           1
# 50%                 1     1               1      1.000000           1
# 75%                 1     1               1      1.000000           1
# max                 1     1               1      3.000000           1
#
#        not_available  Cant_get_there  Shy  Other_responsibility  \
# count             33              30   48                    66
# mean               1               1    1                     1
# std                0               0    0                     0
# min                1               1    1                     1
# 25%                1               1    1                     1
# 50%                1               1    1                     1
# 75%                1               1    1                     1
# max                1               1    1                     1
#
#        Parents_say_no  Don't_know_how  Internet  Church.1  School.2  \
# count              29              48       135        10       148
# mean                1               1         1         1         1
# std                 0               0         0         0         0
# min                 1               1         1         1         1
# 25%                 1               1         1         1         1
# 50%                 1               1         1         1         1
# 75%                 1               1         1         1         1
# max                 1               1         1         1         1
#
#        Newspaper  WINZ  Library.1  Youth_group.2  Mail  Txt  800
# count  70.000000     5         25              6   102   61   13
# mean    1.142857     1          1              1     1    1    1
# std     1.195229     0          0              0     0    0    0
# min     1.000000     1          1              1     1    1    1
# 25%     1.000000     1          1              1     1    1    1
# 50%     1.000000     1          1              1     1    1    1
# 75%     1.000000     1          1              1     1    1    1
# max    11.000000     1          1              1     1    1    1
#
# [8 rows x 149 columns]

# %%
print 'The personal concerns raised were as a percentage of 418 RLHS participants:'
Concerns8 = df_lhs.loc[:,'Lonely':'Other.3'].count()/len(df_lhs.index)*100
print Concerns8
print
print 'The second rating of general concerns:'
Concerns9 = df_lhs.loc[:,'Lonely.1':'Other.4'].count()/len(df_lhs.index)*100
print Concerns9
Concerns_diff = Concerns8.sub(Concerns9.values)
# Out:
# The personal concerns raised were as a percentage of 418 RLHS participants:
# Lonely           14.120370
# Relationships    11.111111
# Grades           58.101852
# D&A               5.555556
# Bullying         14.583333
# Lack_of_money    13.657407
# Violence          8.101852
# Finding_job      10.648148
# Identity          2.777778
# Culture           1.851852
# Friends.1        12.962963
# Family.1         14.583333
# Other.3           4.861111
# dtype: float64
#
# The second rating of general concerns:
# Lonely.1            7.175926
# Relationships.1     9.259259
# Grades.1           16.435185
# D&A.1              53.935185
# Bullying.1         37.268519
# Lack_of_money.1    17.592593
# Violence.1         34.722222
# Finding_job.1      10.879630
# Identity.1          5.324074
# Culture.1           4.861111
# Friends.2           7.638889
# Family.2           11.805556
# Other.4             4.398148
# dtype: float64

# %%
#Concerns_diff.plot(kind='bar')
Make_bar(Concerns_diff.count(),Concerns_diff.values[0:Concerns_diff.count()],Concerns_diff.keys(),
         '$Personal - General \ Concerns$','Percentage change')

# %% [markdown]
# The above plot shows the differential between concerns that are personal to the youth compared to how that person rated general concerns. So, for example, $5$% rated drugs and alcohol as a personal issue. However, this was rated as a general issue by $54$%. This $-48$% difference indicates that more than half of youth perceive drugs and alcohol as a major issues where only $5$% rated it as personally impacting on them. Similarly, bullying and violence were also rated as more relevant than personally experienced. This probably indicates general concerns, perhaps some expectation and stereotyping.
#
# Conversely, school grades were rated as much more personally than generally concerning. So one might expect that this indicates an issue with personal self efficacy wherein youth feel grades, or the lack thereof, to be more applicable to themselves than to their peers. In any event, grades present a general concern for youth. The last differential of note was the issue of loneliness, with $14$% of youth rating themselves as feeling lonely, but with a perception that this was a slightly lesser issue for others. What is interesting is that the differential wasn't larger, suggesting that youth are aware of others being lonely. So the question arising is that where this impression is relatively accurate, that still the issue of loneliness persists. Being lonely and being aware of other lonely people doesn't appear to assist in changing anything.

# %%
#Insert breakdown of concerns by school, showing side by side bars for personal-v-general

# %% [markdown]
# ### Activities

# %%
print 'The activities undertaken as a percentage of 866 participants:'
activities =  df.loc[:,'Volleyball':'Other.5'].count()/len(df.index)*100
print activities
# Out:
# The activities undertaken as a percentage of 866 participants:
# Volleyball    25.057737
# Ki_orahi      11.200924
# T_Ball        21.478060
# Ripper        23.210162
# B_Ball        25.173210
# Zumba         18.591224
# Netball       18.475751
# Dance_off     15.819861
# Bootcamp      20.669746
# Other.5       17.321016
# dtype: float64

# %%
Standard_background()
activities.plot(kind='bar',color='purple',alpha=.7)

# %% [markdown]
# ### Days of the week

# %%
print 'The after school care as a percentage of 866 participants:'
print df.loc[:,'Monday':'Sunday'].count()/len(df.index)*100
# Out:
# The after school care as a percentage of 866 participants:
# Monday       27.829099
# Tuesday      23.787529
# Wednesday    24.826790
# Thursday     25.404157
# Friday       24.249423
# Saturday     24.711316
# Sunday       23.903002
# dtype: float64

# %% [markdown]
# ### Places visited

# %%
print 'The places visited as a  frequency rating (0-6) of 866 participants:'
places =  df.loc[:,'Library':'Stadium'].mean().round(2)
places
# Out:
# The places visited as a  frequency rating (0-6) of 866 participants:
# Library              3.80
# Aquatic              3.54
# City_Focus           3.63
# Redwoods             2.94
# Parks                3.02
# Lakes                2.60
# Night_market         4.06
# Museuem              4.10
# Youth_centre         4.86
# Youth_health         5.00
# Gym                  4.24
# Church               4.72
# Marae                4.47
# Events_centre        4.24
# Sports_drom          4.52
# Convention_centre    4.28
# Stadium              4.52
# dtype: float64

# %%
Standard_background()
df.loc[:,'Gym'].plot(kind='hist',color='purple', alpha=.7)

# %% [markdown]
# ### Parks?

# %%
print 'The parks visited as a mean frequency rating of 866 participants:'
print df.loc[:,'W_Heights':'Puketawhero'].mean().round(0)
YS_Y = (df.loc[:,'Youth_space?'] == 'Y').sum()
YS_N = (df.loc[:,'Youth_space?'] == 'N').sum()
print 'The number who wanted to have a youth space was',YS_Y,'where', YS_N,'said "No"'
print 'So {:.2f}% for "Y" and {:.2f}% said "N".'.format(YS_Y.sum()/760.*100,YS_N.sum()/760.*100)
# Out:
# The parks visited as a mean frequency rating of 866 participants:
# W_Heights       5
# Fordlands       5
# Central_City    5
# Ngong           5
# Puketawhero     5
# dtype: float64
# The number who wanted to have a youth space was 539 where 220 said "No"
# So 70.92% for "Y" and 28.95% said "N".

# %%
df.loc[:,'W_Heights':'Puketawhero'].plot(kind='hist')

# %%
#How does this vary over school?
table_youth_space = pd.pivot_table(df, values=['Whangamarino','Rotokawa','RLHS','Ohwata','Rotoma','Lynmore','Ruamata','Mokoia'],
                       columns=['Youth_space?'], aggfunc=np.sum)
table_youth_space = table_youth_space.fillna(0).copy()
#table_youth_space['Ratio']=table_youth_space['Y']/table_youth_space['N']
table_youth_space
# Out:
# Youth_space?    N    Y
# Lynmore        16   42
# Mokoia         49  161
# Ohwata          1   41
# RLHS          133  249
# Rotokawa        9   23
# Rotoma          0    0
# Ruamata         0    0
# Whangamarino    4   16

# %%
table_youth_space.plot(kind='bar')
plt.title('$Youth \ Space$',fontsize=20)

# %%
df.loc[:,'Youth_space?':'Rotaz?'].count()
# Out:
# Youth_space?    759
# Rotaz?          738
# dtype: int64

# %% [markdown]
# Youth space desire was generally viewed as a need by around $71$% but not as need by $29$% of youth. The ratio of those saying "Yes" to "No" to the questions was around $3:1$. However, for the $41$ youth in Owhata School responses, all bar one person indicated a need for a youth space.

# %% [markdown]
# ### Rotaz Card

# %%
Rotaz_Y = (df.loc[:,'Rotaz?'] == 'Y').sum()
Rotaz_N = (df.loc[:,'Rotaz?'] == 'N').sum()
print 'The number who knew about the Rotaz care was',Rotaz_Y,'where', Rotaz_N,'said "No"'
print 'So {:.2f}% for "Y" and {:.2f}% said "N".'.format(Rotaz_Y.sum()/738.*100,Rotaz_N.sum()/738.*100)
# Out:
# The number who knew about the Rotaz care was 293 where 444 said "No"
# So 39.70% for "Y" and 60.16% said "N".

# %% [markdown]
# ### Interests

# %%
print 'Current interests as a percentage of 866 participants:'
interests_A = df.loc[:,'Physical':'Other.6'].count()/len(df.index)*100
interests_A.name = ('Current Interests')
print interests_A
# Out:
# Current interests as a percentage of 866 participants:
# Physical                  45.150115
# Sport.1                   52.078522
# Music                     23.325635
# Creative                  14.318707
# Comm_fiar                 10.854503
# Youth_group                8.545035
# Faith_group                9.006928
# Student_council            6.351039
# Community_interest         2.540416
# Environmental_Volunter     6.812933
# Volunteering              11.085450
# Art                       22.748268
# Culture.2                  7.736721
# School                    25.635104
# Shopping                  42.263279
# With_friends_             68.475751
# With_family               59.930716
# Nothing                    8.429561
# Other.6                   10.508083
# Name: Current Interests, dtype: float64

# %%
print 'Interests they would like as a percentage of 866 participants:'
interests_B = df.loc[:,'Physical.1':'Other.7'].count()/len(df.index)*100
interests_B.name =('Desired interests')
print interests_B
# Out:
# Interests they would like as a percentage of 866 participants:
# Physical.1                  10.508083
# Sport.2                     16.743649
# Music.1                     17.321016
# Creative.1                  14.780600
# Comm_fiar.1                 10.508083
# Youth_group.1               11.547344
# Faith_group.1                4.157044
# Student_council.1           13.625866
# Community_interest.1         5.427252
# Environmental_Volunter.1    10.739030
# Volunteering.1              14.549654
# Art.1                       19.053118
# Culture.3                    8.314088
# School.1                     8.314088
# Shopping.1                   8.775982
# With_friends_.1              9.237875
# With_family.1                6.235566
# Nothing.1                   17.898383
# Other.7                      4.849885
# Name: Desired interests, dtype: float64

# %%
fig, axs = plt.subplots(1,2)
plt.title('$Youth \ interests$',fontsize=20,loc='left')
interests_A.plot(kind='bar',legend=True, alpha=.7,ax=axs[0])
interests_B.plot(kind='bar',color='g',legend=True, alpha=.7,ax=axs[1])

# %%
Standard_background()
interests_A.plot(kind='bar',legend=True, alpha=.7,position=0,width=.4,fontsize=14)
interests_B.plot(kind='bar',color='g',legend=True, alpha=.7,position=1,width=.4)
plt.title('$Change \ in \ interests$',fontsize=20)

# %%
interests_diff = interests_A.sub(interests_B.values)
Standard_background()
interests_diff, interests_diff.plot(kind='bar',alpha=.7,fontsize=14)
plt.title('$Change \ in \ interests \ from \ current \ to \ desired$',fontsize=20)

# %% [markdown]
# The above ratings were interesting for the fact that the ratings suggest youth want to involved LESS in half of the areas rated. For example, $45$% indicated current involvement with physical activity. However, only $11$% indicated that they wanted to be involved in physical activity. The same pattern was evident for Sport, Music, School ($17$%) Shopping, Hangin with friends and Hangin with Whanau/Family. There was a slight desire to be more involved with environmental and community spirit type activities. These responses were quite intriguing. Do they mean that youth are searching for activities with greater meaning than simply "fun" activities? It would be interesting and probably significant for organisations seeking to meet youth needs to question whether this finding represents inaccurate fundamental assumptions being made on their part about youth needs. A followup might be a focus group with high school youth to ask them what they think is going on with this result.

# %%
print 'Reasons as a percentage of 866 participants:'
print df.loc[:,'Not_interested':'Other.8'].count()/len(df.index)*100
print 'Reasons as a percentage of RLHS participants:'
print df_lhs.loc[:,'Not_interested':'Other.8'].count()/len(df_lhs.index)*100
# Out:
# Reasons as a percentage of 866 participants:
# Not_interested          27.598152
# Time                    22.863741
# Costs_too_much          16.859122
# Can't_afford            12.817552
# No_friends              21.247113
# not_available           13.856813
# Cant_get_there          14.780600
# Shy                     18.244804
# Other_responsibility    29.099307
# Parents_say_no          10.277136
# Don't_know_how          15.242494
# Other.8                  9.237875
# dtype: float64
# Reasons as a percentage of RLHS participants:
# Not_interested          34.259259
# Time                    26.157407
# Costs_too_much          12.962963
# Can't_afford            10.185185
# No_friends              22.453704
# not_available           13.194444
# Cant_get_there          16.666667
# Shy                     17.592593
# Other_responsibility    31.944444
# Parents_say_no           5.324074
# Don't_know_how          10.416667
# Other.8                 10.416667
# dtype: float64

# %% [markdown]
# Disinterest and time account for nearly half of the reason youth don't participate in activites. This matches the above impression of mismatching interest to activity. Cost is relevant for $29$% overall and for $22$% of high school youth. What changes for that $7$%? Are they youth with paid work?
#
# Lack of friends accounts for a $\frac{1}{5}$ of reasons youth cannot participate in desired activites.
#
# Shyness also accounts for just under $\frac{1}{5}$ of reasons youth cannot participate in activities they desire. It would be interesting to examine the extent to which this shyness really prevents participation, given a much lower epidemiology of clincial social phobia. Strategies to counteract shyness, a Positive Psychology approach, would probably also be worth considering, and of course would relate directly to making friends and reducing loneliness. It might also be a project linked to increasing self-efficacy given the $10-15$% of youth indicating that they don't know how to engage with desired activities.
#
# Is it worth examining for a difference between Owhata and the rest?

# %% [markdown]
# ### Information Sources

# %%
print 'Found out about it from... as a percentage of 866 participants:'
info_source = df.loc[:,'Internet':'Other.9'].count()/len(df.index)*100
Standard_background()
info_source, info_source.plot(kind='bar',alpha=.7)
# Out:
# Found out about it from... as a percentage of 866 participants:
# (Internet         53.579677
#  Church.1          3.695150
#  School.2         63.972286
#  Newspaper        27.713626
#  WINZ              1.847575
#  Library.1         9.815242
#  Youth_group.2     3.233256
#  Mail             30.831409
#  Txt              25.519630
#  800               5.080831
#  Other.9           9.122402
#  dtype: float64, <matplotlib.axes._subplots.AxesSubplot at 0x110780e90>)

# %% [markdown]
# ### Interest in Eastside Community Council

# %%
EYC_Y = (df.loc[:,'Eastside_youth_council'] == 'Y').sum()
EYC_N = (df.loc[:,'Eastside_youth_council'] == 'N').sum()
EYC_tot = float(EYC_Y + EYC_N)
print 'Interest in being on the EYC as a percentage of {:.0f} participants:'.format(EYC_tot)
print 'The number who wanted to have a youth space was',EYC_Y,'where', EYC_N,'said "No"'
print 'So {:.2f}% for "Y" and {:.2f}% said "N".'.format(EYC_Y/EYC_tot*100.,EYC_N/EYC_tot*100.)
# Out:
# Interest in being on the EYC as a percentage of 716 participants:
# The number who wanted to have a youth space was 201 where 515 said "No"
# So 28.07% for "Y" and 71.93% said "N".

# %%
def func_2(a, total=EYC_tot):
    return np.count_nonzero(a)/total*100
table2 = pd.pivot_table(df, values=['Eastside_youth_council'],#values=['Eastside_youth_council'],
                       columns=['Gender_(M/F)','Ethnicity'], aggfunc=count_nonzero)
table2 = table2.fillna(0).copy()
table2
# Out:
#                         Gender_(M/F)  Ethnicity
# Eastside_youth_council  F              Chinese          2
#                                        Cook_Is          5
#                                        Indian           4
#                                        Maori          111
#                                        Samoan           1
#                                       Multiple         64
#                                       NZEuro          216
#                         M              Chinese          4
#                                        Cook_Is          6
#                                        Indian           6
#                                        Maori           89
#                                        Samoan           1
#                                        Tongan           2
#                                       Multiple         65
#                                       NZEuro          222
# dtype: int64

# %%
df.columns.values.tolist()
# Out:
# [u'ID',
#  u'Age',
#  u'IWI',
#  u'Other',
#  u'Gender_(M/F)',
#  u'Local_Area',
#  u'Whangamarino',
#  u'Rotokawa',
#  u'RLHS',
#  u'Ohwata',
#  u'Rotoma',
#  u'Lynmore',
#  u'Ruamata',
#  u'Mokoia',
#  u'Bus',
#  u'Rollerblade',
#  u'Skateboard',
#  u'Car',
#  u'Walk/run',
#  u'Bike',
#  u'Motorbike',
#  u'Taxi',
#  u'Scooter',
#  u'Other.1',
#  u'Family',
#  u'Education',
#  u'Friends',
#  u'My_job/work',
#  u'Finding_a_job',
#  u'Social_life_-_fun',
#  u'Money_making',
#  u'Interests/hobbies',
#  u'Sport',
#  u'Other.2',
#  u'Lonely',
#  u'Relationships',
#  u'Grades',
#  u'D&A',
#  u'Bullying',
#  u'Lack_of_money',
#  u'Violence',
#  u'Finding_job',
#  u'Identity',
#  u'Culture',
#  u'Friends.1',
#  u'Family.1',
#  u'Other.3',
#  u'Lonely.1',
#  u'Relationships.1',
#  u'Grades.1',
#  u'D&A.1',
#  u'Bullying.1',
#  u'Lack_of_money.1',
#  u'Violence.1',
#  u'Finding_job.1',
#  u'Identity.1',
#  u'Culture.1',
#  u'Friends.2',
#  u'Family.2',
#  u'Other.4',
#  u'10._One_change',
#  u'3_best_things',
#  u'#2',
#  u'#3',
#  u'Volleyball',
#  u'Ki_orahi',
#  u'T_Ball',
#  u'Ripper',
#  u'B_Ball',
#  u'Zumba',
#  u'Netball',
#  u'Dance_off',
#  u'Bootcamp',
#  u'Other.5',
#  u'Monday',
#  u'Tuesday',
#  u'Wednesday',
#  u'Thursday',
#  u'Friday',
#  u'Saturday',
#  u'Sunday',
#  u'Library',
#  u'Aquatic',
#  u'City_Focus',
#  u'Redwoods',
#  u'Parks',
#  u'Lakes',
#  u'Night_market',
#  u'Museuem',
#  u'Youth_centre',
#  u'Youth_health',
#  u'Gym',
#  u'Church',
#  u'Marae',
#  u'Events_centre',
#  u'Sports_drom',
#  u'Convention_centre',
#  u'Stadium',
#  u'Where_else_do_you_go?',
#  u'W_Heights',
#  u'Fordlands',
#  u'Central_City',
#  u'Ngong',
#  u'Puketawhero',
#  u'Youth_space?',
#  u'Rotaz?',
#  u'Physical',
#  u'Sport.1',
#  u'Music',
#  u'Creative',
#  u'Comm_fiar',
#  u'Youth_group',
#  u'Faith_group',
#  u'Student_council',
#  u'Community_interest',
#  u'Environmental_Volunter',
#  u'Volunteering',
#  u'Art',
#  u'Culture.2',
#  u'School',
#  u'Shopping',
#  u'With_friends_',
#  u'With_family',
#  u'Nothing',
#  u'Other.6',
#  u'Physical.1',
#  u'Sport.2',
#  u'Music.1',
#  u'Creative.1',
#  u'Comm_fiar.1',
#  u'Youth_group.1',
#  u'Faith_group.1',
#  u'Student_council.1',
#  u'Community_interest.1',
#  u'Environmental_Volunter.1',
#  u'Volunteering.1',
#  u'Art.1',
#  u'Culture.3',
#  u'School.1',
#  u'Shopping.1',
#  u'With_friends_.1',
#  u'With_family.1',
#  u'Nothing.1',
#  u'Other.7',
#  u'Not_interested',
#  u'Time',
#  u'Costs_too_much',
#  u"Can't_afford",
#  u'No_friends',
#  u'not_available',
#  u'Cant_get_there',
#  u'Shy',
#  u'Other_responsibility',
#  u'Parents_say_no',
#  u"Don't_know_how",
#  u'Other.8',
#  u'Internet',
#  u'Church.1',
#  u'School.2',
#  u'Newspaper',
#  u'WINZ',
#  u'Library.1',
#  u'Youth_group.2',
#  u'Mail',
#  u'Txt',
#  800,
#  u'Other.9',
#  u'Eastside_youth_council',
#  'Ethnicity']

# %%
temp =df.ix[:,'Physical':'Other.6'].count()
act_list = list(temp.keys()[0:18])
act_list
# Out:
# [u'Physical',
#  u'Sport.1',
#  u'Music',
#  u'Creative',
#  u'Comm_fiar',
#  u'Youth_group',
#  u'Faith_group',
#  u'Student_council',
#  u'Community_interest',
#  u'Environmental_Volunter',
#  u'Volunteering',
#  u'Art',
#  u'Culture.2',
#  u'School',
#  u'Shopping',
#  u'With_friends_',
#  u'With_family',
#  u'Nothing']

# %%
#,columns=['Gender_(M/F)']
def func_1(a):
    return np.sum(a)/866.*100 #Maybe not needed to divide by whole sample
table3 = pd.pivot_table(df, values=act_list, index=['Age'], aggfunc=func_1)
table3
# Out:
#           Art  Comm_fiar  Community_interest  Creative  Culture.2  \
# Age
# 9    2.655889   1.501155            0.115473  1.385681   0.923788
# 10   3.926097   2.078522            0.692841  1.847575   1.847575
# 11   4.849885   2.193995            1.154734  3.464203   1.501155
# 12   2.078522   0.923788                 NaN  1.154734   0.577367
# 13   3.117783   1.732102            0.230947  1.847575   0.692841
# 14   1.963048   0.692841            0.115473  1.501155   0.923788
# 15   1.963048   0.346420                 NaN  1.385681   0.461894
# 16   1.270208   0.692841                 NaN  1.039261   0.346420
# 17   0.230947   0.346420            0.115473  0.346420   0.230947
# 18   0.115473        NaN                 NaN  0.115473        NaN
#
#      Environmental_Volunter  Faith_group     Music  Physical    School  \
# Age
# 9                  0.346420     1.154734  1.847575  1.270208  1.270208
# 10                 1.616628     1.847575  3.926097  5.080831  2.771363
# 11                 2.424942     1.154734  5.080831  7.043880  4.157044
# 12                 0.923788     0.577367  2.886836  3.810624  2.771363
# 13                 0.230947     0.577367  3.002309  5.889145  2.655889
# 14                 0.230947     1.039261  1.963048  7.274827  3.464203
# 15                 0.230947     1.732102  1.963048  6.235566  3.926097
# 16                 0.230947     0.692841  1.732102  5.542725  2.540416
# 17                 0.346420     0.115473  0.461894  1.501155  1.385681
# 18                      NaN          NaN       NaN  0.230947       NaN
#
#      Shopping   Sport.1  Student_council  Volunteering  With_family  \
# Age
# 9    3.464203  2.655889         0.346420      1.039261     3.695150
# 10   6.581986  7.967667         1.154734      2.193995     8.314088
# 11   8.545035  9.237875         1.616628      2.309469    11.431871
# 12   4.965358  5.427252         1.385681      0.577367     6.928406
# 13   5.196305  5.773672              NaN      0.461894     7.274827
# 14   4.618938  7.621247         0.577367      0.577367     7.505774
# 15   4.041570  5.311778         0.461894      1.963048     6.581986
# 16   2.771363  4.618938         0.461894      0.808314     4.272517
# 17   1.501155  2.193995         0.346420      0.692841     2.540416
# 18   0.115473  0.115473              NaN      0.115473     0.115473
#
#      With_friends_  Youth_group
# Age
# 9         2.886836     0.692841
# 10        8.545035     1.385681
# 11       11.431871     0.577367
# 12        7.621247     0.461894
# 13        9.237875     1.501155
# 14        9.584296     0.923788
# 15        9.006928     1.039261
# 16        6.120092     1.270208
# 17        2.540416     0.346420
# 18        0.115473          NaN
