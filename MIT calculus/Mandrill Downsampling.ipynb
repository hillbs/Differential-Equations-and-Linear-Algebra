# %% [markdown]
# # SVD for downsampling

# %%
import matplotlib.pyplot as plt
import os
import scipy.linalg as la
#Set the cwd.
os.chdir('/Users/LlewelynRW/Downloads/1.2 - ls - pres/Presidents/')
img2 = imread('mandrill.jpg')
U4,Sig4,V4 = svd(img2)
Sig4 = diag(Sig4) #Creates sparse diagonal matrix ∑
plt.plot(la.svdvals(np.array(img2)[:,:,0]))

# %%
plt.imshow(img2)

# %%
sx,sy,sz = shape(img2)
target_Vector = np.reshape(img2,[sx*sy,sz])
#set the value to center the data 
shift = 127
target_Vector = target_Vector - shift
U5,S6,V7 = svd(target_Vector, full_matrices=True)
S6 = diag(S6)
