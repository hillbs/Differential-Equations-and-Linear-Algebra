# %%
import pandas as pd

# %%
#plt.figure()
def Standard_background():
    f = plt.figure(facecolor=".9")
    ax = f.add_subplot(111, axisbg="#F4EAEA")
    return

# %% [markdown]
# A reference for some advanced reading in is http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/

# %%
team_stats.columns = ['TEAM','PLD','PTS','TRS','CON','PEN','DG','YC','RC']
team_stats.sort('PTS',ascending=False)
# Out:
#              TEAM  PLD   PTS  TRS  CON  PEN  DG  YC  RC
# 12    New Zealand   43  2012  272  198   98   8   4   0
# 1       Australia   41  1423  181  132   91   8   3   1
# 6          France   43  1354  158  109  121  10   8   0
# 4         England   40  1246  131   97  121  20   4   0
# 18   South Africa   29  1009  115   88   73  13   5   2
# 17       Scotland   33   972  113   82   85  10   2   0
# 23          Wales   32   919  115   83   61   6   2   2
# 8         Ireland   30   819   96   73   64   9   3   0
# 0       Argentina   30   742   74   49   85   9   5   1
# 16          Samoa   24   585   68   47   51   2   3   2
# 5            FIJI   24   538   59   45   48   6   6   1
# 2          Canada   25   469   49   29   52   8   2   3
# 9           Italy   24   455   47   32   53   3   6   0
# 10          Japan   24   428   51   29   42   3   1   0
# 20          Tonga   21   335   36   25   35   1  10   3
# 14        Romania   24   305   33   14   40   1   3   0
# ...

# %%
Team_Stats = pd.read_clipboard(names = ['TEAM','PLD','PTS','TRS','CON','PEN','DG','YC','RC'])

# %%
#Team_Stats = Team_Stats.ix[1::2]

# %%
Team_Stats
#poolC.ix[1:2,'TEAM'] = 'NZ'
# Out:
#              TEAM  PLD   PTS  TRS  CON  PEN  DG  YC  RC
# 0     New Zealand   43  2012  272  198   98   8   4   0
# 1       Australia   41  1423  181  132   91   8   3   1
# 2          France   43  1354  158  109  121  10   8   0
# 3         England   40  1246  131   97  121  20   4   0
# 4    South Africa   29  1009  115   88   73  13   5   2
# 5        Scotland   33   972  113   82   85  10   2   0
# 6           Wales   32   919  115   83   61   6   2   2
# 7         Ireland   30   819   96   73   64   9   3   0
# 8       Argentina   30   742   74   49   85   9   5   1
# 9           Samoa   24   585   68   47   51   2   3   2
# 10           FIJI   24   538   59   45   48   6   6   1
# 11         Canada   25   469   49   29   52   8   2   3
# 12          Italy   24   455   47   32   53   3   6   0
# 13          Japan   24   428   51   29   42   3   1   0
# 14          Tonga   21   335   36   25   35   1  10   3
# 15        Romania   24   305   33   14   40   1   3   0
# ...

# %%
#team_stats.save('Team_stats.pkl')
Team_Stats.to_pickle('/Users/LlewelynRW/Dropbox/Calculus materials/18.086/Team_stats.pkl')
Team_Stats
# Out:
#              TEAM  PLD   PTS  TRS  CON  PEN  DG  YC  RC
# 0     New Zealand   43  2012  272  198   98   8   4   0
# 1       Australia   41  1423  181  132   91   8   3   1
# 2          France   43  1354  158  109  121  10   8   0
# 3         England   40  1246  131   97  121  20   4   0
# 4    South Africa   29  1009  115   88   73  13   5   2
# 5        Scotland   33   972  113   82   85  10   2   0
# 6           Wales   32   919  115   83   61   6   2   2
# 7         Ireland   30   819   96   73   64   9   3   0
# 8       Argentina   30   742   74   49   85   9   5   1
# 9           Samoa   24   585   68   47   51   2   3   2
# 10           FIJI   24   538   59   45   48   6   6   1
# 11         Canada   25   469   49   29   52   8   2   3
# 12          Italy   24   455   47   32   53   3   6   0
# 13          Japan   24   428   51   29   42   3   1   0
# 14          Tonga   21   335   36   25   35   1  10   3
# 15        Romania   24   305   33   14   40   1   3   0
# ...

# %% [markdown]
# # RWC analysis

# %% [markdown]
# The above sections read the data from the RWC site, save the dfs and clean the data

# %%
Team_Stats = pd.read_pickle('/Users/LlewelynRW/Dropbox/Calculus materials/18.086/Team_stats.pkl')
PoolA = pd.read_pickle('/Users/LlewelynRW/Dropbox/Calculus materials/18.086/PoolA.pkl')
PoolB = pd.read_pickle('/Users/LlewelynRW/Dropbox/Calculus materials/18.086/PoolB.pkl')
PoolC = pd.read_pickle('/Users/LlewelynRW/Dropbox/Calculus materials/18.086/PoolC.pkl')
PoolD = pd.read_pickle('/Users/LlewelynRW/Dropbox/Calculus materials/18.086/PoolD.pkl')

# %%
PoolB.ix[1,0] = 'SOUTH AFRICA'
PoolB.ix[1,1] = 0
PoolC.ix[1,0] = 'NEW ZEALAND'
PoolC.ix[1,1] = 0

# %%
RWC15 = pd.concat([PoolA,PoolB,PoolC,PoolD]) 
RWC15['Rank'] = 1.+ (RWC15.W-RWC15.L)/2.
RWC15.TEAM,Team_Stats.TEAM
# Out:
# (1       AUSTRALIA
#  3         ENGLAND
#  5           WALES
#  7            FIJI
#  9         URUGUAY
#  1    SOUTH AFRICA
#  3           SAMOA
#  5           JAPAN
#  7        SCOTLAND
#  9             USA
#  1     NEW ZEALAND
#  3       ARGENTINA
#  5           TONGA
#  7         GEORGIA
#  9         NAMIBIA
#  1          FRANCE
#  3         IRELAND
#  5           ITALY
#  7          CANADA
#  9         ROMANIA
#  Name: TEAM, dtype: object, 0       New Zealand
#  1         Australia
#  2            France
#  3           England
#  4      South Africa
#  5          Scotland
#  6             Wales
#  7           Ireland
#  8         Argentina
#  9             Samoa
#  10             FIJI
#  11           Canada
#  12            Italy
#  13            Japan
#  14            Tonga
#  15          Romania
#  16              USA
#  17          Namibia
#  18          Georgia
#  19          Uruguay
#  20         Zimbabwe
#  21           Russia
#  22         Portugal
#  23    Cote D'Ivoire
# ...

# %%
#Create a normally distributed strength for each team
Team_Stats['PTS_Per_Game'] = Team_Stats.PTS/Team_Stats.PLD
Team_Stats['Strength'] = (Team_Stats.PTS_Per_Game - Team_Stats.PTS_Per_Game.mean())/Team_Stats.PTS_Per_Game.std()

#Make the joining column compatible.
Team_Stats.TEAM = map(str.upper,Team_Stats.TEAM)
RWC_Combined = pd.merge(Team_Stats,RWC15,on='TEAM')
#Set the index to the team name.
RWC_Combined = RWC_Combined.set_index(['TEAM'])
RWC_Combined.Strength
# Out:
# TEAM
# NEW ZEALAND     2.557188
# AUSTRALIA       1.361989
# FRANCE          1.043594
# ENGLAND         1.010125
# SOUTH AFRICA    1.370474
# SCOTLAND        0.842423
# WALES           0.769644
# IRELAND         0.629312
# ARGENTINA       0.375436
# SAMOA           0.339992
# FIJI            0.146288
# CANADA         -0.215402
# ITALY          -0.195785
# JAPAN          -0.307061
# TONGA          -0.493111
# ROMANIA        -0.813988
# USA            -0.657966
# NAMIBIA        -1.121442
# GEORGIA        -0.884052
# URUGUAY        -0.686226
# Name: Strength, dtype: float64

# %%
Standard_background()
RWC_Combined.Strength.plot(kind='bar',figsize=(12,8),color='purple')
